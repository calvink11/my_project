# %% [markdown]
# # News Preprocessing Using Ckiplab NLP Package

# %%
import pandas as pd
import numpy
from collections import Counter
from snownlp import SnowNLP
from ckip_transformers.nlp import CkipWordSegmenter, CkipPosTagger, CkipNerChunker

df = pd.read_csv('now_category_news.csv', sep='|')

ws = CkipWordSegmenter(level=2)
pos = CkipPosTagger(level=2)
ner = CkipNerChunker(level=2)

tokens = ws(df.content)

tokens_pos = pos(tokens)

word_pos_pair = [list(zip(w, p)) for w, p in zip(tokens, tokens_pos)]

entity_list = ner(df.content)

allowPOS = ['Na', 'Nb', 'Nc', 'VA', 'VAC', 'VB', 'VC']

tokens_v2 = []
for wp in word_pos_pair:
    tokens_v2.append([w for w, p in wp if (len(w) >= 2) and p in allowPOS])

df['tokens'] = tokens
df['tokens_v2'] = tokens_v2
df['entities'] = entity_list
df['token_pos'] = word_pos_pair

allowPOS = ['Na', 'Nb', 'Nc', 'VC']

def word_frequency(wp_pair):
    filtered_words = []
    for word, pos in wp_pair:
        if (pos in allowPOS) & (len(word) >= 2):
            filtered_words.append(word)

    counter = Counter(filtered_words)
    return counter.most_common(200)


keyfreqs = []
for wp in word_pos_pair:
    topwords = word_frequency(wp)
    keyfreqs.append(topwords)

df['top_key_freq'] = keyfreqs

summary = []
sentiment = []
for text in df.content:
    sn = SnowNLP(text)
    summary.append(sn.summary())
    sentiment.append(round(sn.sentiments, 2))

df['summary'] = summary
df['sentiment'] = sentiment

df = df[[
    'item_id', 'date','category', 'title', 'content', 'sentiment', 'summary',
    'top_key_freq', 'tokens', 'tokens_v2', 'entities', 'token_pos', 'link',
    'photo_link'
]]

df.to_csv('now_news_preprocessed.csv', sep='|', index=False)

print("process OK!")
# Out:
# Tokenization: 100%|██████████| 3671/3671 [00:03<00:00, 963.46it/s]
# Inference: 100%|██████████| 29/29 [58:32<00:00, 121.11s/it]
# Tokenization: 100%|██████████| 3671/3671 [00:02<00:00, 1229.41it/s]
# Inference: 100%|██████████| 749/749 [15:59:19<00:00, 76.85s/it]
# Tokenization: 100%|██████████| 3671/3671 [00:04<00:00, 787.93it/s]
# Inference: 100%|██████████| 29/29 [1:01:58<00:00, 128.22s/it]
# process OK!

# %%
df = pd.read_csv('now_news_preprocessed.csv', sep='|')
df.head(1)
# Out:
#                  item_id        date category                       title  \
# 0  column/_20220505_1001  2022-05-05       焦點  配發率32%！富邦金每股配4元股利、現金股利歷史新高
#
#                                              content  sentiment  \
# 0  富邦金控今（5）日公告，董事會決議通過擬配發普通股每股現金股利3.5元及股票股利0.5元，合...        0.0
#
#                                              summary  \
# 0  ['富邦金這次同時配發股票股利每股0.5元', '包含富邦人壽上繳155.78億元、台北富邦...
#
#                                         top_key_freq  \
# 0  [('股利', 18), ('富邦', 12), ('現金', 9), ('股票', 5),...
#
#                                               tokens  \
# 0  ['富邦', '金控', '今', '（5', '）', '日', '公告', '，', '...
#
#                                            tokens_v2  \
# 0  ['富邦', '金控', '董事會', '通過', '普通股', '現金', '股利', '...
#
#                                             entities  \
# 0  [NerToken(word='富邦金控', ner='ORG', idx=(0, 4)),...
#
#                                            token_pos  \
# 0  [('富邦', 'Nb'), ('金控', 'Na'), ('今', 'Nd'), ('（5...
#
#                                    link  \
# 0  https://www.nownews.com/news/5796259
#
#                                           photo_link
# 0  https://media.nownews.com/nn_media/thumbnail/2...

# %% [markdown]
# ## Count top 200 word frequency for each category

# %%
import pandas as pd

# %%
df = pd.read_csv('now_news_preprocessed.csv',sep='|')

# %%
from collections import Counter

# %%
news_links = ['column/', 'news-summary/', 'breaking/', 'entertainment/', 'novelty/', 'life/', 'finance/', 'st/', 'news-global/', 'sport/']
news_categories = ['焦點', '要聞', '即時', '娛樂', '新奇', '生活', '財經', '專題', '全球', '運動']

# %%
allowedPOS=['Na', 'Nb', 'Nc']

# %%
def get_top_words():
    top_cate_words={}
    counter_all = Counter()
    for category in news_categories:
        df_group = df[df.category == category]
        words_group = []
        for row in df_group.token_pos:
            filtered_words = []
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)                
            words_group += filtered_words
        counter = Counter( words_group )
        counter_all += counter
        topwords = counter.most_common(200)
        top_cate_words[category] = topwords
    top_cate_words['全部'] = counter_all.most_common(200)
    return list(top_cate_words.items())

# %%
result = get_top_words()

# %%
top_group_words = get_top_words()

# %%
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])

# %%
df_top_group_words
# Out:
#    category                                           top_keys
# 0        焦點  [(台灣, 555), (美國, 387), (疫情, 369), (中國, 341), (...
# 1        要聞  [(台灣, 576), (疫情, 554), (中央, 309), (政府, 285), (...
# 2        即時  [(台灣, 532), (疫情, 392), (網友, 357), (公司, 223), (...
# 3        娛樂  [(網友, 332), (粉絲, 292), (汪小菲, 239), (台灣, 208), ...
# 4        新奇  [(網友, 645), (編輯, 289), (台灣, 240), (貼文, 236), (...
# 5        生活  [(台灣, 301), (網友, 254), (疫情, 239), (民眾, 231), (...
# 6        財經  [(台灣, 435), (公司, 303), (能源, 293), (市場, 279), (...
# 7        專題  [(女優, 2082), (男優, 1890), (台灣, 1272), (產業, 981)...
# 8        全球  [(中國, 732), (美國, 638), (烏克蘭, 422), (國家, 378), ...
# 9        運動  [(球員, 411), (球隊, 365), (比賽, 339), (勇士, 338), (...
# 10       全部  [(台灣, 4594), (疫情, 2436), (女優, 2180), (男優, 1928...

# %%
df_top_group_words.to_csv('now_news_topkeys_with_category_via_token_pos.csv', index=False)

# %% [markdown]
# ## Count top 200 persons via NER

# %%
df = pd.read_csv('now_news_preprocessed.csv',sep='|')

# %%
df.head(1)
# Out:
#                  item_id        date category                       title  \
# 0  column/_20220505_1001  2022-05-05       焦點  配發率32%！富邦金每股配4元股利、現金股利歷史新高
#
#                                              content  sentiment  \
# 0  富邦金控今（5）日公告，董事會決議通過擬配發普通股每股現金股利3.5元及股票股利0.5元，合...        0.0
#
#                                              summary  \
# 0  ['富邦金這次同時配發股票股利每股0.5元', '包含富邦人壽上繳155.78億元、台北富邦...
#
#                                         top_key_freq  \
# 0  [('股利', 18), ('富邦', 12), ('現金', 9), ('股票', 5),...
#
#                                               tokens  \
# 0  ['富邦', '金控', '今', '（5', '）', '日', '公告', '，', '...
#
#                                            tokens_v2  \
# 0  ['富邦', '金控', '董事會', '通過', '普通股', '現金', '股利', '...
#
#                                             entities  \
# 0  [NerToken(word='富邦金控', ner='ORG', idx=(0, 4)),...
#
#                                            token_pos  \
# 0  [('富邦', 'Nb'), ('金控', 'Na'), ('今', 'Nd'), ('（5...
#
#                                    link  \
# 0  https://www.nownews.com/news/5796259
#
#                                           photo_link
# 0  https://media.nownews.com/nn_media/thumbnail/2...

# %%
df.entities[0]
# Out:
# "[NerToken(word='富邦金控', ner='ORG', idx=(0, 4)), NerToken(word='3.5元', ner='MONEY', idx=(31, 35)), NerToken(word='0.5元', ner='MONEY', idx=(40, 44)), NerToken(word='4.0元', ner='MONEY', idx=(52, 56)), NerToken(word='32%', ner='PERCENT', idx=(77, 80)), NerToken(word='富邦金', ner='ORG', idx=(86, 89)), NerToken(word='2021年', ner='DATE', idx=(116, 121)), NerToken(word='1,445.59億元', ner='MONEY', idx=(132, 142)), NerToken(word='富邦金', ner='ORG', idx=(170, 173)), NerToken(word='去年', ner='DATE', idx=(182, 184)), NerToken(word='新台幣3元', ner='MONEY', idx=(187, 192)), NerToken(word='3.5元', ner='MONEY', idx=(200, 204)), NerToken(word='俄', ner='GPE', idx=(262, 263)), NerToken(word='富邦金控', ner='ORG', idx=(336, 340)), NerToken(word='富邦人壽', ner='ORG', idx=(349, 353)), NerToken(word='155.78億元', ner='MONEY', idx=(355, 363)), NerToken(word='台北富邦銀行', ner='ORG', idx=(364, 370)), NerToken(word='富邦', ner='ORG', idx=(380, 382)), NerToken(word='47.99億元', ner='MONEY', idx=(386, 393)), NerToken(word='富邦', ner='ORG', idx=(394, 396)), NerToken(word='1.43億元', ner='MONEY', idx=(401, 407)), NerToken(word='富邦人壽', ner='ORG', idx=(409, 413)), NerToken(word='富邦人壽', ner='ORG', idx=(419, 423)), NerToken(word='5.2%', ner='PERCENT', idx=(432, 436)), NerToken(word='富邦', ner='ORG', idx=(439, 441)), NerToken(word='台北富邦銀行', ner='ORG', idx=(451, 457)), NerToken(word='北富銀', ner='ORG', idx=(463, 466)), NerToken(word='2021年', ner='DATE', idx=(466, 471)), NerToken(word='38.5%', ner='PERCENT', idx=(474, 479)), NerToken(word='富邦', ner='ORG', idx=(516, 518)), NerToken(word='富邦', ner='ORG', idx=(521, 523)), NerToken(word='富邦金', ner='ORG', idx=(551, 554)), NerToken(word='0.5元', ner='MONEY', idx=(566, 570)), NerToken(word='富邦金', ner='ORG', idx=(571, 574)), NerToken(word='金管會', ner='ORG', idx=(698, 701)), NerToken(word='6', ner='CARDINAL', idx=(703, 704)), NerToken(word='500億', ner='CARDINAL', idx=(716, 720))]"

# %%
def NerToken(word, ner, idx):
    return ner,word

# %%
for ner,key in eval(df.entities[0]):
    print(ner,key)
# Out:
# ORG 富邦金控
# MONEY 3.5元
# MONEY 0.5元
# MONEY 4.0元
# PERCENT 32%
# ORG 富邦金
# DATE 2021年
# MONEY 1,445.59億元
# ORG 富邦金
# DATE 去年
# MONEY 新台幣3元
# MONEY 3.5元
# GPE 俄
# ORG 富邦金控
# ORG 富邦人壽
# MONEY 155.78億元
# ORG 台北富邦銀行
# ORG 富邦
# MONEY 47.99億元
# ORG 富邦
# MONEY 1.43億元
# ORG 富邦人壽
# ORG 富邦人壽
# PERCENT 5.2%
# ORG 富邦
# ORG 台北富邦銀行
# ORG 北富銀
# DATE 2021年
# PERCENT 38.5%
# ORG 富邦
# ORG 富邦
# ORG 富邦金
# MONEY 0.5元
# ORG 富邦金
# ORG 金管會
# CARDINAL 6
# CARDINAL 500億

# %%
from collections import Counter

# %%
allowedNE = ['PERSON']

news_categories = ['焦點', '要聞', '即時', '娛樂', '新奇', '生活', '財經', '專題', '全球', '運動']

# %%
def ne_word_frequency( a_news_ne ):
    filtered_words =[]
    for ner,word in a_news_ne:
        if (len(word) >= 2) & (ner in allowedNE):
            filtered_words.append(word)
    counter = Counter( filtered_words )
    return counter.most_common( 200 )

# %%
def get_top_ner_words():
    top_cate_ner_words={}
    words_all=[]
    for category in news_categories:
        df_group = df[df.category == category]
        words_group = []

        # concatenate terms in a category
        for row in df_group.entities:
            words_group += eval(row)

        # concatenate all terms
        words_all += words_group

        # Get top words by calling ne_word_frequency() function
        topwords = ne_word_frequency( words_group )
        top_cate_ner_words[category] = topwords

    topwords_all = ne_word_frequency(words_all)
    top_cate_ner_words['全部'] = topwords_all
    
    return list(top_cate_ner_words.items())
    # return top_cate_ne_words

# %%
# %%time
hotPersons = get_top_ner_words()
# Out:
# CPU times: total: 1.36 s
# Wall time: 1.4 s

# %%
hotPersons
# Out:
# [('焦點',
#   [('陳時中', 113),
#    ('柯文哲', 83),
#    ('蔡英文', 81),
#    ('汪小菲', 64),
#    ('張善政', 63),
#    ('馬可仕', 62),
#    ('拜登', 53),
#    ('蒲亭', 49),
#    ('伊美黛', 48),
#    ('葛斯齊', 41),
#    ('黃珊珊', 38),
#    ('于北辰', 34),
#    ('王婉諭', 32),
#    ('蔣萬安', 31),
#    ('朱立倫', 31),
#    ('林佳龍', 31),
#    ('林智堅', 29),
#    ('習近平', 28),
#    ('鄭文燦', 25),
#    ('侯友宜', 24),
#    ('卡蜜兒', 24),
#    ('羅智強', 23),
#    ('沈慧虹', 23),
#    ('蘇紫雲', 23),
#    ('鄒幸彤', 23),
#    ('金正恩', 22),
#    ('蘇貞昌', 22),
#    ('柯拉蓉', 22),
#    ('孫唯容', 21),
#    ('澤倫斯基', 21),
#    ('陳苾暐', 21),
#    ('戴普', 21),
#    ('郭彥均', 20),
#    ('邱志偉', 19),
#    ('馬克宏', 18),
#    ('馬英九', 18),
#    ('高嘉瑜', 17),
#    ('黃亭偉', 17),
#    ('奈特', 17),
#    ('艾班尼斯', 16),
#    ('艾爾段', 16),
#    ('岸田文雄', 15),
#    ('顏若芳', 14),
#    ('羅一鈞', 14),
#    ('安珀', 14),
#    ('陳偉華', 13),
#    ('余天', 13),
#    ('莊人祥', 13),
#    ('易俊宏', 12),
#    ('鄭運鵬', 12),
#    ('艾奎諾', 12),
#    ('艾奎諾二世', 12),
#    ('莫里森', 11),
#    ('邱奕勝', 11),
#    ('陳有忠', 11),
#    ('何博文', 10),
#    ('張麗善', 10),
#    ('張穎穎', 10),
#    ('吳佩芸', 10),
#    ('陳其邁', 9),
#    ('林義傑', 9),
#    ('徐巧芯', 9),
#    ('布希', 9),
#    ('賴心雅', 9),
#    ('谷愛凌', 8),
#    ('尹錫悅', 8),
#    ('陳日君', 8),
#    ('張惇涵', 8),
#    ('江啟臣', 8),
#    ('陳亮達', 8),
#    ('詹長權', 7),
#    ('陳柏惟', 7),
#    ('陳吉仲', 7),
#    ('翁茂鍾', 7),
#    ('蕭茲', 7),
#    ('達志', 7),
#    ('川普', 7),
#    ('林家興', 7),
#    ('林英煌', 7),
#    ('達克沃絲', 7),
#    ('厄羅爾', 7),
#    ('王毅', 7),
#    ('波特王', 7),
#    ('鄧美慧', 6),
#    ('林靜儀', 6),
#    ('林鶴明', 6),
#    ('魯明哲', 6),
#    ('萬美玲', 6),
#    ('金斯', 6),
#    ('朱士廷', 6),
#    ('賴品妤', 6),
#    ('哈莉瑪', 6),
#    ('蔡清祥', 6),
#    ('吳訓孝', 6),
#    ('尼諾', 6),
#    ('黃世杰', 6),
#    ('劉和然', 6),
#    ('希哈布', 6),
#    ('黃家琦', 6),
#    ('徐志榮', 6),
#    ('連千毅', 6),
#    ('蓋戴', 6),
#    ('黃英賢', 6),
#    ('徐永明', 6),
#    ('伊隆．馬斯克', 6),
#    ('林莞茜', 6),
#    ('林飛帆', 6),
#    ('阿瑞唐多', 6),
#    ('許家睿', 6),
#    ('李兆立', 5),
#    ('黃德清', 5),
#    ('楊植斗', 5),
#    ('侯佩岑', 5),
#    ('林奏延', 5),
#    ('埃皮舍瓦', 5),
#    ('阮清龍', 5),
#    ('朱玉英', 5),
#    ('趙立堅', 5),
#    ('徐和建', 5),
#    ('廖嬋娥', 5),
#    ('盧秀燕', 5),
#    ('阿爾登', 5),
#    ('莫迪', 5),
#    ('安倍', 5),
#    ('布朗', 5),
#    ('張維倩', 5),
#    ('亮達', 5),
#    ('李家超', 5),
#    ('薩勒', 5),
#    ('馬拉普', 5),
#    ('路易', 5),
#    ('吳宗憲', 5),
#    ('強尼', 5),
#    ('楊金龍', 5),
#    ('郭台銘', 4),
#    ('陸振翮', 4),
#    ('田文雄', 4),
#    ('米納', 4),
#    ('鄭小康', 4),
#    ('柯建銘', 4),
#    ('錢震宇', 4),
#    ('吳釗燮', 4),
#    ('文在寅', 4),
#    ('江雅綺', 4),
#    ('陳學聖', 4),
#    ('李敏勇', 4),
#    ('呂紹嘉', 4),
#    ('岸田', 4),
#    ('李杰', 4),
#    ('周鳴晨', 4),
#    ('林盈君', 4),
#    ('阿克萊', 4),
#    ('比比洛夫', 4),
#    ('邱議瑩', 4),
#    ('吳德榮', 4),
#    ('芮斯莫格', 4),
#    ('吐瓦魯', 4),
#    ('鍾男', 4),
#    ('孫文', 4),
#    ('歐巴馬', 4),
#    ('蘇治芬', 4),
#    ('呂玉玲', 4),
#    ('陳水扁', 4),
#    ('張蘭', 4),
#    ('龔明鑫', 4),
#    ('劉政鴻', 4),
#    ('蒙娜麗莎', 4),
#    ('李建葦', 4),
#    ('鄧振中', 4),
#    ('畢昂奇', 4),
#    ('侯漢廷', 4),
#    ('林俊憲', 4),
#    ('卡蜜拉', 4),
#    ('鍾文雄', 4),
#    ('婁俊碩', 3),
#    ('許家蓓', 3),
#    ('雪蔓', 3),
#    ('鄭仲嵐', 3),
#    ('林右昌', 3),
#    ('莊伯仲', 3),
#    ('李永得', 3),
#    ('邁南德', 3),
#    ('李光章', 3),
#    ('拉莫斯', 3),
#    ('王清霜', 3),
#    ('黃天牧', 3),
#    ('陳建仁', 3),
#    ('劉宇其', 3),
#    ('烏克蘭', 3),
#    ('王婉', 3),
#    ('馬立波', 3),
#    ('莎琪', 3),
#    ('圖爾桑尼', 3),
#    ('賀錦麗', 3),
#    ('戚振宏', 3),
#    ('葛蘭', 3),
#    ('李新穎', 3),
#    ('吳秀梅', 3),
#    ('戴琪', 3),
#    ('蕭依古', 3)]),
#  ('要聞',
#   [('柯文哲', 216),
#    ('侯友宜', 150),
#    ('陳時中', 126),
#    ('蔡英文', 119),
#    ('朱立倫', 117),
#    ('張善政', 107),
#    ('蘇貞昌', 100),
#    ('羅智強', 91),
#    ('黃珊珊', 83),
#    ('蔣萬安', 75),
#    ('盧秀燕', 64),
#    ('馬英九', 51),
#    ('林佳龍', 49),
#    ('余天', 39),
#    ('張國華', 29),
#    ('何博文', 28),
#    ('林鶴明', 27),
#    ('高嘉瑜', 26),
#    ('達克沃絲', 25),
#    ('吳釗燮', 25),
#    ('李鴻鈞', 23),
#    ('顏若芳', 23),
#    ('恩恩', 21),
#    ('王國材', 20),
#    ('潘文忠', 20),
#    ('鄭運鵬', 19),
#    ('林楚茵', 19),
#    ('呂玉玲', 19),
#    ('張國明', 19),
#    ('張惇涵', 16),
#    ('林奕華', 15),
#    ('戴瑋姍', 15),
#    ('郭彥均', 15),
#    ('陳秀熙', 14),
#    ('林智堅', 14),
#    ('林秉樞', 14),
#    ('王婉諭', 14),
#    ('邱臣遠', 13),
#    ('江啟臣', 13),
#    ('高登', 13),
#    ('蔡其昌', 13),
#    ('于北辰', 13),
#    ('蔡適應', 12),
#    ('易俊宏', 12),
#    ('趙少康', 12),
#    ('鄭文燦', 12),
#    ('曾梓展', 12),
#    ('許甫', 12),
#    ('蘇紫雲', 12),
#    ('蘇巧慧', 12),
#    ('周玉蔻', 11),
#    ('柯建銘', 11),
#    ('邱奕勝', 11),
#    ('陳隆翔', 11),
#    ('魯明哲', 11),
#    ('蔡壁如', 11),
#    ('羅秉成', 10),
#    ('李明政', 10),
#    ('曾銘宗', 10),
#    ('林右昌', 10),
#    ('王任賢', 10),
#    ('孫健萍', 10),
#    ('王定宇', 10),
#    ('卓冠廷', 9),
#    ('黃健庭', 9),
#    ('高涌誠', 9),
#    ('林靜儀', 9),
#    ('張國政', 9),
#    ('林姿妙', 9),
#    ('李永得', 9),
#    ('林應然', 8),
#    ('陳偉杰', 8),
#    ('葛利歐', 8),
#    ('恩恩爸', 8),
#    ('林莞茜', 8),
#    ('梁文傑', 8),
#    ('宋楚瑜', 8),
#    ('邢泰釗', 8),
#    ('李登輝', 8),
#    ('李明哲', 8),
#    ('陳文政', 8),
#    ('鍾佳濱', 8),
#    ('黃建賢', 8),
#    ('賴清德', 8),
#    ('劉和然', 8),
#    ('陳柏惟', 8),
#    ('郭董', 8),
#    ('游錫堃', 7),
#    ('林錫耀', 7),
#    ('黃景泰', 7),
#    ('萬美玲', 7),
#    ('洪孟楷', 7),
#    ('溫朗東', 7),
#    ('李昆澤', 7),
#    ('周春米', 7),
#    ('顏寬恆', 7),
#    ('林炳存', 7),
#    ('柳采葳', 7),
#    ('杜奕瑾', 7),
#    ('蔣介石', 7),
#    ('楊志良', 7),
#    ('郭台銘', 7),
#    ('莫德納', 6),
#    ('羅致政', 6),
#    ('陳椒華', 6),
#    ('陳博淵', 6),
#    ('鄭朝方', 6),
#    ('勞倫契克', 6),
#    ('趙介佑', 6),
#    ('江惠民', 6),
#    ('江肇國', 6),
#    ('林思銘', 6),
#    ('鄭正鈐', 6),
#    ('岸田文雄', 6),
#    ('王立任', 6),
#    ('賴秋媚', 6),
#    ('黃高彬', 6),
#    ('黃亭偉', 6),
#    ('黃捷', 6),
#    ('吳宗憲', 6),
#    ('宋正一', 6),
#    ('劉士州', 6),
#    ('黃福雄', 6),
#    ('顏清標', 6),
#    ('許家睿', 6),
#    ('黃韋鈞', 5),
#    ('陳乃瑜', 5),
#    ('梁晨', 5),
#    ('黃彩玲', 5),
#    ('蔡清祥', 5),
#    ('劍青', 5),
#    ('蕭行凱', 5),
#    ('蔡易餘', 5),
#    ('岸田', 5),
#    ('賴香伶', 5),
#    ('高虹安', 5),
#    ('李秉穎', 5),
#    ('拜登', 5),
#    ('陳其邁', 5),
#    ('安倍', 5),
#    ('川普', 5),
#    ('布希', 5),
#    ('張榮發', 5),
#    ('費鴻泰', 5),
#    ('張凱鈞', 5),
#    ('歐江安', 5),
#    ('布林肯', 5),
#    ('徐志榮', 5),
#    ('陳世凱', 5),
#    ('林耕仁', 5),
#    ('張之豪', 5),
#    ('林俊憲', 5),
#    ('侯家軍', 4),
#    ('余苑綺', 4),
#    ('李亞萍', 4),
#    ('翁震州', 4),
#    ('彭一書', 4),
#    ('葉啟洲', 4),
#    ('林為洲', 4),
#    ('烏克蘭', 4),
#    ('黎榮章', 4),
#    ('林清淇', 4),
#    ('令狐榮達', 4),
#    ('李大維', 4),
#    ('李德維', 4),
#    ('葉毓蘭', 4),
#    ('陳子瑜', 4),
#    ('張博洋', 4),
#    ('田文雄', 4),
#    ('黃呂錦茹', 4),
#    ('鄭照新', 4),
#    ('張恒嘉', 4),
#    ('孫文', 4),
#    ('陳吉仲', 4),
#    ('蔡炳坤', 4),
#    ('王正嘉', 4),
#    ('徐國勇', 4),
#    ('施信如', 4),
#    ('周江杰', 4),
#    ('莊青一', 4),
#    ('張宏林', 4),
#    ('謝佩芬', 4),
#    ('顏寬恒', 4),
#    ('高淑真', 4),
#    ('鄧振中', 4),
#    ('王閔生', 4),
#    ('安藤忠雄', 4),
#    ('林飛帆', 4),
#    ('沈慧虹', 4),
#    ('黃心華', 3),
#    ('李宇翔', 3),
#    ('吳亞蓁', 3),
#    ('山田摩衣', 3),
#    ('黃琳', 3),
#    ('林秉宥', 3),
#    ('陳建仁', 3),
#    ('王世堅', 3),
#    ('邱國正', 3),
#    ('博塔文', 3),
#    ('斯洛伐克', 3)]),
#  ('即時',
#   [('陳時中', 90),
#    ('汪小菲', 74),
#    ('馬可仕', 67),
#    ('葛斯齊', 44),
#    ('羅智強', 40),
#    ('蔡英文', 39),
#    ('柯文哲', 38),
#    ('蒲亭', 35),
#    ('朱立倫', 32),
#    ('呂忠翰', 31),
#    ('林志玲', 30),
#    ('陳苾暐', 29),
#    ('納豆', 29),
#    ('張善政', 27),
#    ('連千毅', 25),
#    ('郭婞淳', 23),
#    ('侯友宜', 22),
#    ('澤倫斯基', 22),
#    ('李鴻鈞', 22),
#    ('梓梓', 21),
#    ('大S', 21),
#    ('吳釗燮', 20),
#    ('陳雅雲', 19),
#    ('樂天', 18),
#    ('張志浩', 18),
#    ('蘇貞昌', 18),
#    ('范米特', 18),
#    ('林莞茜', 17),
#    ('沈慧虹', 17),
#    ('黃珊珊', 17),
#    ('曾莞婷', 16),
#    ('林智堅', 16),
#    ('郭俊麟', 16),
#    ('唐綺陽', 16),
#    ('拜登', 16),
#    ('江宏傑', 15),
#    ('林依晨', 15),
#    ('郭彥均', 15),
#    ('王祖賢', 14),
#    ('林佳辰', 14),
#    ('張惇涵', 14),
#    ('張蘭', 14),
#    ('楊子賢', 14),
#    ('朱雲豪', 14),
#    ('丘昌榮', 13),
#    ('陳偉華', 13),
#    ('詹鎰睿', 13),
#    ('高登', 13),
#    ('莊詠鈞', 13),
#    ('小璐', 13),
#    ('習近平', 13),
#    ('桑尼', 13),
#    ('韓素希', 12),
#    ('楊謹華', 12),
#    ('楊穎軒', 12),
#    ('林佳龍', 12),
#    ('季芹', 12),
#    ('王思聰', 12),
#    ('黃啟嘉', 12),
#    ('李惠婷', 12),
#    ('陳珮瑜', 12),
#    ('鍾明軒', 12),
#    ('馬克宏', 12),
#    ('胡瓏貿', 12),
#    ('王心凌', 12),
#    ('喬伊斯', 12),
#    ('金泰梨', 11),
#    ('吳姍儒', 11),
#    ('林奕華', 11),
#    ('陳隆翔', 11),
#    ('瀨昆妮', 11),
#    ('李家超', 11),
#    ('杜特蒂', 11),
#    ('長瀨昆妮', 11),
#    ('張穎穎', 11),
#    ('李家瑞', 11),
#    ('蘇建文', 11),
#    ('潘毅', 10),
#    ('昆凌', 10),
#    ('高國華', 10),
#    ('宋家豪', 10),
#    ('王仁甫', 10),
#    ('戴普', 10),
#    ('宋仲基', 10),
#    ('鄭又瑋', 10),
#    ('賴琳恩', 10),
#    ('張淑晶', 10),
#    ('杜魯道', 10),
#    ('林暉閔', 10),
#    ('楊敬敏', 10),
#    ('太陽', 10),
#    ('吳念庭', 10),
#    ('張麗善', 10),
#    ('謝依霖', 10),
#    ('吳沁婕', 9),
#    ('林靖凱', 9),
#    ('江少慶', 9),
#    ('鄭運鵬', 9),
#    ('羅志祥', 9),
#    ('文在寅', 9),
#    ('李永得', 9),
#    ('王勝偉', 9),
#    ('林穎孟', 9),
#    ('王力宏', 9),
#    ('高涌誠', 9),
#    ('張嘉哲', 9),
#    ('許甫', 9),
#    ('羅貝多', 9),
#    ('劉伊心', 9),
#    ('孫生', 9),
#    ('鄧福如', 9),
#    ('魯拉', 9),
#    ('白冰冰', 9),
#    ('艾宸', 9),
#    ('徐巧芯', 9),
#    ('亞歷山大', 9),
#    ('宋慧喬', 9),
#    ('陳嘉緯', 9),
#    ('蔡康永', 9),
#    ('范國宸', 9),
#    ('錢薇娟', 9),
#    ('李俊昊', 8),
#    ('具俊曄', 8),
#    ('劉在錫', 8),
#    ('尹錫悅', 8),
#    ('周淑萍', 8),
#    ('宋楚瑜', 8),
#    ('蔡清祥', 8),
#    ('蔡鍾協', 8),
#    ('卡梅辛', 8),
#    ('岸田文雄', 8),
#    ('王婉諭', 8),
#    ('塔克', 8),
#    ('梁云菲', 8),
#    ('林威助', 8),
#    ('林益全', 8),
#    ('詹長權', 7),
#    ('林泓育', 7),
#    ('曾豪駒', 7),
#    ('徐大寶', 7),
#    ('陳吉仲', 7),
#    ('張宗憲', 7),
#    ('陳智菡', 7),
#    ('翁茂鍾', 7),
#    ('賴品妤', 7),
#    ('柯建銘', 7),
#    ('鄭文燦', 7),
#    ('周天成', 7),
#    ('韓瑜', 7),
#    ('李克強', 7),
#    ('郭佩蓉', 7),
#    ('溫朗東', 7),
#    ('張瀞云', 7),
#    ('御寺雪', 7),
#    ('阿苒', 7),
#    ('特拉斯', 7),
#    ('黃新皓', 7),
#    ('寇世勳', 7),
#    ('崔佩儀', 7),
#    ('洪寶川', 7),
#    ('達克沃絲', 7),
#    ('吳鳳', 7),
#    ('苗可麗', 7),
#    ('戴培峰', 7),
#    ('李宗賢', 6),
#    ('梁家榮', 6),
#    ('楊植斗', 6),
#    ('孫唯容', 6),
#    ('徐熙媛', 6),
#    ('曹世鎬', 6),
#    ('林義傑', 6),
#    ('孫一寧', 6),
#    ('索沙', 6),
#    ('艾思凱', 6),
#    ('賈永婕', 6),
#    ('王子維', 6),
#    ('哈莉瑪', 6),
#    ('九宮格', 6),
#    ('王定宇', 6),
#    ('蘇建榮', 6),
#    ('陳金鋒', 6),
#    ('柯震東', 6),
#    ('陳國昌', 6),
#    ('趙介佑', 6),
#    ('王敏淳', 6),
#    ('岬奈奈美', 6),
#    ('江惠民', 6),
#    ('邢泰釗', 6),
#    ('阿果', 6),
#    ('李昆澤', 6),
#    ('洪榮宏', 6),
#    ('薩拉', 6),
#    ('林鄭月娥', 6),
#    ('葉毓蘭', 6),
#    ('林思銘', 6),
#    ('波諾', 6),
#    ('Janet', 6),
#    ('陳美鳳', 6),
#    ('王毅', 6),
#    ('Brown', 6)]),
#  ('娛樂',
#   [('汪小菲', 235),
#    ('葛斯齊', 100),
#    ('張穎穎', 90),
#    ('納豆', 56),
#    ('戴普', 56),
#    ('大S', 39),
#    ('林襄', 37),
#    ('連千毅', 37),
#    ('張蘭', 36),
#    ('陳文茜', 33),
#    ('吳宗憲', 32),
#    ('楊穎軒', 31),
#    ('全智賢', 31),
#    ('長瀨昆妮', 30),
#    ('朴秉恩', 28),
#    ('陳妍希', 27),
#    ('強尼', 27),
#    ('黃曉明', 26),
#    ('張雅琴', 25),
#    ('阿雅', 24),
#    ('卡蜜兒', 24),
#    ('梁詠琪', 22),
#    ('徐睿知', 22),
#    ('波特王', 22),
#    ('許藍方', 21),
#    ('江宏傑', 21),
#    ('梓梓', 21),
#    ('林志玲', 21),
#    ('唐玲', 21),
#    ('陳曉', 20),
#    ('陳怡叡', 20),
#    ('奚夢瑤', 20),
#    ('阿Sa', 20),
#    ('王祖賢', 19),
#    ('詹鎰睿', 19),
#    ('婉婷', 19),
#    ('熊霓', 19),
#    ('馬東石', 18),
#    ('昆凌', 17),
#    ('謝忻', 17),
#    ('柯震東', 17),
#    ('吳姍儒', 17),
#    ('許雅鈞', 17),
#    ('阿嬌', 17),
#    ('黃琳', 16),
#    ('金剛', 16),
#    ('安柏赫德', 16),
#    ('安珀', 16),
#    ('福原愛', 15),
#    ('具俊曄', 15),
#    ('郭采潔', 15),
#    ('吳心緹', 15),
#    ('蔡淑臻', 14),
#    ('吳辰君', 14),
#    ('王心凌', 14),
#    ('徐恩', 13),
#    ('瀨昆妮', 13),
#    ('葉政勳', 13),
#    ('吳慷仁', 13),
#    ('沈玉琳', 13),
#    ('白雲', 13),
#    ('良山兄', 13),
#    ('阿翰', 13),
#    ('安柏', 13),
#    ('苗可麗', 13),
#    ('彭佳慧', 12),
#    ('陳沂', 12),
#    ('楊繡惠', 12),
#    ('林佳辰', 12),
#    ('朱琦郁', 12),
#    ('陳伊', 12),
#    ('釋小龍', 12),
#    ('秀智', 11),
#    ('徐佳瑩', 11),
#    ('楊冪', 11),
#    ('老蕭', 11),
#    ('楊銘威', 11),
#    ('安以軒', 11),
#    ('李優', 11),
#    ('廖麗芳', 11),
#    ('晏柔中', 11),
#    ('林莎', 10),
#    ('艾姬', 10),
#    ('簡嘉芸', 10),
#    ('張嘉哲', 10),
#    ('賴琳恩', 10),
#    ('黃心娣', 10),
#    ('迪士尼', 10),
#    ('何守正', 10),
#    ('艾宸', 10),
#    ('基尼', 10),
#    ('李妍憬', 10),
#    ('張凱娸', 10),
#    ('琳妲', 10),
#    ('張娜拉', 10),
#    ('羅志祥', 9),
#    ('李芷婷', 9),
#    ('楊謹華', 9),
#    ('蔣承縉', 9),
#    ('劉芒', 9),
#    ('曹西平', 9),
#    ('鍾怡婷', 9),
#    ('Toyz', 9),
#    ('徐熙媛', 9),
#    ('賈永婕', 9),
#    ('周曉涵', 9),
#    ('陳冠希', 9),
#    ('王俐人', 9),
#    ('謝薇安', 9),
#    ('黃子佼', 9),
#    ('何猷君', 9),
#    ('蔡允潔', 9),
#    ('胡宇威', 9),
#    ('徐乃麟', 9),
#    ('朴信惠', 9),
#    ('崔泰俊', 9),
#    ('利菁', 9),
#    ('潘綱大', 9),
#    ('歐漢聲', 9),
#    ('林采緹', 9),
#    ('伊藤舞雪', 9),
#    ('張郁婕', 8),
#    ('朴珍榮', 8),
#    ('楊丞琳', 8),
#    ('蔡鍾協', 8),
#    ('陳零九', 8),
#    ('003', 8),
#    ('王宥忻', 8),
#    ('紀卜心', 8),
#    ('蕭敬騰', 8),
#    ('藍星蕾', 8),
#    ('陳時中', 8),
#    ('伊能靜', 8),
#    ('Melody', 8),
#    ('孟耿如', 8),
#    ('陳珊妮', 8),
#    ('鍾楚紅', 8),
#    ('曾沛慈', 8),
#    ('謝和弦', 8),
#    ('黃大米', 8),
#    ('李準基', 8),
#    ('周興哲', 8),
#    ('潘瑋柏', 8),
#    ('宣云', 8),
#    ('孟若羽', 8),
#    ('金慧峻', 7),
#    ('阿翔', 7),
#    ('金高銀', 7),
#    ('蕭涵云', 7),
#    ('Joeman', 7),
#    ('趙麗穎', 7),
#    ('林青霞', 7),
#    ('宋仲基', 7),
#    ('韓瑜', 7),
#    ('張瀞云', 7),
#    ('張志浩', 7),
#    ('曾愷玹', 7),
#    ('王少偉', 7),
#    ('哈利', 7),
#    ('希希', 7),
#    ('鄭伊健', 7),
#    ('蕾拉', 7),
#    ('王偉忠', 7),
#    ('郭紹源', 7),
#    ('蔡阿嘎', 7),
#    ('金宇彬', 7),
#    ('李相燁', 7),
#    ('周子翔', 7),
#    ('巴比', 7),
#    ('徐玄振', 7),
#    ('穆希瓦拉', 7),
#    ('朱芯儀', 7),
#    ('吳夢夢', 7),
#    ('章子怡', 7),
#    ('賈靜雯', 7),
#    ('林依晨', 7),
#    ('樂天', 7),
#    ('吳卓源', 6),
#    ('張伍', 6),
#    ('莫允雯', 6),
#    ('王敏淳', 6),
#    ('岬奈奈美', 6),
#    ('洪榮宏', 6),
#    ('鄧福如', 6),
#    ('張香香', 6),
#    ('邱鋒澤', 6),
#    ('郭佩蓉', 6),
#    ('曾敬驊', 6),
#    ('李荷妮', 6),
#    ('邱宇辰', 6),
#    ('藍鈞天', 6),
#    ('熙媛', 6),
#    ('安希', 6),
#    ('陳雅雲', 6),
#    ('辛尤里', 6),
#    ('袁曼軒', 6),
#    ('李佳薇', 6),
#    ('史哲', 6),
#    ('伍佰', 6),
#    ('吳亦凡', 6)]),
#  ('新奇',
#   [('鍾怡婷', 42),
#    ('張志浩', 39),
#    ('詹鎰睿', 34),
#    ('高敏敏', 33),
#    ('李惠婷', 31),
#    ('潘毅', 27),
#    ('陳雅雲', 26),
#    ('賴禹妡', 24),
#    ('林楷傑', 23),
#    ('陳珮瑜', 22),
#    ('戴普', 18),
#    ('張嘉哲', 17),
#    ('波特王', 11),
#    ('王祖賢', 10),
#    ('李芷婷', 9),
#    ('郭佩蓉', 9),
#    ('劉芒', 9),
#    ('漢堡王', 8),
#    ('林襄', 8),
#    ('林聰明', 8),
#    ('003', 8),
#    ('迪士尼', 8),
#    ('中華', 8),
#    ('沈采穎', 8),
#    ('Joeman', 7),
#    ('陳冠希', 7),
#    ('希希', 7),
#    ('普里西拉', 7),
#    ('賈靜雯', 7),
#    ('強尼', 7),
#    ('鄧美慧', 6),
#    ('葛斯克', 6),
#    ('安希', 6),
#    ('辛尤里', 6),
#    ('吳鳳', 6),
#    ('周慧敏', 6),
#    ('陳鈺昕', 6),
#    ('黃韻文', 5),
#    ('麥當勞', 5),
#    ('周淑萍', 5),
#    ('周曉涵', 5),
#    ('紀卜心', 5),
#    ('安柏', 5),
#    ('千千', 5),
#    ('郭台銘', 4),
#    ('艾菲爾', 4),
#    ('王力宏', 4),
#    ('Andy', 4),
#    ('李多惠', 4),
#    ('川端步', 4),
#    ('林志玲', 4),
#    ('邱南昌', 4),
#    ('葉君璋', 4),
#    ('安柏赫德', 4),
#    ('江守山', 4),
#    ('陳伊', 4),
#    ('郭董', 4),
#    ('謝忻', 4),
#    ('楓浜', 4),
#    ('鍾文雄', 4),
#    ('查理', 3),
#    ('王宥鈞', 3),
#    ('Toyz', 3),
#    ('蘇一峰', 3),
#    ('安娜貝斯', 3),
#    ('山田一侍', 3),
#    ('艾宸', 3),
#    ('Bari', 3),
#    ('葉式', 3),
#    ('顏清標', 3),
#    ('夏子雯', 3),
#    ('白井良', 3),
#    ('鄭家純', 3),
#    ('馬吉', 3),
#    ('梁社漢', 3),
#    ('大谷', 2),
#    ('Apple', 2),
#    ('李智凱', 2),
#    ('劉怡里', 2),
#    ('林智群', 2),
#    ('宮崎駿', 2),
#    ('雷克萊爾頓', 2),
#    ('安娜貝絲', 2),
#    ('基尼', 2),
#    ('圤智雨', 2),
#    ('智雨', 2),
#    ('頂呱呱', 2),
#    ('翁梓華', 2),
#    ('林青霞', 2),
#    ('林莞茜', 2),
#    ('張哲生', 2),
#    ('林天佑', 2),
#    ('阿翰', 2),
#    ('黃高彬', 2),
#    ('陳之漢', 2),
#    ('葉總', 2),
#    ('詹姆士', 2),
#    ('安珀赫德', 2),
#    ('卡蜜兒瓦斯奎茲', 2),
#    ('凱特摩絲', 2),
#    ('A芷婷', 1),
#    ('阿美莉卡', 1),
#    ('霍奇爾戈梅茲', 1),
#    ('大谷翔平', 1),
#    ('林威辰', 1),
#    ('Overboard!', 1),
#    ('BrokenR', 1),
#    ('九面', 1),
#    ('百億', 1),
#    ('九妹', 1),
#    ('沙朗', 1),
#    ('力宏敢', 1),
#    ('羅智祥', 1),
#    ('王傑', 1),
#    ('陳珮', 1),
#    ('屈臣氏', 1),
#    ('雅雲', 1),
#    ('廖明毅', 1),
#    ('盧廣仲', 1),
#    ('林士峰', 1),
#    ('士峰', 1),
#    ('張嘉航', 1),
#    ('皮航', 1),
#    ('下垂', 1),
#    ('舒培', 1),
#    ('秦舒培', 1),
#    ('陳時中', 1),
#    ('PercyJackson&theOlympians', 1),
#    ('沃克斯科貝爾', 1),
#    ('羊男格羅佛', 1),
#    ('AryanSimhadri', 1),
#    ('LeahSavaJeffries', 1),
#    ('李建宗', 1),
#    ('周杰倫', 1),
#    ('軒姐宸妹', 1),
#    ('大麥克', 1),
#    ('祖克柏', 1),
#    ('林立', 1),
#    ('PO', 1),
#    ('林鳳營', 1),
#    ('楊穎軒', 1),
#    ('志浩', 1),
#    ('吳睿學', 1),
#    ('倪浩軒', 1),
#    ('白沙屯', 1),
#    ('林襄E', 1),
#    ('馬東石', 1),
#    ('張美', 1),
#    ('冨樫義博', 1),
#    ('蘇慧倫', 1),
#    ('丁國琳', 1),
#    ('陳美鳳', 1),
#    ('方岑', 1),
#    ('戈偉如', 1),
#    ('況明潔', 1),
#    ('陳子璇', 1),
#    ('蕭記', 1),
#    ('永味津', 1),
#    ('曾敬德', 1),
#    ('林楷傑花', 1),
#    ('呂淑珍', 1),
#    ('喬瑟夫', 1),
#    ('彭昱凱', 1),
#    ('木曜四', 1),
#    ('阿凱', 1),
#    ('張勵德', 1),
#    ('軒姐宸', 1),
#    ('董至成', 1),
#    ('白冰冰', 1),
#    ('林威助', 1),
#    ('林智勝', 1),
#    ('吳東融', 1),
#    ('威助', 1),
#    ('熊霓', 1),
#    ('楊登嵙', 1),
#    ('摩根特里梅因', 1),
#    ('范瑋琪', 1),
#    ('小孟', 1),
#    ('馬田', 1),
#    ('王心凌', 1),
#    ('NOWnews', 1),
#    ('星巴克', 1),
#    ('Disney', 1),
#    ('安珀', 1),
#    ('林卲穎', 1),
#    ('孫唯容', 1),
#    ('柯南', 1),
#    ('伊梓帆', 1),
#    ('鄭麗君', 1),
#    ('湯姆克魯斯', 1),
#    ('好市多', 1),
#    ('吉伯特', 1),
#    ('標太郎', 1)]),
#  ('生活',
#   [('柯文哲', 116),
#    ('陳時中', 85),
#    ('黃珊珊', 53),
#    ('鄭文燦', 48),
#    ('陳苾暐', 31),
#    ('蔡英文', 28),
#    ('盧秀燕', 27),
#    ('潘毅', 20),
#    ('陳雅雲', 19),
#    ('鍾怡婷', 19),
#    ('張志浩', 17),
#    ('倪浩軒', 16),
#    ('林莞茜', 15),
#    ('羅一鈞', 14),
#    ('侯友宜', 14),
#    ('李惠婷', 13),
#    ('陳沂', 12),
#    ('劉和然', 12),
#    ('謝金燕', 11),
#    ('辜仲諒', 11),
#    ('土星', 10),
#    ('賴禹妡', 10),
#    ('蔡壁如', 10),
#    ('陳其邁', 10),
#    ('吳佩芸', 10),
#    ('王祖賢', 10),
#    ('林穎孟', 9),
#    ('賴心雅', 9),
#    ('曾梓展', 8),
#    ('莫德納', 8),
#    ('陳文政', 8),
#    ('鍾男', 8),
#    ('陳亮達', 8),
#    ('王婉諭', 8),
#    ('孫唯容', 7),
#    ('詹鎰睿', 7),
#    ('林奕華', 7),
#    ('蘿莉塔', 7),
#    ('葉毓蘭', 7),
#    ('連千毅', 7),
#    ('黃姿華', 7),
#    ('鄧美慧', 6),
#    ('蔣萬安', 6),
#    ('李沐晴', 6),
#    ('黃捷', 6),
#    ('陳正傑', 6),
#    ('莊人祥', 6),
#    ('吳鳳', 6),
#    ('徐永明', 6),
#    ('楊逸鴻', 6),
#    ('漢堡王', 5),
#    ('陳婕翎', 5),
#    ('陳珮瑜', 5),
#    ('九宮格', 5),
#    ('林秉煜', 5),
#    ('葉曜彰', 5),
#    ('蔡政呈', 5),
#    ('郭台銘', 5),
#    ('陳志金', 5),
#    ('亮達', 5),
#    ('林右昌', 5),
#    ('劉緯澤', 4),
#    ('陳建仁', 4),
#    ('艾菲爾', 4),
#    ('林盈君', 4),
#    ('葉一堅', 4),
#    ('張茗喧', 4),
#    ('周淑萍', 4),
#    ('蔡炳坤', 4),
#    ('袁曼軒', 4),
#    ('呂秋遠', 4),
#    ('陳文省', 4),
#    ('林男', 4),
#    ('施信如', 4),
#    ('李建葦', 4),
#    ('黃錦儀', 4),
#    ('郭董', 4),
#    ('鍾文雄', 4),
#    ('伍婉華', 3),
#    ('郭斐然', 3),
#    ('周永鴻', 3),
#    ('恩恩', 3),
#    ('邱星澤', 3),
#    ('梁文傑', 3),
#    ('蔡明堂', 3),
#    ('江肇國', 3),
#    ('王立任', 3),
#    ('蔡適應', 3),
#    ('劉宇其', 3),
#    ('陳文茜', 3),
#    ('呂玉玲', 3),
#    ('郭彥均', 3),
#    ('蘇貞昌', 3),
#    ('王美玉', 3),
#    ('夏子雯', 3),
#    ('林清麗', 3),
#    ('令狐榮達', 3),
#    ('沈采穎', 3),
#    ('王閔生', 3),
#    ('汪志冰', 3),
#    ('白井良', 3),
#    ('曾燦金', 3),
#    ('侯漢廷', 3),
#    ('梁社漢', 3),
#    ('王心凌', 3),
#    ('葉元之', 2),
#    ('陳正偉', 2),
#    ('歐貝爾', 2),
#    ('Apple', 2),
#    ('劉金秀', 2),
#    ('林奏延', 2),
#    ('吳世瑋', 2),
#    ('麥當勞', 2),
#    ('張旭嵐', 2),
#    ('恩恩爸', 2),
#    ('李宇松', 2),
#    ('曾敬德', 2),
#    ('媽祖', 2),
#    ('劉怡里', 2),
#    ('陳政偉', 2),
#    ('邱臣遠', 2),
#    ('劉沛滕', 2),
#    ('郭紹源', 2),
#    ('宮崎駿', 2),
#    ('星巴克', 2),
#    ('陳椒華', 2),
#    ('張男', 2),
#    ('陳時中今', 2),
#    ('徐永年', 2),
#    ('李家興', 2),
#    ('周玉琴', 2),
#    ('邱世源', 2),
#    ('楊佳明', 2),
#    ('陳智菡', 2),
#    ('李錫璋', 2),
#    ('游淑慧', 2),
#    ('張語涵', 2),
#    ('李大維', 2),
#    ('林淑媛', 2),
#    ('翁梓華', 2),
#    ('麥建方', 2),
#    ('輝瑞', 2),
#    ('張哲生', 2),
#    ('戴錫欽', 2),
#    ('吳泓逸', 2),
#    ('莫羽靜', 2),
#    ('王幼玲', 2),
#    ('林麗蟬', 2),
#    ('邱奕勝', 2),
#    ('張善政', 2),
#    ('柯南', 2),
#    ('李孟軒', 2),
#    ('張蔭泉', 2),
#    ('詹姆士', 2),
#    ('潘婷', 2),
#    ('小孟', 2),
#    ('郭佩蓉', 2),
#    ('戴普', 2),
#    ('劉男', 1),
#    ('高登', 1),
#    ('蕭煇俊', 1),
#    ('金牛', 1),
#    ('水瓶', 1),
#    ('李嘉誠', 1),
#    ('比爾蓋茲', 1),
#    ('王永慶', 1),
#    ('露恰露恰', 1),
#    ('林威辰', 1),
#    ('Overboard!', 1),
#    ('BrokenR', 1),
#    ('楊文', 1),
#    ('楊文科', 1),
#    ('潘杰賢', 1),
#    ('沈佩瑤', 1),
#    ('蔡增光', 1),
#    ('張菱育', 1),
#    ('廖君凰', 1),
#    ('劉海星', 1),
#    ('游忠義', 1),
#    ('李兆立', 1),
#    ('錢震宇', 1),
#    ('葉男', 1),
#    ('郭羿岑', 1),
#    ('屈臣氏', 1),
#    ('黃國瑋', 1),
#    ('林智堅', 1),
#    ('蔡政', 1),
#    ('涂維政', 1),
#    ('蔡其昌', 1),
#    ('苗博雅', 1),
#    ('李昆晏', 1),
#    ('陳潤秋', 1),
#    ('賴香伶', 1),
#    ('張其碌', 1),
#    ('高虹安', 1),
#    ('衛教', 1),
#    ('張宏育', 1),
#    ('吳東昇', 1),
#    ('潘炤穎', 1),
#    ('伊利亞', 1)]),
#  ('財經',
#   [('王雲怡', 55),
#    ('林伯修', 45),
#    ('鄧振中', 43),
#    ('王守誠', 30),
#    ('彭郁文', 29),
#    ('王美花', 27),
#    ('施月英', 27),
#    ('林楷傑', 23),
#    ('吳斐竣', 21),
#    ('黃昭展', 21),
#    ('曾敬德', 19),
#    ('楊金龍', 19),
#    ('趙家緯', 18),
#    ('蔡祈岩', 15),
#    ('劉揚偉', 15),
#    ('邱達生', 15),
#    ('吳敏求', 14),
#    ('曾文生', 11),
#    ('陳寶郎', 11),
#    ('王國材', 10),
#    ('黃天牧', 9),
#    ('周恒豪', 9),
#    ('蔡卉荀', 9),
#    ('畢昂奇', 9),
#    ('劉德音', 8),
#    ('榮鴻慶', 8),
#    ('鮑爾', 7),
#    ('許勝雄', 7),
#    ('李其展', 6),
#    ('徐佳馨', 6),
#    ('謝晨彥', 6),
#    ('林之晨', 6),
#    ('龔明鑫', 6),
#    ('林建涵', 6),
#    ('施振榮', 6),
#    ('莊博貴', 6),
#    ('李育家', 6),
#    ('王伯元', 5),
#    ('范卓雲', 5),
#    ('林孝信', 5),
#    ('蔡明介', 5),
#    ('沈軾榮', 4),
#    ('高嘉瑜', 4),
#    ('白易弘', 4),
#    ('王煒', 4),
#    ('林恩平', 4),
#    ('張國華', 4),
#    ('廖祥安', 4),
#    ('柯宏安', 4),
#    ('畢務潔', 4),
#    ('丁紋甄', 4),
#    ('黃舒衛', 4),
#    ('張旭嵐', 4),
#    ('許永明', 4),
#    ('蘇聖峰', 4),
#    ('江怡慧', 4),
#    ('葉獻文', 4),
#    ('吳哲宇', 4),
#    ('林維俊', 4),
#    ('張玉煇', 4),
#    ('戴琪', 4),
#    ('三浦雄治', 4),
#    ('柯文哲', 3),
#    ('陳尹柔', 3),
#    ('吳文永', 3),
#    ('翁維薇', 3),
#    ('鄭貞茂', 3),
#    ('陳基寶', 3),
#    ('沈建宏', 3),
#    ('賴清德', 3),
#    ('曹世綸', 3),
#    ('翁毓傑', 2),
#    ('李怡勳', 2),
#    ('劉人豪', 2),
#    ('侯立洋', 2),
#    ('張嘉哲', 2),
#    ('陳世卿', 2),
#    ('黃志宜', 2),
#    ('張國明', 2),
#    ('劉信', 2),
#    ('周彥廷', 2),
#    ('施瓊華', 2),
#    ('吳祝春', 2),
#    ('莊人祥', 2),
#    ('梅斯特', 2),
#    ('戴維斯', 2),
#    ('吳旻潔', 2),
#    ('郎美囡', 2),
#    ('林天佑', 2),
#    ('李紀珠', 2),
#    ('李順欽', 2),
#    ('謝文彬', 2),
#    ('張傳章', 2),
#    ('簡錦漢', 2),
#    ('陳馨蕙', 2),
#    ('劉文雄', 2),
#    ('吳東明', 2),
#    ('洪士琪', 2),
#    ('林伯翰', 2),
#    ('吳昕達', 2),
#    ('吳東進', 2),
#    ('許澎', 2),
#    ('朱立明', 2),
#    ('張志杰', 2),
#    ('NabilaPopal', 2),
#    ('CNN', 2),
#    ('馬克祖克柏', 2),
#    ('李秉穎', 2),
#    ('葉菀婷', 1),
#    ('劉伊菡', 1),
#    ('江靖婷', 1),
#    ('嚴蘭欣', 1),
#    ('廖仁義', 1),
#    ('梁永斐', 1),
#    ('陳慶鴻', 1),
#    ('趙國智', 1),
#    ('王品', 1),
#    ('鍾文雄', 1),
#    ('陳慧蓉', 1),
#    ('林斌', 1),
#    ('林耀英', 1),
#    ('陳俊明', 1),
#    ('黃有執', 1),
#    ('林恩舟', 1),
#    ('魏哲家', 1),
#    ('凱基', 1),
#    ('周玉蔻', 1),
#    ('黃珊珊', 1),
#    ('榮海運', 1),
#    ('張國煒', 1),
#    ('長榮', 1),
#    ('林俊秀', 1),
#    ('楊金', 1),
#    ('黃天牧明', 1),
#    ('蔡英文', 1),
#    ('肯德基', 1),
#    ('徐睿承', 1),
#    ('魏啓林', 1),
#    ('王耀庭', 1),
#    ('林昌育', 1),
#    ('林楷傑花', 1),
#    ('呂淑珍', 1),
#    ('藍怡婷', 1),
#    ('嵩壽百歲', 1),
#    ('陳冲', 1),
#    ('潘思亮', 1),
#    ('謝金河', 1),
#    ('陳立恒', 1),
#    ('方振仁', 1),
#    ('陳薇仲', 1),
#    ('張淵翔', 1),
#    ('周怡君', 1),
#    ('蔡明', 1),
#    ('蔡力行', 1),
#    ('吳敏求傳', 1),
#    ('沈榮津', 1),
#    ('陳良基', 1),
#    ('張善政', 1),
#    ('護國神山', 1),
#    ('米飛', 1),
#    ('吳敏', 1),
#    ('Money101', 1)]),
#  ('專題',
#   [('Jacky', 564),
#    ('吳夢夢', 417),
#    ('鄧佳華', 276),
#    ('孟若羽', 237),
#    ('阿嘉', 228),
#    ('Morgan', 174),
#    ('圤智雨', 126),
#    ('熊吉', 120),
#    ('Vicky', 81),
#    ('楊丞琳', 66),
#    ('YoungJohnny', 63),
#    ('Rona', 54),
#    ('劉昱均', 36),
#    ('一劍浣春秋', 36),
#    ('金寶娜', 36),
#    ('小齊', 27),
#    ('張烽益', 24),
#    ('智雨', 24),
#    ('林育品', 21),
#    ('雪碧', 21),
#    ('方祺媛', 21),
#    ('阿澎', 21),
#    ('阿喜', 18),
#    ('劉心語', 18),
#    ('蔡男', 12),
#    ('女優苡若', 9),
#    ('Mogran', 9),
#    ('青青', 9),
#    ('浣春秋', 9),
#    ('acky', 9),
#    ('JAcky', 9),
#    ('吉林', 9),
#    ('Jilin', 9),
#    ('一劍', 9),
#    ('夢若羽', 9),
#    ('苡若', 9),
#    ('夢夢', 9),
#    ('ohnny', 9),
#    ('Youny', 9),
#    ('Johnny', 9),
#    ('鄭家純', 6),
#    ('金基德', 3),
#    ('三上悠亞', 3),
#    ('阿賢', 3)]),
#  ('全球',
#   [('拜登', 142),
#    ('馬可仕', 85),
#    ('蒲亭', 74),
#    ('杜特蒂', 53),
#    ('王毅', 48),
#    ('薩拉', 47),
#    ('澤倫斯基', 40),
#    ('李家超', 30),
#    ('伊美黛', 29),
#    ('馬克宏', 26),
#    ('岸田', 24),
#    ('卡蜜兒', 24),
#    ('馬斯克', 23),
#    ('鄒幸彤', 23),
#    ('戴普', 21),
#    ('習近平', 20),
#    ('岸田文雄', 18),
#    ('布林肯', 18),
#    ('川普', 18),
#    ('希特勒', 17),
#    ('普萊斯', 17),
#    ('艾班尼斯', 17),
#    ('尚皮耶', 16),
#    ('庫克', 16),
#    ('黃英賢', 16),
#    ('岩室純子', 16),
#    ('羅貝多', 15),
#    ('尹錫悅', 14),
#    ('林鄭月娥', 14),
#    ('安珀', 14),
#    ('普丁', 13),
#    ('巴舍萊', 13),
#    ('裴卓', 13),
#    ('艾爾段', 12),
#    ('李克強', 12),
#    ('吳釗燮', 12),
#    ('田文雄', 11),
#    ('李明哲', 11),
#    ('莫里森', 11),
#    ('齋藤', 11),
#    ('宮野裕史', 11),
#    ('林芳正', 10),
#    ('希希馬林', 10),
#    ('耶南德茲', 10),
#    ('桑柏格', 10),
#    ('張世先', 10),
#    ('魯拉', 9),
#    ('文在寅', 9),
#    ('蕭茲', 9),
#    ('孫春蘭', 9),
#    ('杜登', 9),
#    ('張先玲', 9),
#    ('湊伸治', 9),
#    ('米歇爾', 8),
#    ('馬修麥康納', 8),
#    ('卡梅辛', 8),
#    ('特拉斯', 8),
#    ('杜魯道', 8),
#    ('祖克柏', 8),
#    ('波索納洛', 8),
#    ('葉倫', 8),
#    ('拉夫羅夫', 8),
#    ('古提瑞茲', 8),
#    ('廖國勛', 8),
#    ('切列霍夫', 8),
#    ('詩妮娜', 7),
#    ('卡巴耶娃', 7),
#    ('哈紹吉', 7),
#    ('蓋戴', 7),
#    ('伊麗莎白二世', 7),
#    ('侯友宜', 7),
#    ('譚德塞', 7),
#    ('小馬可仕', 7),
#    ('傅爾頓', 7),
#    ('王文岳', 6),
#    ('佛奇', 6),
#    ('岸信夫', 6),
#    ('勞斯', 6),
#    ('卡卡巴維', 6),
#    ('波諾', 6),
#    ('朱拉蓬', 6),
#    ('陳日君', 6),
#    ('金正恩', 6),
#    ('艾奎諾', 6),
#    ('葛來儀', 6),
#    ('阿爾登', 6),
#    ('沈大偉', 6),
#    ('澤林斯卡', 6),
#    ('阿瑞唐多', 6),
#    ('泰王', 5),
#    ('莎琪', 5),
#    ('黃創夏', 5),
#    ('楊潔篪', 5),
#    ('陳文玲', 5),
#    ('莫德納', 5),
#    ('黑田', 5),
#    ('羅德里格斯', 5),
#    ('馬爾帕斯', 5),
#    ('達志', 5),
#    ('海恩斯', 5),
#    ('松野博一', 5),
#    ('朱鳳蓮', 5),
#    ('佐爾金', 5),
#    ('麥奎斯頓', 5),
#    ('樂玉成', 5),
#    ('王小龍', 5),
#    ('畢昂奇', 5),
#    ('哈爾科夫', 5),
#    ('雪蔓', 5),
#    ('賽爾西', 5),
#    ('強尼', 5),
#    ('孫國祥', 4),
#    ('劉蕭翔', 4),
#    ('蔡英文', 4),
#    ('李登輝', 4),
#    ('鈴木隼人', 4),
#    ('裴洛西', 4),
#    ('蕭徐行', 4),
#    ('苟晶', 4),
#    ('張文宏', 4),
#    ('杜魯', 4),
#    ('Lazada', 4),
#    ('鄧炳強', 4),
#    ('摩依士', 4),
#    ('查爾斯', 4),
#    ('查猜', 4),
#    ('莫迪', 4),
#    ('蒙娜麗莎', 4),
#    ('劉海星', 4),
#    ('吉歐阿納', 4),
#    ('庫列巴', 4),
#    ('克里契科', 4),
#    ('齊德茲茨', 4),
#    ('魯塞夫', 4),
#    ('阿瓦德', 4),
#    ('順子', 4),
#    ('卡蜜拉', 4),
#    ('強生', 3),
#    ('柯比', 3),
#    ('鈴木憲和', 3),
#    ('歐巴馬', 3),
#    ('烏克蘭', 3),
#    ('韋列舒克', 3),
#    ('沙爾曼', 3),
#    ('馬立波', 3),
#    ('王乙康', 3),
#    ('桑迪亞加·烏諾', 3),
#    ('尤瓦爾迪', 3),
#    ('梁國樑', 3),
#    ('休布瑞吉', 3),
#    ('麥葛瑞格', 3),
#    ('阿雲達', 3),
#    ('德拉吉', 3),
#    ('費勒', 3),
#    ('阮光同', 3),
#    ('安妮瓦', 3),
#    ('李顯龍', 3),
#    ('帕拉修斯', 3),
#    ('梅森', 3),
#    ('駱惠寧', 3),
#    ('林穎佑', 3),
#    ('伊斯特布洛克', 3),
#    ('凱默邁爾', 3),
#    ('馬林', 3),
#    ('尼尼斯托', 3),
#    ('威爾遜', 3),
#    ('高德曼', 3),
#    ('湯瑪斯-葛林斐德', 3),
#    ('康貝爾', 3),
#    ('星巴克', 3),
#    ('佩柏迪', 3),
#    ('JoeBiden', 3),
#    ('施毅', 3),
#    ('威克瑞米辛赫', 3),
#    ('米娜', 3),
#    ('Win', 3),
#    ('張志賢', 3),
#    ('李鴻忠', 3),
#    ('蘭馬克', 3),
#    ('賈西亞', 3),
#    ('王楠', 3),
#    ('宋濤', 3),
#    ('齋藤真由美', 3),
#    ('韓德洙', 3),
#    ('賈哈', 3),
#    ('史騰伯格', 3),
#    ('侯芷明', 3),
#    ('古田順子', 3),
#    ('柏頓', 3),
#    ('蘇堤達', 2),
#    ('鈴木憲', 2),
#    ('NancyPelosi', 2),
#    ('波多利雅科', 2),
#    ('艾爾', 2),
#    ('古特瑞斯', 2),
#    ('阿格拉瓦', 2),
#    ('涅班濟亞', 2),
#    ('孫曉雅', 2),
#    ('蓬佩奧', 2),
#    ('許家印', 2)]),
#  ('運動',
#   [('塞爾提克', 70),
#    ('大谷', 45),
#    ('桑尼', 39),
#    ('大谷翔平', 37),
#    ('胡瓏貿', 33),
#    ('呂政儒', 32),
#    ('王建民', 28),
#    ('王勝偉', 28),
#    ('布銳克曼', 28),
#    ('張育成', 27),
#    ('芮恩', 26),
#    ('Curry', 25),
#    ('塔克', 25),
#    ('Green', 22),
#    ('葉丙成', 22),
#    ('林益全', 21),
#    ('何喬登', 20),
#    ('StephenCurry', 18),
#    ('江少慶', 18),
#    ('呂忠翰', 17),
#    ('柯瑞', 17),
#    ('黃忠義', 17),
#    ('庫薩斯', 17),
#    ('林智勝', 16),
#    ('汪小菲', 16),
#    ('Nadal', 16),
#    ('威迪茲', 16),
#    ('戴資穎', 15),
#    ('詹皇', 15),
#    ('Poole', 15),
#    ('郭泓志', 15),
#    ('曾文鼎', 14),
#    ('灰熊', 14),
#    ('蔣淯安', 14),
#    ('柯文哲', 14),
#    ('李芳', 14),
#    ('陽岱鋼', 13),
#    ('SteveKerr', 13),
#    ('蔡其昌', 13),
#    ('Harden', 13),
#    ('Morant', 13),
#    ('陳仕朋', 13),
#    ('葉君璋', 13),
#    ('林華韋', 13),
#    ('王柏融', 12),
#    ('Kerr', 12),
#    ('陳鴻文', 12),
#    ('太陽', 12),
#    ('錢薇娟', 12),
#    ('廖麗芳', 12),
#    ('阿翰', 12),
#    ('樂天', 11),
#    ('辰羚', 11),
#    ('Butler', 11),
#    ('劉錚', 11),
#    ('吳念庭', 11),
#    ('海神', 11),
#    ('楊敬敏', 10),
#    ('蔣智賢', 10),
#    ('陳俊秀', 10),
#    ('張宗憲', 10),
#    ('林丞軒', 10),
#    ('郭婞淳', 10),
#    ('山口茜', 10),
#    ('高飛', 10),
#    ('威廉斯', 10),
#    ('范國宸', 10),
#    ('林承飛', 9),
#    ('吳俊偉', 9),
#    ('恩恩', 9),
#    ('Brown', 9),
#    ('Smart', 9),
#    ('張穎穎', 9),
#    ('葉政勳', 9),
#    ('艾倫', 9),
#    ('馬鋼', 9),
#    ('林志傑', 8),
#    ('阿果', 8),
#    ('林琨笙', 8),
#    ('陳統恩', 8),
#    ('高雄', 8),
#    ('Looney', 8),
#    ('蔡明里', 8),
#    ('劉東洋', 8),
#    ('黃紹熙', 8),
#    ('宋家豪', 8),
#    ('Gobert', 8),
#    ('許樂', 8),
#    ('賴清德', 8),
#    ('陳靖寰', 8),
#    ('陳亮達', 8),
#    ('張誌家', 8),
#    ('陳金鋒', 7),
#    ('索沙', 7),
#    ('貝比魯斯', 7),
#    ('陳時中', 7),
#    ('朱育賢', 7),
#    ('申皓瑋', 7),
#    ('張閔勛', 7),
#    ('林明憲', 7),
#    ('Payton', 7),
#    ('陳其邁', 7),
#    ('張正偉', 7),
#    ('JoeMaddon', 7),
#    ('丘昌榮', 7),
#    ('希希', 7),
#    ('周思齊', 7),
#    ('艾思凱', 7),
#    ('林秉聖', 7),
#    ('喬伊斯', 7),
#    ('林昆漢', 7),
#    ('劉基鴻', 7),
#    ('高國豪', 6),
#    ('許晉哲', 6),
#    ('郭俊麟', 6),
#    ('Brooks', 6),
#    ('黃韋盛', 6),
#    ('霸帝士', 6),
#    ('葉竹軒', 6),
#    ('怡庭', 6),
#    ('JaMorant', 6),
#    ('Zverev', 6),
#    ('張進德', 6),
#    ("O'Neal", 6),
#    ('熊霓', 6),
#    ('郭鈺婷', 6),
#    ('Buss', 6),
#    ('辛巴', 6),
#    ('陳雨菲', 6),
#    ('蘇翊傑', 6),
#    ('于煥亞', 6),
#    ('姆巴佩', 6),
#    ('英熊', 6),
#    ('沈嘉玟', 6),
#    ('王威晨', 6),
#    ('Doncic', 6),
#    ('蘇建文', 6),
#    ('戴培峰', 5),
#    ('林書緯', 5),
#    ('小戴', 5),
#    ('DraymondGreen', 5),
#    ('哈姆', 5),
#    ('謝裕民', 5),
#    ('蔡齊哲', 5),
#    ('富邦', 5),
#    ('林振賢', 5),
#    ('鄭達鴻', 5),
#    ('NBA', 5),
#    ('JordanPoole', 5),
#    ('方昶詠', 5),
#    ('賴Ki', 5),
#    ('Alcaraz', 5),
#    ('Jenkins', 5),
#    ('孟超', 5),
#    ('陳子豪', 5),
#    ('林立', 5),
#    ('楊志豪', 5),
#    ('林襄', 5),
#    ('樂天桃猿', 5),
#    ('林子偉', 5),
#    ('卡米諾斯', 5),
#    ('蘇奕晉', 5),
#    ('李逸驊', 5),
#    ('亮達', 5),
#    ('侯尊堯', 5),
#    ('朱雲豪', 5),
#    ('曾俊欣', 5),
#    ('金州', 5),
#    ('Tsonga', 5),
#    ('范米特', 5),
#    ('林威助', 5),
#    ('鄭志龍', 4),
#    ('羅賓森', 4),
#    ('曾豪駒', 4),
#    ('Clarke', 4),
#    ('林家文', 4),
#    ('陳盈駿', 4),
#    ('張旖旂', 4),
#    ('賴禹妡', 4),
#    ('塞爾蒂克', 4),
#    ('炎亞綸', 4),
#    ('布依德', 4),
#    ('KevonLooney', 4),
#    ('MarcusSmart', 4),
#    ('郭泰源', 4),
#    ('查理', 4),
#    ('Embiid', 4),
#    ('Jor', 4),
#    ('曼菲斯', 4),
#    ('O’Neal', 4),
#    ('林恩宇', 4),
#    ('王顗翔', 4),
#    ('張奕', 4),
#    ('吳永仁', 4),
#    ('吳家駿', 4),
#    ('Kevin', 4),
#    ('張智峰', 4),
#    ('劉嘉發', 4),
#    ('德古拉', 4),
#    ('趙璟榮', 4)]),
#  ('全部',
#   [('Jacky', 564),
#    ('柯文哲', 471),
#    ('陳時中', 430),
#    ('吳夢夢', 424),
#    ('汪小菲', 389),
#    ('蔡英文', 280),
#    ('鄧佳華', 276),
#    ('孟若羽', 245),
#    ('阿嘉', 230),
#    ('侯友宜', 217),
#    ('拜登', 216),
#    ('馬可仕', 214),
#    ('張善政', 200),
#    ('黃珊珊', 192),
#    ('葛斯齊', 185),
#    ('朱立倫', 181),
#    ('Morgan', 174),
#    ('蒲亭', 158),
#    ('羅智強', 154),
#    ('蘇貞昌', 145),
#    ('圤智雨', 137),
#    ('戴普', 128),
#    ('張穎穎', 120),
#    ('熊吉', 120),
#    ('蔣萬安', 113),
#    ('盧秀燕', 101),
#    ('鄭文燦', 93),
#    ('林佳龍', 92),
#    ('澤倫斯基', 85),
#    ('納豆', 85),
#    ('陳苾暐', 81),
#    ('伊美黛', 81),
#    ('張志浩', 81),
#    ('Vicky', 81),
#    ('卡蜜兒', 77),
#    ('詹鎰睿', 77),
#    ('連千毅', 76),
#    ('楊丞琳', 74),
#    ('馬英九', 73),
#    ('鍾怡婷', 72),
#    ('陳雅雲', 71),
#    ('塞爾提克', 70),
#    ('杜特蒂', 66),
#    ('YoungJohnny', 63),
#    ('習近平', 62),
#    ('吳釗燮', 62),
#    ('王婉諭', 62),
#    ('郭彥均', 62),
#    ('王毅', 62),
#    ('李惠婷', 62),
#    ('大S', 61),
#    ('林智堅', 60),
#    ('潘毅', 59),
#    ('馬克宏', 56),
#    ('張蘭', 56),
#    ('鄧振中', 56),
#    ('林志玲', 55),
#    ('王雲怡', 55),
#    ('薩拉', 54),
#    ('Rona', 54),
#    ('王祖賢', 53),
#    ('林襄', 53),
#    ('余天', 52),
#    ('桑尼', 52),
#    ('林莞茜', 49),
#    ('高嘉瑜', 48),
#    ('呂忠翰', 48),
#    ('岸田文雄', 47),
#    ('于北辰', 47),
#    ('賴禹妡', 47),
#    ('大谷', 47),
#    ('李家超', 46),
#    ('鄒幸彤', 46),
#    ('林楷傑', 46),
#    ('強尼', 45),
#    ('安珀', 45),
#    ('李鴻鈞', 45),
#    ('胡瓏貿', 45),
#    ('林伯修', 45),
#    ('沈慧虹', 44),
#    ('梓梓', 44),
#    ('楊穎軒', 44),
#    ('吳宗憲', 43),
#    ('大谷翔平', 43),
#    ('孫唯容', 41),
#    ('顏若芳', 41),
#    ('長瀨昆妮', 41),
#    ('鄭運鵬', 40),
#    ('達克沃絲', 40),
#    ('張嘉哲', 40),
#    ('波特王', 40),
#    ('陳珮瑜', 40),
#    ('林鶴明', 39),
#    ('恩恩', 38),
#    ('艾班尼斯', 38),
#    ('何博文', 38),
#    ('張惇涵', 38),
#    ('一劍浣春秋', 38),
#    ('岸田', 37),
#    ('王國材', 37),
#    ('江宏傑', 37),
#    ('王勝偉', 37),
#    ('高敏敏', 37),
#    ('陳文茜', 37),
#    ('蘇紫雲', 36),
#    ('樂天', 36),
#    ('劉昱均', 36),
#    ('金寶娜', 36),
#    ('陳其邁', 34),
#    ('林奕華', 34),
#    ('金正恩', 33),
#    ('莊人祥', 33),
#    ('張國華', 33),
#    ('郭婞淳', 33),
#    ('呂政儒', 33),
#    ('塔克', 33),
#    ('布銳克曼', 33),
#    ('羅一鈞', 32),
#    ('王心凌', 32),
#    ('全智賢', 32),
#    ('川普', 31),
#    ('智雨', 31),
#    ('阿翰', 31),
#    ('尹錫悅', 30),
#    ('蔡其昌', 30),
#    ('王建民', 30),
#    ('王守誠', 30),
#    ('馬斯克', 29),
#    ('林佳辰', 29),
#    ('林益全', 29),
#    ('王美花', 29),
#    ('彭郁文', 29),
#    ('艾爾段', 28),
#    ('曾敬德', 28),
#    ('陳妍希', 28),
#    ('吳姍儒', 28),
#    ('朴秉恩', 28),
#    ('張烽益', 27),
#    ('高登', 27),
#    ('江少慶', 27),
#    ('昆凌', 27),
#    ('黃曉明', 27),
#    ('張雅琴', 27),
#    ('Curry', 27),
#    ('熊霓', 27),
#    ('施月英', 27),
#    ('小齊', 27),
#    ('張育成', 27),
#    ('陳偉華', 26),
#    ('莫里森', 26),
#    ('劉和然', 26),
#    ('邱奕勝', 26),
#    ('呂玉玲', 26),
#    ('楊金龍', 26),
#    ('芮恩', 26),
#    ('郭台銘', 25),
#    ('羅貝多', 25),
#    ('倪浩軒', 25),
#    ('江啟臣', 25),
#    ('葉政勳', 25),
#    ('吳鳳', 25),
#    ('廖麗芳', 25),
#    ('易俊宏', 24),
#    ('柯拉蓉', 24),
#    ('布林肯', 24),
#    ('陳亮達', 24),
#    ('許雅鈞', 24),
#    ('黃英賢', 24),
#    ('潘文忠', 24),
#    ('具俊曄', 24),
#    ('瀨昆妮', 24),
#    ('郭佩蓉', 24),
#    ('陳沂', 24),
#    ('阿雅', 24),
#    ('林右昌', 23),
#    ('李永得', 23),
#    ('黃亭偉', 23),
#    ('賴清德', 23),
#    ('莫德納', 23),
#    ('曾梓展', 23),
#    ('威迪茲', 23),
#    ('柯震東', 23),
#    ('葉君璋', 23),
#    ('范米特', 23),
#    ('Green', 23),
#    ('田文雄', 22),
#    ('柯建銘', 22),
#    ('文在寅', 22),
#    ('希特勒', 22),
#    ('陳隆翔', 22),
#    ('郭俊麟', 22),
#    ('林依晨', 22),
#    ('艾宸', 22),
#    ('太陽', 22),
#    ('梁詠琪', 22),
#    ('徐睿知', 22),
#    ('葉丙成', 22),
#    ('魯明哲', 21),
#    ('蕭茲', 21),
#    ('林鄭月娥', 21)])]

# %%
df_hotPersons = pd.DataFrame(hotPersons, columns = ['category','top_keys'])

# %%
df_hotPersons
# Out:
#    category                                           top_keys
# 0        焦點  [(陳時中, 113), (柯文哲, 83), (蔡英文, 81), (汪小菲, 64), ...
# 1        要聞  [(柯文哲, 216), (侯友宜, 150), (陳時中, 126), (蔡英文, 119...
# 2        即時  [(陳時中, 90), (汪小菲, 74), (馬可仕, 67), (葛斯齊, 44), (...
# 3        娛樂  [(汪小菲, 235), (葛斯齊, 100), (張穎穎, 90), (納豆, 56), ...
# 4        新奇  [(鍾怡婷, 42), (張志浩, 39), (詹鎰睿, 34), (高敏敏, 33), (...
# 5        生活  [(柯文哲, 116), (陳時中, 85), (黃珊珊, 53), (鄭文燦, 48), ...
# 6        財經  [(王雲怡, 55), (林伯修, 45), (鄧振中, 43), (王守誠, 30), (...
# 7        專題  [(Jacky, 564), (吳夢夢, 417), (鄧佳華, 276), (孟若羽, 2...
# 8        全球  [(拜登, 142), (馬可仕, 85), (蒲亭, 74), (杜特蒂, 53), (王...
# 9        運動  [(塞爾提克, 70), (大谷, 45), (桑尼, 39), (大谷翔平, 37), (...
# 10       全部  [(Jacky, 564), (柯文哲, 471), (陳時中, 430), (吳夢夢, 4...

# %%
df_hotPersons.to_csv('now_news_top_person_by_category_via_ner.csv', sep='|', index=False)

# %% [markdown]
# # Count top-200 hot keywords for each NER name

# %%
import pandas as pd

# %%
df = pd.read_csv('now_news_preprocessed.csv',sep='|')

# %%
df.head(1)
# Out:
#                  item_id        date category                       title  \
# 0  column/_20220505_1001  2022-05-05       焦點  配發率32%！富邦金每股配4元股利、現金股利歷史新高
#
#                                              content  sentiment  \
# 0  富邦金控今（5）日公告，董事會決議通過擬配發普通股每股現金股利3.5元及股票股利0.5元，合...        0.0
#
#                                              summary  \
# 0  ['富邦金這次同時配發股票股利每股0.5元', '包含富邦人壽上繳155.78億元、台北富邦...
#
#                                         top_key_freq  \
# 0  [('股利', 18), ('富邦', 12), ('現金', 9), ('股票', 5),...
#
#                                               tokens  \
# 0  ['富邦', '金控', '今', '（5', '）', '日', '公告', '，', '...
#
#                                            tokens_v2  \
# 0  ['富邦', '金控', '董事會', '通過', '普通股', '現金', '股利', '...
#
#                                             entities  \
# 0  [NerToken(word='富邦金控', ner='ORG', idx=(0, 4)),...
#
#                                            token_pos  \
# 0  [('富邦', 'Nb'), ('金控', 'Na'), ('今', 'Nd'), ('（5...
#
#                                    link  \
# 0  https://www.nownews.com/news/5796259
#
#                                           photo_link
# 0  https://media.nownews.com/nn_media/thumbnail/2...

# %%
df.entities[0]
# Out:
# "[NerToken(word='富邦金控', ner='ORG', idx=(0, 4)), NerToken(word='3.5元', ner='MONEY', idx=(31, 35)), NerToken(word='0.5元', ner='MONEY', idx=(40, 44)), NerToken(word='4.0元', ner='MONEY', idx=(52, 56)), NerToken(word='32%', ner='PERCENT', idx=(77, 80)), NerToken(word='富邦金', ner='ORG', idx=(86, 89)), NerToken(word='2021年', ner='DATE', idx=(116, 121)), NerToken(word='1,445.59億元', ner='MONEY', idx=(132, 142)), NerToken(word='富邦金', ner='ORG', idx=(170, 173)), NerToken(word='去年', ner='DATE', idx=(182, 184)), NerToken(word='新台幣3元', ner='MONEY', idx=(187, 192)), NerToken(word='3.5元', ner='MONEY', idx=(200, 204)), NerToken(word='俄', ner='GPE', idx=(262, 263)), NerToken(word='富邦金控', ner='ORG', idx=(336, 340)), NerToken(word='富邦人壽', ner='ORG', idx=(349, 353)), NerToken(word='155.78億元', ner='MONEY', idx=(355, 363)), NerToken(word='台北富邦銀行', ner='ORG', idx=(364, 370)), NerToken(word='富邦', ner='ORG', idx=(380, 382)), NerToken(word='47.99億元', ner='MONEY', idx=(386, 393)), NerToken(word='富邦', ner='ORG', idx=(394, 396)), NerToken(word='1.43億元', ner='MONEY', idx=(401, 407)), NerToken(word='富邦人壽', ner='ORG', idx=(409, 413)), NerToken(word='富邦人壽', ner='ORG', idx=(419, 423)), NerToken(word='5.2%', ner='PERCENT', idx=(432, 436)), NerToken(word='富邦', ner='ORG', idx=(439, 441)), NerToken(word='台北富邦銀行', ner='ORG', idx=(451, 457)), NerToken(word='北富銀', ner='ORG', idx=(463, 466)), NerToken(word='2021年', ner='DATE', idx=(466, 471)), NerToken(word='38.5%', ner='PERCENT', idx=(474, 479)), NerToken(word='富邦', ner='ORG', idx=(516, 518)), NerToken(word='富邦', ner='ORG', idx=(521, 523)), NerToken(word='富邦金', ner='ORG', idx=(551, 554)), NerToken(word='0.5元', ner='MONEY', idx=(566, 570)), NerToken(word='富邦金', ner='ORG', idx=(571, 574)), NerToken(word='金管會', ner='ORG', idx=(698, 701)), NerToken(word='6', ner='CARDINAL', idx=(703, 704)), NerToken(word='500億', ner='CARDINAL', idx=(716, 720))]"

# %%
def NerToken(word, ner, idx):
    # print(ner,word)
    return ner,word

# %%
NerToken(word='烏克蘭', ner='GPE', idx=(4, 7))
# Out:
# ('GPE', '烏克蘭')

# %%
eval(df.entities[0])
# Out:
# [('ORG', '富邦金控'),
#  ('MONEY', '3.5元'),
#  ('MONEY', '0.5元'),
#  ('MONEY', '4.0元'),
#  ('PERCENT', '32%'),
#  ('ORG', '富邦金'),
#  ('DATE', '2021年'),
#  ('MONEY', '1,445.59億元'),
#  ('ORG', '富邦金'),
#  ('DATE', '去年'),
#  ('MONEY', '新台幣3元'),
#  ('MONEY', '3.5元'),
#  ('GPE', '俄'),
#  ('ORG', '富邦金控'),
#  ('ORG', '富邦人壽'),
#  ('MONEY', '155.78億元'),
#  ('ORG', '台北富邦銀行'),
#  ('ORG', '富邦'),
#  ('MONEY', '47.99億元'),
#  ('ORG', '富邦'),
#  ('MONEY', '1.43億元'),
#  ('ORG', '富邦人壽'),
#  ('ORG', '富邦人壽'),
#  ('PERCENT', '5.2%'),
#  ('ORG', '富邦'),
#  ('ORG', '台北富邦銀行'),
#  ('ORG', '北富銀'),
#  ('DATE', '2021年'),
#  ('PERCENT', '38.5%'),
#  ('ORG', '富邦'),
#  ('ORG', '富邦'),
#  ('ORG', '富邦金'),
#  ('MONEY', '0.5元'),
#  ('ORG', '富邦金'),
#  ('ORG', '金管會'),
#  ('CARDINAL', '6'),
#  ('CARDINAL', '500億')]

# %%
for ner,key in eval(df.entities[0]):
    print(ner,key)
# Out:
# ORG 富邦金控
# MONEY 3.5元
# MONEY 0.5元
# MONEY 4.0元
# PERCENT 32%
# ORG 富邦金
# DATE 2021年
# MONEY 1,445.59億元
# ORG 富邦金
# DATE 去年
# MONEY 新台幣3元
# MONEY 3.5元
# GPE 俄
# ORG 富邦金控
# ORG 富邦人壽
# MONEY 155.78億元
# ORG 台北富邦銀行
# ORG 富邦
# MONEY 47.99億元
# ORG 富邦
# MONEY 1.43億元
# ORG 富邦人壽
# ORG 富邦人壽
# PERCENT 5.2%
# ORG 富邦
# ORG 台北富邦銀行
# ORG 北富銀
# DATE 2021年
# PERCENT 38.5%
# ORG 富邦
# ORG 富邦
# ORG 富邦金
# MONEY 0.5元
# ORG 富邦金
# ORG 金管會
# CARDINAL 6
# CARDINAL 500億

# %%
from collections import Counter

# %% [markdown]
# CARDINAL	數字
# DATE	日期
# EVENT	事件
# FAC	設施
# GPE	行政區
# LANGUAGE	語言
# LAW	法律
# LOC	地理區
# MONEY	金錢
# NORP	民族、宗教、政治團體
# ORDINAL	序數
# ORG	組織
# PERCENT	百分比率
# PERSON	人物
# PRODUCT	產品
# QUANTITY	數量
# TIME	時間
# WORK_OF_ART	作品

# %%
NE_Name=['CARDINAL','DATE','EVENT','FAC','GPE','LANGUAGE','LAW','LOC','MONEY','NORP','ORDINAL','ORG','PERCENT','PERSON','PRODUCT','QUANTITY','TIME','WORK_OF_ART']

# %%
# %%time
# It takes time, at least 2 minitues.
top_word_NE=[]
for ne_name in NE_Name:
    allowedNE= [ne_name]
    topwords = get_top_ner_words()
    top_word_NE.append([ne_name, topwords])
# Out:
# CPU times: total: 23.9 s
# Wall time: 23.9 s

# %%
top_word_NE
# Out:
# [['CARDINAL',
#   [('焦點',
#     [('之一', 30),
#      ('19', 27),
#      ('14', 24),
#      ('12', 21),
#      ('18', 20),
#      ('10', 18),
#      ('11', 17),
#      ('15', 16),
#      ('30', 14),
#      ('21', 13),
#      ('119', 13),
#      ('17', 11),
#      ('50', 9),
#      ('16', 9),
#      ('三千', 9),
#      ('13', 8),
#      ('200', 8),
#      ('20萬', 8),
#      ('80', 8),
#      ('百萬', 8),
#      ('60', 7),
#      ('1萬', 7),
#      ('2000', 7),
#      ('42', 7),
#      ('120', 7),
#      ('36', 7),
#      ('100', 7),
#      ('40', 7),
#      ('27', 7),
#      ('數百', 7),
#      ('6/10', 7),
#      ('25', 6),
#      ('1億', 6),
#      ('1000', 6),
#      ('70', 6),
#      ('10萬', 6),
#      ('3/4', 6),
#      ('77', 6),
#      ('3萬', 5),
#      ('29', 5),
#      ('23', 5),
#      ('500', 5),
#      ('54', 5),
#      ('1.9兆', 5),
#      ('20', 5),
#      ('200萬', 5),
#      ('100萬', 5),
#      ('3000', 5),
#      ('38', 5),
#      ('5.2萬', 5),
#      ('300', 4),
#      ('7+7', 4),
#      ('一半', 4),
#      ('192', 4),
#      ('800', 4),
#      ('400萬', 4),
#      ('2019', 4),
#      ('58', 4),
#      ('55', 4),
#      ('63,964', 4),
#      ('105', 4),
#      ('6/12', 4),
#      ('550', 4),
#      ('142', 4),
#      ('26', 3),
#      ('2022', 3),
#      ('1980', 3),
#      ('1995', 3),
#      ('364', 3),
#      ('25萬', 3),
#      ('28', 3),
#      ('113', 3),
#      ('140', 3),
#      ('2.0', 3),
#      ('7000', 3),
#      ('12萬', 3),
#      ('1487', 3),
#      ('301', 3),
#      ('1/4', 3),
#      ('2000多', 3),
#      ('400', 3),
#      ('數百萬', 3),
#      ('70萬', 3),
#      ('5,000萬', 3),
#      ('22', 3),
#      ('11萬', 3),
#      ('6萬', 3),
#      ('1015', 3),
#      ('數十', 3),
#      ('194', 3),
#      ('2萬', 3),
#      ('130萬', 3),
#      ('87', 3),
#      ('240', 3),
#      ('5/23', 3),
#      ('135', 3),
#      ('71', 3),
#      ('600億', 3),
#      ('7成', 2),
#      ('1500', 2),
#      ('123', 2),
#      ('46', 2),
#      ('01', 2),
#      ('48', 2),
#      ('50萬', 2),
#      ('110', 2),
#      ('3300', 2),
#      ('2750', 2),
#      ('700', 2),
#      ('上千', 2),
#      ('37', 2),
#      ('33', 2),
#      ('600', 2),
#      ('41', 2),
#      ('0800', 2),
#      ('1925', 2),
#      ('2/3', 2),
#      ('90', 2),
#      ('兩萬', 2),
#      ('2330', 2),
#      ('5/13', 2),
#      ('6.5萬', 2),
#      ('3千', 2),
#      ('40萬', 2),
#      ('63964', 2),
#      ('破萬', 2),
#      ('低於萬', 2),
#      ('9,482', 2),
#      ('200多萬', 2),
#      ('6萬5', 2),
#      ('22萬', 2),
#      ('6萬3964', 2),
#      ('1419', 2),
#      ('130', 2),
#      ('數千', 2),
#      ('4.4', 2),
#      ('30幾萬', 2),
#      ('上萬', 2),
#      ('322', 2),
#      ('4500', 2),
#      ('600萬', 2),
#      ('9萬1000', 2),
#      ('二對二', 2),
#      ('9.5萬', 2),
#      ('4.7萬', 2),
#      ('5億', 2),
#      ('47', 2),
#      ('20多', 2),
#      ('6/4', 2),
#      ('34', 2),
#      ('265', 2),
#      ('24', 2),
#      ('5000萬', 2),
#      ('一億', 2),
#      ('84800', 2),
#      ('49', 2),
#      ('1.68億', 2),
#      ('1萬6000', 2),
#      ('409', 2),
#      ('134', 2),
#      ('67', 2),
#      ('104', 2),
#      ('78', 2),
#      ('200多', 2),
#      ('500億', 1),
#      ('19.3萬', 1),
#      ('9120', 1),
#      ('成千上萬', 1),
#      ('3+4', 1),
#      ('10+7', 1),
#      ('9600多', 1),
#      ('4000', 1),
#      ('271', 1),
#      ('36168', 1),
#      ('10＋7', 1),
#      ('56', 1),
#      ('1700萬', 1),
#      ('83', 1),
#      ('09:53:5', 1),
#      ('00', 1),
#      ('190', 1),
#      ('621', 1),
#      ('09:56:00', 1),
#      ('6630', 1),
#      ('1萬4,404', 1),
#      ('29萬6,487', 1),
#      ('615', 1),
#      ('45', 1),
#      ('1346', 1),
#      ('794', 1),
#      ('255', 1),
#      ('6/5', 1),
#      ('312萬3521', 1),
#      ('15萬5617', 1),
#      ('2億', 1),
#      ('十幾', 1),
#      ('608', 1),
#      ('1700多', 1),
#      ('70多', 1),
#      ('157', 1)]),
#    ('要聞',
#     [('10', 15),
#      ('200萬', 12),
#      ('119', 11),
#      ('18', 10),
#      ('100', 10),
#      ('400萬', 9),
#      ('300', 9),
#      ('破萬', 8),
#      ('12', 8),
#      ('20', 7),
#      ('14', 7),
#      ('60', 7),
#      ('57', 7),
#      ('之一', 6),
#      ('10萬', 6),
#      ('15', 6),
#      ('1700萬', 6),
#      ('2024', 6),
#      ('25', 5),
#      ('13', 5),
#      ('11', 5),
#      ('5萬', 5),
#      ('21', 5),
#      ('40', 5),
#      ('17', 5),
#      ('46', 5),
#      ('30', 4),
#      ('百萬', 4),
#      ('19', 4),
#      ('20萬', 4),
#      ('九二', 4),
#      ('38', 4),
#      ('400', 4),
#      ('50萬', 4),
#      ('3+4', 4),
#      ('70萬', 4),
#      ('78', 4),
#      ('71', 4),
#      ('48', 4),
#      ('3萬', 3),
#      ('1/3', 3),
#      ('66', 3),
#      ('809', 3),
#      ('95', 3),
#      ('7萬', 3),
#      ('85', 3),
#      ('124', 3),
#      ('49', 3),
#      ('700', 3),
#      ('8萬多', 3),
#      ('2022.06.08', 3),
#      ('3000', 3),
#      ('108', 3),
#      ('50', 3),
#      ('99', 3),
#      ('2萬多', 3),
#      ('2022.05.09', 3),
#      ('22', 3),
#      ('5/8', 3),
#      ('5/4', 3),
#      ('12萬', 3),
#      ('73萬', 3),
#      ('24', 3),
#      ('1億', 3),
#      ('55', 3),
#      ('800', 3),
#      ('817萬', 3),
#      ('47', 3),
#      ('1000', 3),
#      ('三十', 3),
#      ('99萬', 3),
#      ('2022.06.02', 3),
#      ('42', 3),
#      ('7200', 3),
#      ('110.88萬', 3),
#      ('6/6', 3),
#      ('312', 2),
#      ('35', 2),
#      ('202', 2),
#      ('27', 2),
#      ('86', 2),
#      ('33', 2),
#      ('140', 2),
#      ('2.0', 2),
#      ('2022', 2),
#      ('0+7', 2),
#      ('70', 2),
#      ('14萬', 2),
#      ('1萬2,498', 2),
#      ('74', 2),
#      ('5千多', 2),
#      ('193', 2),
#      ('160', 2),
#      ('2750', 2),
#      ('8萬195', 2),
#      ('159', 2),
#      ('1萬1,587', 2),
#      ('1.1萬', 2),
#      ('8萬', 2),
#      ('600', 2),
#      ('172', 2),
#      ('1.93億', 2),
#      ('201萬', 2),
#      ('2,099', 2),
#      ('100萬', 2),
#      ('30萬', 2),
#      ('破千', 2),
#      ('1000萬', 2),
#      ('40萬', 2),
#      ('7,366', 2),
#      ('1360多', 2),
#      ('275', 2),
#      ('4萬', 2),
#      ('53萬', 2),
#      ('一百', 2),
#      ('五十萬', 2),
#      ('7+7', 2),
#      ('5/5', 2),
#      ('一半', 2),
#      ('41', 2),
#      ('三合一', 2),
#      ('64', 2),
#      ('37萬', 2),
#      ('1500萬', 2),
#      ('8400億', 2),
#      ('6萬', 2),
#      ('1萬', 2),
#      ('8566', 2),
#      ('1/8', 2),
#      ('475', 2),
#      ('289', 2),
#      ('6/4', 2),
#      ('2萬', 2),
#      ('2.5萬', 2),
#      ('60042', 2),
#      ('109', 2),
#      ('33萬', 2),
#      ('33.12萬', 2),
#      ('800多', 2),
#      ('9.3萬', 2),
#      ('10多', 2),
#      ('2022.05.31', 2),
#      ('700多', 2),
#      ('675', 2),
#      ('540', 2),
#      ('140萬', 2),
#      ('3-5', 2),
#      ('二七', 2),
#      ('3千', 2),
#      ('10122', 1),
#      ('30580', 1),
#      ('45422', 1),
#      ('678', 1),
#      ('254', 1),
#      ('4到5', 1),
#      ('7000', 1),
#      ('朝三暮四', 1),
#      ('15萬', 1),
#      ('34', 1),
#      ('7,360億', 1),
#      ('28億', 1),
#      ('1,484億', 1),
#      ('20億', 1),
#      ('7716', 1),
#      ('16億', 1),
#      ('29', 1),
#      ('608', 1),
#      ('312萬3521', 1),
#      ('2.8萬', 1),
#      ('470', 1),
#      ('134', 1),
#      ('340', 1),
#      ('158萬', 1),
#      ('8.4萬', 1),
#      ('63萬', 1),
#      ('7.56', 1),
#      ('4.24', 1),
#      ('2.74', 1),
#      ('65', 1),
#      ('8萬2,973', 1),
#      ('1萬2,572', 1),
#      ('1萬1', 1),
#      ('1千', 1),
#      ('22萬', 1),
#      ('一次', 1),
#      ('330', 1),
#      ('138萬145', 1),
#      ('18頭', 1),
#      ('1995', 1),
#      ('2.6萬', 1),
#      ('八成', 1),
#      ('1600', 1),
#      ('1150', 1),
#      ('2萬5500', 1),
#      ('100多', 1),
#      ('2億', 1),
#      ('02', 1),
#      ('6／9', 1),
#      ('1128', 1),
#      ('逾千', 1)]),
#    ('即時',
#     [('10', 49),
#      ('12', 37),
#      ('14', 36),
#      ('之一', 33),
#      ('21', 33),
#      ('19', 27),
#      ('11', 25),
#      ('18', 24),
#      ('50', 23),
#      ('20', 22),
#      ('16', 20),
#      ('30', 19),
#      ('15', 17),
#      ('60', 16),
#      ('24', 16),
#      ('119', 15),
#      ('13', 15),
#      ('百萬', 12),
#      ('17', 12),
#      ('40', 12),
#      ('一半', 11),
#      ('33', 9),
#      ('1萬', 8),
#      ('2000', 8),
#      ('6/10', 8),
#      ('27', 8),
#      ('76', 8),
#      ('26', 8),
#      ('7+7', 7),
#      ('23', 7),
#      ('73萬', 7),
#      ('3/4', 7),
#      ('200萬', 7),
#      ('31', 7),
#      ('10萬', 6),
#      ('22', 6),
#      ('2022', 6),
#      ('1000', 6),
#      ('2:0', 6),
#      ('36萬', 6),
#      ('1億', 6),
#      ('41', 6),
#      ('二軍', 6),
#      ('4萬', 6),
#      ('830', 6),
#      ('100萬', 6),
#      ('3萬', 5),
#      ('5/8', 5),
#      ('29', 5),
#      ('1980', 5),
#      ('1995', 5),
#      ('200', 5),
#      ('400萬', 5),
#      ('58', 5),
#      ('破萬', 5),
#      ('12萬', 5),
#      ('萬六', 5),
#      ('80', 5),
#      ('1700萬', 5),
#      ('40萬', 5),
#      ('100', 5),
#      ('3+4', 4),
#      ('48', 4),
#      ('50億', 4),
#      ('90', 4),
#      ('2019', 4),
#      ('0800', 4),
#      ('96', 4),
#      ('破千', 4),
#      ('5000萬', 4),
#      ('數十', 4),
#      ('1000萬', 4),
#      ('40263', 4),
#      ('108', 4),
#      ('二刀流', 4),
#      ('20萬', 4),
#      ('35', 4),
#      ('32', 4),
#      ('70', 4),
#      ('300萬', 4),
#      ('6/12', 4),
#      ('4.5', 4),
#      ('86', 4),
#      ('106', 3),
#      ('89', 3),
#      ('123', 3),
#      ('83', 3),
#      ('46', 3),
#      ('364', 3),
#      ('500', 3),
#      ('千萬', 3),
#      ('十幾', 3),
#      ('113', 3),
#      ('2.4億', 3),
#      ('201萬', 3),
#      ('7萬', 3),
#      ('2萬', 3),
#      ('28', 3),
#      ('5萬', 3),
#      ('1925', 3),
#      ('504', 3),
#      ('4、5', 3),
#      ('500萬', 3),
#      ('73', 3),
#      ('30萬', 3),
#      ('2022.05.09', 3),
#      ('400', 3),
#      ('40,263', 3),
#      ('71', 3),
#      ('275', 3),
#      ('240', 3),
#      ('304', 3),
#      ('八千', 3),
#      ('70萬', 3),
#      ('34', 3),
#      ('1萬8180', 3),
#      ('3000', 3),
#      ('20多', 3),
#      ('16萬', 3),
#      ('322', 3),
#      ('59', 3),
#      ('3625', 3),
#      ('82', 3),
#      ('2.0', 3),
#      ('數百萬', 3),
#      ('101', 3),
#      ('78', 3),
#      ('5/4', 3),
#      ('300', 3),
#      ('1/4', 3),
#      ('25', 3),
#      ('520', 3),
#      ('102', 3),
#      ('130萬', 3),
#      ('5/23', 3),
#      ('6/1', 3),
#      ('36.2', 3),
#      ('3.2', 3),
#      ('四分之三', 2),
#      ('252萬', 2),
#      ('5/6', 2),
#      ('2萬多', 2),
#      ('01', 2),
#      ('00', 2),
#      ('50萬', 2),
#      ('192', 2),
#      ('25萬', 2),
#      ('117', 2),
#      ('9三', 2),
#      ('2億', 2),
#      ('2千', 2),
#      ('4.8億', 2),
#      ('3000萬', 2),
#      ('1200', 2),
#      ('數百', 2),
#      ('299', 2),
#      ('38', 2),
#      ('6.2', 2),
#      ('770', 2),
#      ('5.93', 2),
#      ('68', 2),
#      ('3至5', 2),
#      ('一軍', 2),
#      ('六成', 2),
#      ('1.93億', 2),
#      ('460', 2),
#      ('99', 2),
#      ('2,099', 2),
#      ('7057', 2),
#      ('1.2億', 2),
#      ('一百萬', 2),
#      ('7,366', 2),
#      ('+7', 2),
#      ('87', 2),
#      ('1360多', 2),
#      ('340', 2),
#      ('180', 2),
#      ('131', 2),
#      ('27萬', 2),
#      ('一次', 2),
#      ('415', 2),
#      ('1000多', 2),
#      ('150', 2),
#      ('五萬', 2),
#      ('8千', 2),
#      ('上萬', 2),
#      ('數千', 2),
#      ('5/5', 2),
#      ('65', 2),
#      ('410', 2),
#      ('92', 2),
#      ('1.4萬', 2),
#      ('8三', 2),
#      ('74', 2),
#      ('198', 2),
#      ('98', 2),
#      ('64', 2),
#      ('72', 2),
#      ('兩萬', 2),
#      ('T1', 2)]),
#    ('娛樂',
#     [('百萬', 22),
#      ('10', 11),
#      ('100萬', 10),
#      ('113', 8),
#      ('12', 7),
#      ('16', 6),
#      ('18', 6),
#      ('100', 6),
#      ('之一', 6),
#      ('2.5萬', 6),
#      ('3萬', 5),
#      ('15', 5),
#      ('一半', 5),
#      ('3億', 5),
#      ('20萬', 4),
#      ('13', 4),
#      ('36萬', 4),
#      ('60', 4),
#      ('10億', 4),
#      ('5萬', 4),
#      ('25', 4),
#      ('1980', 3),
#      ('1995', 3),
#      ('110', 3),
#      ('百億', 3),
#      ('一百萬', 3),
#      ('24', 3),
#      ('11', 3),
#      ('30', 3),
#      ('520', 3),
#      ('20', 3),
#      ('2萬', 3),
#      ('千萬', 3),
#      ('22萬', 2),
#      ('50萬', 2),
#      ('4、5', 2),
#      ('240', 2),
#      ('34', 2),
#      ('500萬', 2),
#      ('13萬', 2),
#      ('16萬', 2),
#      ('10萬', 2),
#      ('35', 2),
#      ('2000多', 2),
#      ('12,156', 2),
#      ('三億', 2),
#      ('84', 2),
#      ('23萬', 2),
#      ('05/30~06/05', 2),
#      ('80', 2),
#      ('50', 2),
#      ('121萬', 2),
#      ('5億', 2),
#      ('9000萬', 2),
#      ('116萬', 2),
#      ('1000萬', 2),
#      ('108萬', 2),
#      ('幾百', 1),
#      ('77萬', 1),
#      ('幾百萬', 1),
#      ('192', 1),
#      ('90多萬', 1),
#      ('94', 1),
#      ('6/10', 1),
#      ('老三', 1),
#      ('三角', 1),
#      ('158萬', 1),
#      ('51萬', 1),
#      ('上億', 1),
#      ('42萬', 1),
#      ('6.8億', 1),
#      ('40萬', 1),
#      ('成千上萬', 1),
#      ('70萬', 1),
#      ('十幾萬', 1),
#      ('0.86', 1),
#      ('0.81', 1),
#      ('2022', 1),
#      ('167', 1),
#      ('3.8萬', 1),
#      ('上百萬', 1),
#      ('0002', 1),
#      ('000', 1),
#      ('3000', 1),
#      ('14', 1),
#      ('一次', 1),
#      ('150', 1),
#      ('202', 1),
#      ('215億', 1),
#      ('49萬', 1),
#      ('2.8萬', 1),
#      ('67萬', 1),
#      ('1萬', 1),
#      ('79萬', 1),
#      ('4.4萬', 1),
#      ('破百', 1),
#      ('1000', 1),
#      ('7.7萬', 1),
#      ('十八', 1),
#      ('十幾', 1),
#      ('8千萬', 1),
#      ('283萬', 1),
#      ('600', 1),
#      ('9千萬', 1),
#      ('4300萬', 1),
#      ('5五', 1),
#      ('4/17', 1),
#      ('32', 1),
#      ('26.5萬', 1),
#      ('99999', 1),
#      ('99', 1),
#      ('一萬', 1),
#      ('30萬', 1),
#      ('6.5', 1),
#      ('10+7', 1),
#      ('88億', 1),
#      ('76.1萬', 1),
#      ('17', 1),
#      ('189', 1),
#      ('8000', 1),
#      ('5千', 1),
#      ('27', 1),
#      ('16萬8千', 1),
#      ('13萬多', 1),
#      ('132', 1),
#      ('180', 1),
#      ('95', 1),
#      ('孫萬', 1),
#      ('150萬', 1),
#      ('120', 1),
#      ('19', 1),
#      ('3.9萬', 1),
#      ('1.5萬', 1),
#      ('19萬', 1),
#      ('一千萬', 1),
#      ('破千萬', 1),
#      ('五千萬', 1),
#      ('一億多', 1),
#      ('1.5億', 1),
#      ('112', 1),
#      ('106', 1),
#      ('159', 1),
#      ('61', 1),
#      ('18,576,747', 1),
#      ('303,058,512', 1),
#      ('兩億', 1),
#      ('700萬', 1),
#      ('十萬', 1),
#      ('70', 1),
#      ('115', 1),
#      ('90', 1),
#      ('86', 1),
#      ('54', 1),
#      ('05/30~06', 1),
#      ('343萬', 1),
#      ('424', 1),
#      ('超過百', 1),
#      ('上千', 1),
#      ('55萬', 1),
#      ('8千多', 1),
#      ('3000萬三', 1),
#      ('175萬', 1),
#      ('4千萬', 1),
#      ('311', 1),
#      ('2000', 1),
#      ('80幾萬', 1),
#      ('509萬', 1),
#      ('1萬7千', 1),
#      ('101', 1),
#      ('1.7萬', 1),
#      ('36', 1),
#      ('510億', 1),
#      ('500', 1),
#      ('133萬', 1),
#      ('三十萬', 1),
#      ('12多萬', 1),
#      ('0800', 1),
#      ('1925', 1),
#      ('4億', 1),
#      ('76萬', 1),
#      ('右三', 1),
#      ('右二', 1),
#      ('4.3億', 1),
#      ('134萬', 1),
#      ('200萬', 1),
#      ('550萬', 1),
#      ('1.8萬', 1),
#      ('288萬', 1),
#      ('48', 1),
#      ('85', 1),
#      ('58', 1),
#      ('23', 1),
#      ('341', 1),
#      ('19:00', 1),
#      ('上百', 1),
#      ('2500', 1),
#      ('左二', 1),
#      ('百分百', 1),
#      ('3.4', 1),
#      ('90萬', 1)]),
#    ('新奇',
#     [('10', 17),
#      ('之一', 16),
#      ('百萬', 15),
#      ('一半', 10),
#      ('100', 9),
#      ('1萬', 8),
#      ('30', 8),
#      ('150萬', 8),
#      ('60', 7),
#      ('5萬', 7),
#      ('11', 7),
#      ('50', 7),
#      ('6/30', 7),
#      ('100萬', 7),
#      ('12', 6),
#      ('25', 5),
#      ('2萬', 5),
#      ('千萬', 5),
#      ('10萬', 4),
#      ('300', 4),
#      ('288萬', 4),
#      ('20萬', 4),
#      ('上千', 4),
#      ('180', 4),
#      ('505萬', 4),
#      ('5000', 3),
#      ('300萬', 3),
#      ('70', 3),
#      ('80', 3),
#      ('2.0', 3),
#      ('三選一', 3),
#      ('19', 3),
#      ('45', 3),
#      ('6/1', 3),
#      ('6千', 3),
#      ('500萬', 3),
#      ('6萬', 3),
#      ('1200萬', 3),
#      ('4800萬', 3),
#      ('5,000萬', 3),
#      ('200萬', 3),
#      ('20', 3),
#      ('40', 3),
#      ('175', 3),
#      ('一百萬', 3),
#      ('3億', 3),
#      ('500', 2),
#      ('36', 2),
#      ('800', 2),
#      ('一百', 2),
#      ('5千', 2),
#      ('百億', 2),
#      ('6/8', 2),
#      ('16', 2),
#      ('35', 2),
#      ('兩萬', 2),
#      ('60萬', 2),
#      ('13萬', 2),
#      ('五桐號', 2),
#      ('6/1～6/14', 2),
#      ('7萬', 2),
#      ('830', 2),
#      ('4、5', 2),
#      ('14', 2),
#      ('41', 2),
#      ('23', 2),
#      ('158', 2),
#      ('238', 2),
#      ('8萬多', 2),
#      ('120', 2),
#      ('2289', 2),
#      ('140', 2),
#      ('三億', 2),
#      ('18', 2),
#      ('6/5', 2),
#      ('1-2', 2),
#      ('66', 2),
#      ('2千多', 1),
#      ('60餘', 1),
#      ('五萬多', 1),
#      ('至7萬', 1),
#      ('7-11七', 1),
#      ('5／10', 1),
#      ('7,851', 1),
#      ('22', 1),
#      ('兩千兩百萬多萬', 1),
#      ('2200萬', 1),
#      ('109萬', 1),
#      ('三百', 1),
#      ('一千', 1),
#      ('90萬', 1),
#      ('55', 1),
#      ('三萬', 1),
#      ('兩萬五', 1),
#      ('42萬', 1),
#      ('40萬', 1),
#      ('8.8', 1),
#      ('約88', 1),
#      ('88', 1),
#      ('二擇一', 1),
#      ('26', 1),
#      ('50~59', 1),
#      ('96', 1),
#      ('100~108', 1),
#      ('10~19', 1),
#      ('八千', 1),
#      ('一千五', 1),
#      ('五千', 1),
#      ('6/1～6/30', 1),
#      ('6/8～6/30', 1),
#      ('7/20～8/2', 1),
#      ('2~3', 1),
#      ('一送一', 1),
#      ('7/2', 1),
#      ('8/2', 1),
#      ('21:00', 1),
#      ('10幾', 1),
#      ('2022', 1),
#      ('十二', 1),
#      ('3萬', 1),
#      ('1萬7', 1),
#      ('1.4萬份', 1),
#      ('一萬四千', 1),
#      ('504', 1),
#      ('75', 1),
#      ('95', 1),
#      ('5/9～5/1', 1),
#      ('153', 1),
#      ('1000', 1),
#      ('10多', 1),
#      ('幾百', 1),
#      ('2萬多', 1),
#      ('444萬', 1),
#      ('800萬', 1),
#      ('一萬', 1),
#      ('25.6萬', 1),
#      ('1.4萬', 1),
#      ('8萬', 1),
#      ('幾百億', 1),
#      ('299', 1),
#      ('三顆', 1),
#      ('三百多', 1),
#      ('2千', 1),
#      ('99', 1),
#      ('123', 1),
#      ('8千萬', 1),
#      ('30億', 1),
#      ('1億', 1),
#      ('5億', 1),
#      ('10億', 1),
#      ('4.5000', 1),
#      ('幾千', 1),
#      ('3萬多', 1),
#      ('1萬5490', 1),
#      ('32', 1),
#      ('26.5萬', 1),
#      ('7千', 1),
#      ('5千多', 1),
#      ('230', 1),
#      ('7+7', 1),
#      ('90', 1),
#      ('35萬', 1),
#      ('上百萬', 1),
#      ('2：00', 1),
#      ('6、7萬', 1),
#      ('76.1萬', 1),
#      ('17', 1),
#      ('5/31', 1),
#      ('5/2', 1),
#      ('6/17', 1),
#      ('6/24', 1),
#      ('0.8', 1),
#      ('715', 1),
#      ('1066', 1),
#      ('518', 1),
#      ('125', 1),
#      ('480', 1),
#      ('77', 1),
#      ('415', 1),
#      ('172', 1),
#      ('396', 1),
#      ('150～250', 1),
#      ('145', 1),
#      ('47', 1),
#      ('115', 1),
#      ('46', 1),
#      ('168', 1),
#      ('13', 1),
#      ('43', 1),
#      ('\u3000百萬', 1),
#      ('200', 1),
#      ('5/30', 1),
#      ('三次', 1),
#      ('900萬', 1),
#      ('1320萬', 1),
#      ('10.1萬', 1),
#      ('700萬', 1),
#      ('220', 1),
#      ('19萬', 1),
#      ('1243', 1)]),
#    ('生活',
#     [('10', 25),
#      ('之一', 18),
#      ('12', 16),
#      ('30', 12),
#      ('1萬', 11),
#      ('20', 11),
#      ('100萬', 11),
#      ('124', 10),
#      ('18', 10),
#      ('100', 10),
#      ('14', 9),
#      ('19', 8),
#      ('200萬', 8),
#      ('15', 8),
#      ('50', 8),
#      ('百萬', 8),
#      ('一半', 8),
#      ('25', 8),
#      ('500', 7),
#      ('千萬', 7),
#      ('60', 7),
#      ('2019', 6),
#      ('300', 6),
#      ('80', 6),
#      ('200', 6),
#      ('5萬', 6),
#      ('71', 6),
#      ('上千', 5),
#      ('150萬', 5),
#      ('5/13', 5),
#      ('20萬', 5),
#      ('5.2萬', 5),
#      ('400萬', 4),
#      ('1億', 4),
#      ('17', 4),
#      ('70', 4),
#      ('55', 4),
#      ('11', 4),
#      ('113', 4),
#      ('16', 4),
#      ('42', 4),
#      ('7萬', 4),
#      ('6萬', 4),
#      ('101', 4),
#      ('2萬', 4),
#      ('1980', 4),
#      ('1995', 4),
#      ('24', 4),
#      ('1200萬', 4),
#      ('5/18', 4),
#      ('130萬', 4),
#      ('505萬', 4),
#      ('68118', 4),
#      ('152', 4),
#      ('62080', 4),
#      ('5000萬', 3),
#      ('110', 3),
#      ('299', 3),
#      ('38', 3),
#      ('3萬', 3),
#      ('618', 3),
#      ('85', 3),
#      ('6/1', 3),
#      ('119', 3),
#      ('830', 3),
#      ('500萬', 3),
#      ('2萬多', 3),
#      ('2022.05.09', 3),
#      ('破萬', 3),
#      ('195', 3),
#      ('23', 3),
#      ('5,000萬', 3),
#      ('40', 3),
#      ('9613', 3),
#      ('76', 3),
#      ('290', 3),
#      ('6/6', 3),
#      ('540', 3),
#      ('33', 3),
#      ('62110', 3),
#      ('57', 3),
#      ('193', 2),
#      ('300萬', 2),
#      ('288萬', 2),
#      ('90萬', 2),
#      ('1萬2,498', 2),
#      ('74', 2),
#      ('5千多', 2),
#      ('1千', 2),
#      ('22萬', 2),
#      ('36', 2),
#      ('800', 2),
#      ('一百', 2),
#      ('45萬', 2),
#      ('13', 2),
#      ('2500萬', 2),
#      ('192', 2),
#      ('1500', 2),
#      ('68', 2),
#      ('00', 2),
#      ('一百萬', 2),
#      ('6/30', 2),
#      ('一送一', 2),
#      ('2022', 2),
#      ('6千', 2),
#      ('數千', 2),
#      ('三分之一', 2),
#      ('5/12', 2),
#      ('0800', 2),
#      ('4、5', 2),
#      ('95', 2),
#      ('1.93億', 2),
#      ('201萬', 2),
#      ('2萬3206', 2),
#      ('2,099', 2),
#      ('73', 2),
#      ('96', 2),
#      ('30萬', 2),
#      ('5/9', 2),
#      ('1800', 2),
#      ('7+7', 2),
#      ('3+4', 2),
#      ('5/16', 2),
#      ('4800萬', 2),
#      ('3,346', 2),
#      ('603', 2),
#      ('2455', 2),
#      ('800多', 2),
#      ('9751', 2),
#      ('超過萬', 2),
#      ('360', 2),
#      ('2000', 2),
#      ('517', 2),
#      ('8636', 2),
#      ('9.5萬', 2),
#      ('4.7萬', 2),
#      ('100多', 2),
#      ('60萬', 2),
#      ('78', 2),
#      ('84800', 2),
#      ('2022.05.31', 2),
#      ('700多', 2),
#      ('41', 2),
#      ('600', 2),
#      ('140萬', 2),
#      ('3-5', 2),
#      ('6/5', 2),
#      ('0.2', 2),
#      ('675', 2),
#      ('3.9', 2),
#      ('29', 2),
#      ('68151', 2),
#      ('496', 2),
#      ('144', 2),
#      ('87', 2),
#      ('21', 2),
#      ('104', 2),
#      ('116', 2),
#      ('259', 1),
#      ('5／9', 1),
#      ('2千多', 1),
#      ('271', 1),
#      ('36168', 1),
#      ('10＋7', 1),
#      ('56', 1),
#      ('6400萬', 1),
#      ('三百', 1),
#      ('二次元', 1),
#      ('五千', 1),
#      ('一千', 1),
#      ('8萬2,973', 1),
#      ('1萬2,572', 1),
#      ('1萬1', 1),
#      ('三萬', 1),
#      ('兩萬五', 1),
#      ('135萬', 1),
#      ('40萬', 1),
#      ('0.4', 1),
#      ('329', 1),
#      ('143', 1),
#      ('6.1', 1),
#      ('42萬', 1),
#      ('1.8', 1),
#      ('6.1倍', 1),
#      ('1.1萬', 1),
#      ('約3萬多', 1),
#      ('約7000', 1),
#      ('1000多', 1),
#      ('15萬', 1),
#      ('2億', 1),
#      ('2~3', 1),
#      ('3、4億', 1),
#      ('28', 1),
#      ('82億', 1),
#      ('610萬', 1),
#      ('230萬', 1),
#      ('6,000', 1),
#      ('6/18', 1),
#      ('4百萬', 1),
#      ('6/1～6/14', 1)]),
#    ('財經',
#     [('百萬', 17),
#      ('萬六', 12),
#      ('10', 10),
#      ('11', 9),
#      ('20', 9),
#      ('之一', 8),
#      ('千萬', 8),
#      ('500', 7),
#      ('12', 7),
#      ('100', 7),
#      ('237', 6),
#      ('1.2', 6),
#      ('20萬', 5),
#      ('30', 5),
#      ('一半', 4),
#      ('2021', 4),
#      ('101', 4),
#      ('33萬', 4),
#      ('61萬', 4),
#      ('70萬', 4),
#      ('1,202', 4),
#      ('40萬', 4),
#      ('2.28萬', 4),
#      ('破萬', 4),
#      ('2萬', 3),
#      ('15', 3),
#      ('16', 3),
#      ('61', 3),
#      ('18', 3),
#      ('400', 3),
#      ('600萬', 3),
#      ('14', 3),
#      ('95', 3),
#      ('60萬', 3),
#      ('13', 3),
#      ('2050', 3),
#      ('4.2', 3),
#      ('8000', 3),
#      ('九成', 3),
#      ('557', 3),
#      ('5.7', 3),
#      ('6.9', 3),
#      ('上百', 3),
#      ('60多', 3),
#      ('30多', 3),
#      ('600多', 3),
#      ('29', 3),
#      ('102', 3),
#      ('10萬', 2),
#      ('400萬', 2),
#      ('2022', 2),
#      ('34', 2),
#      ('2千萬', 2),
#      ('54', 2),
#      ('17', 2),
#      ('60億', 2),
#      ('4萬', 2),
#      ('200萬', 2),
#      ('1.1萬', 2),
#      ('近百', 2),
#      ('4966', 2),
#      ('2586', 2),
#      ('2.9萬', 2),
#      ('1萬', 2),
#      ('37', 2),
#      ('6千', 2),
#      ('3+4', 2),
#      ('00', 2),
#      ('70', 2),
#      ('80', 2),
#      ('90', 2),
#      ('1.7', 2),
#      ('40', 2),
#      ('1200萬', 2),
#      ('1000萬', 2),
#      ('86', 2),
#      ('19~21萬', 2),
#      ('700', 2),
#      ('18~19萬', 2),
#      ('十四', 2),
#      ('1080萬', 2),
#      ('2603', 2),
#      ('1至5', 2),
#      ('26萬', 2),
#      ('1.6萬', 2),
#      ('1.98', 2),
#      ('13萬', 2),
#      ('1,000', 2),
#      ('28', 2),
#      ('兩碼', 2),
#      ('百萬英', 2),
#      ('4倍', 2),
#      ('2.5萬', 2),
#      ('5成', 2),
#      ('數百萬', 2),
#      ('99萬', 2),
#      ('101.3萬', 2),
#      ('19', 2),
#      ('14筆', 2),
#      ('四眼', 2),
#      ('3家', 2),
#      ('146名', 2),
#      ('兩家', 2),
#      ('30名', 2),
#      ('31名', 2),
#      ('19家', 2),
#      ('898', 2),
#      ('22名', 2),
#      ('18名', 2),
#      ('34.7萬', 2),
#      ('12.8萬', 2),
#      ('16.2萬', 2),
#      ('13.1億', 2),
#      ('三星', 2),
#      ('7億', 2),
#      ('126萬', 2),
#      ('3000多', 2),
#      ('一成', 2),
#      ('3068', 2),
#      ('5721', 2),
#      ('338', 2),
#      ('3648', 2),
#      ('三萬', 2),
#      ('八萬', 2),
#      ('1.6', 1),
#      ('102.48', 1),
#      ('103', 1),
#      ('4/29', 1),
#      ('4到5', 1),
#      ('百億', 1),
#      ('30.68億', 1),
#      ('2500億', 1),
#      ('5千', 1),
#      ('137萬', 1),
#      ('24', 1),
#      ('900', 1),
#      ('295萬', 1),
#      ('289萬', 1),
#      ('數十', 1),
#      ('0.1174', 1),
#      ('0.5947', 1),
#      ('五顏六', 1),
#      ('0~9', 1),
#      ('20餘', 1),
#      ('2001', 1),
#      ('88', 1),
#      ('三選一', 1),
#      ('260', 1),
#      ('4成', 1),
#      ('一半以上', 1),
#      ('三十', 1),
#      ('8萬', 1),
#      ('520', 1),
#      ('其一', 1),
#      ('9.9', 1),
#      ('35.8', 1),
#      ('200', 1),
#      ('124', 1),
#      ('36', 1),
#      ('雙位數', 1),
#      ('十四五', 1),
#      ('數千', 1),
#      ('303', 1),
#      ('53萬', 1),
#      ('1.93億', 1),
#      ('201萬', 1),
#      ('2成', 1),
#      ('1~49', 1),
#      ('139', 1),
#      ('6萬4', 1),
#      ('815萬6000', 1),
#      ('9000', 1),
#      ('6000', 1),
#      ('近十萬', 1),
#      ('數以百萬', 1),
#      ('5倍', 1),
#      ('2.0', 1),
#      ('超過一倍', 1),
#      ('2022Q1', 1),
#      ('309', 1),
#      ('2380', 1),
#      ('23', 1),
#      ('5997', 1),
#      ('8千', 1),
#      ('600', 1),
#      ('506', 1),
#      ('506一', 1),
#      ('518', 1),
#      ('近9千萬', 1),
#      ('0+7', 1),
#      ('82050976', 1),
#      ('75704516', 1),
#      ('65萬', 1),
#      ('4.2億', 1),
#      ('25.9億', 1),
#      ('10047', 1),
#      ('9727', 1),
#      ('9千', 1),
#      ('超過萬', 1),
#      ('1556', 1)]),
#    ('專題',
#     [('50', 54),
#      ('一半', 54),
#      ('20', 48),
#      ('40幾', 39),
#      ('48', 36),
#      ('10', 30),
#      ('近百', 27),
#      ('老二', 27),
#      ('70', 21),
#      ('百萬', 18),
#      ('18', 18),
#      ('15', 18),
#      ('一千萬', 18),
#      ('30', 18),
#      ('上百', 18),
#      ('8千', 18),
#      ('數十萬', 18),
#      ('3萬多', 12),
#      ('10萬', 12),
#      ('1百', 12),
#      ('5億', 12),
#      ('八比二', 9),
#      ('五比五', 9),
#      ('之一', 9),
#      ('7萬', 9),
#      ('20萬', 9),
#      ('九成', 9),
#      ('6千', 9),
#      ('10幾', 9),
#      ('六四分', 9),
#      ('七三分', 9),
#      ('三分之一', 9),
#      ('24', 6),
#      ('50多', 6),
#      ('400萬', 6),
#      ('4百萬', 6),
#      ('200', 6),
#      ('30萬', 6),
#      ('20幾萬', 6),
#      ('破百', 6),
#      ('2800萬', 3),
#      ('123', 3),
#      ('187', 3),
#      ('8萬', 3),
#      ('17', 3),
#      ('40萬', 3),
#      ('20幾', 3),
#      ('50萬', 3)]),
#    ('全球',
#     [('10', 31),
#      ('之一', 25),
#      ('19', 23),
#      ('2萬', 17),
#      ('16', 15),
#      ('23', 14),
#      ('82', 13),
#      ('20', 13),
#      ('31', 11),
#      ('11', 11),
#      ('30', 10),
#      ('1.9兆', 10),
#      ('數百', 10),
#      ('2019', 9),
#      ('100萬', 8),
#      ('15', 8),
#      ('21', 8),
#      ('14', 8),
#      ('25', 8),
#      ('12', 7),
#      ('50', 7),
#      ('三千', 7),
#      ('億萬', 7),
#      ('1萬', 6),
#      ('17', 6),
#      ('數十', 6),
#      ('一半', 6),
#      ('100', 6),
#      ('百萬', 6),
#      ('40', 6),
#      ('200', 5),
#      ('13', 5),
#      ('數千', 5),
#      ('33', 5),
#      ('400', 5),
#      ('60', 4),
#      ('98', 4),
#      ('30多', 4),
#      ('35', 4),
#      ('46', 4),
#      ('83', 4),
#      ('數百萬', 4),
#      ('34', 4),
#      ('2/3', 4),
#      ('500', 4),
#      ('68', 3),
#      ('23萬', 3),
#      ('470萬', 3),
#      ('77', 3),
#      ('300', 3),
#      ('7萬', 3),
#      ('18', 3),
#      ('1000多', 3),
#      ('2000', 3),
#      ('1000萬', 3),
#      ('20萬', 3),
#      ('26萬', 3),
#      ('70', 3),
#      ('322', 3),
#      ('3625', 3),
#      ('數以百萬', 3),
#      ('122', 3),
#      ('數以千計', 3),
#      ('200多', 3),
#      ('10萬', 3),
#      ('38', 3),
#      ('上百', 3),
#      ('90', 3),
#      ('十多', 3),
#      ('120', 3),
#      ('24', 3),
#      ('10多', 3),
#      ('22', 3),
#      ('5226', 3),
#      ('51', 2),
#      ('141', 2),
#      ('55', 2),
#      ('99', 2),
#      ('505', 2),
#      ('半數', 2),
#      ('27', 2),
#      ('1500萬', 2),
#      ('74萬', 2),
#      ('348', 2),
#      ('44', 2),
#      ('700萬', 2),
#      ('20多', 2),
#      ('81', 2),
#      ('67', 2),
#      ('69', 2),
#      ('80', 2),
#      ('1000', 2),
#      ('600', 2),
#      ('174', 2),
#      ('40多', 2),
#      ('1萬8180', 2),
#      ('58', 2),
#      ('415', 2),
#      ('92', 2),
#      ('2.0', 2),
#      ('580萬', 2),
#      ('4千', 2),
#      ('450', 2),
#      ('700', 2),
#      ('18萬', 2),
#      ('26', 2),
#      ('數以百計', 2),
#      ('234', 2),
#      ('2780', 2),
#      ('3014', 2),
#      ('3000', 2),
#      ('777', 2),
#      ('160多', 2),
#      ('47', 2),
#      ('113', 2),
#      ('30萬', 2),
#      ('168', 2),
#      ('10億', 2),
#      ('10餘', 2),
#      ('48', 2),
#      ('1800', 2),
#      ('180', 2),
#      ('43', 2),
#      ('千萬', 2),
#      ('50多', 2),
#      ('79', 2),
#      ('二十', 2),
#      ('1500', 2),
#      ('14億', 2),
#      ('132', 2),
#      ('250', 2),
#      ('600億', 2),
#      ('過萬', 2),
#      ('幾百萬', 2),
#      ('百餘', 1),
#      ('60餘', 1),
#      ('40餘', 1),
#      ('成千上萬', 1),
#      ('4714', 1),
#      ('4628', 1),
#      ('374', 1),
#      ('356', 1),
#      ('245', 1),
#      ('4340', 1),
#      ('4024', 1),
#      ('72', 1),
#      ('5153', 1),
#      ('21萬8945', 1),
#      ('11萬1906', 1),
#      ('33萬1097', 1),
#      ('6萬119', 1),
#      ('9333', 1),
#      ('3.23', 1),
#      ('數十萬', 1),
#      ('280', 1),
#      ('560萬', 1),
#      ('近500', 1),
#      ('70萬', 1),
#      ('1490萬', 1),
#      ('1660萬', 1),
#      ('48萬', 1),
#      ('破百萬', 1),
#      ('780', 1),
#      ('1400', 1),
#      ('63', 1),
#      ('12339', 1),
#      ('4級', 1),
#      ('158萬', 1),
#      ('14萬', 1),
#      ('8.4萬', 1),
#      ('63萬', 1),
#      ('7.56', 1),
#      ('4.24', 1),
#      ('2.74', 1),
#      ('65', 1),
#      ('85', 1),
#      ('十幾', 1),
#      ('十分之一', 1),
#      ('260', 1),
#      ('210', 1),
#      ('2500', 1),
#      ('105', 1),
#      ('6成', 1),
#      ('8300多', 1),
#      ('3100', 1),
#      ('500萬', 1),
#      ('2600萬', 1),
#      ('360萬', 1),
#      ('111,000', 1),
#      ('八成二', 1),
#      ('300萬', 1),
#      ('8640萬', 1),
#      ('780萬', 1),
#      ('21.3萬', 1),
#      ('150萬', 1),
#      ('40萬', 1),
#      ('1萬8000多', 1),
#      ('1萬300', 1),
#      ('911', 1),
#      ('約4萬', 1)]),
#    ('運動',
#     [('10', 80),
#      ('12', 46),
#      ('21', 38),
#      ('13', 37),
#      ('11', 29),
#      ('76', 28),
#      ('17', 28),
#      ('18', 27),
#      ('20', 27),
#      ('30', 26),
#      ('19', 25),
#      ('之一', 23),
#      ('23', 23),
#      ('15', 21),
#      ('14', 20),
#      ('16', 19),
#      ('29', 18),
#      ('22', 16),
#      ('40', 16),
#      ('二軍', 15),
#      ('28', 15),
#      ('38', 14),
#      ('24', 13),
#      ('26', 13),
#      ('100', 12),
#      ('25', 10),
#      ('108', 9),
#      ('33', 9),
#      ('50', 8),
#      ('3.2', 8),
#      ('47', 7),
#      ('99', 6),
#      ('二刀流', 6),
#      ('27', 6),
#      ('八千', 5),
#      ('2022', 5),
#      ('2:0', 5),
#      ('31', 5),
#      ('35', 5),
#      ('96', 5),
#      ('39', 5),
#      ('64', 5),
#      ('55', 5),
#      ('46', 5),
#      ('59', 5),
#      ('8三', 5),
#      ('43', 5),
#      ('6.02', 5),
#      ('120', 4),
#      ('41', 4),
#      ('48', 4),
#      ('101', 4),
#      ('6.2', 4),
#      ('10.3', 4),
#      ('109', 4),
#      ('34', 4),
#      ('24.8', 4),
#      ('百萬', 3),
#      ('3:0', 3),
#      ('457', 3),
#      ('60', 3),
#      ('103', 3),
#      ('6/23', 3),
#      ('09', 3),
#      ('2.5', 3),
#      ('5/9', 3),
#      ('98', 3),
#      ('70', 3),
#      ('110', 3),
#      ('1,700', 3),
#      ('78', 3),
#      ('150', 3),
#      ('4.6', 3),
#      ('4.1', 3),
#      ('14.1', 3),
#      ('2.7', 3),
#      ('12.1', 3),
#      ('3.7', 3),
#      ('75', 3),
#      ('0.3', 3),
#      ('4.8', 3),
#      ('一百', 3),
#      ('十四', 2),
#      ('18.8', 2),
#      ('1000', 2),
#      ('8分7', 2),
#      ('56', 2),
#      ('400多', 2),
#      ('2.7億', 2),
#      ('千萬', 2),
#      ('1:1', 2),
#      ('8萬多', 2),
#      ('119', 2),
#      ('117', 2),
#      ('9三', 2),
#      ('一軍', 2),
#      ('116', 2),
#      ('14.20', 2),
#      ('20.1', 2),
#      ('2.3', 2),
#      ('95', 2),
#      ('134', 2),
#      ('105', 2),
#      ('3.18', 2),
#      ('16萬', 2),
#      ('44', 2),
#      ('500', 2),
#      ('128', 2),
#      ('三元', 2),
#      ('106', 2),
#      ('700', 2),
#      ('T1', 2),
#      ('25.4', 2),
#      ('2.2', 2),
#      ('2.1', 2),
#      ('17.5', 2),
#      ('1.9', 2),
#      ('48.5', 2),
#      ('2比1', 2),
#      ('136', 2),
#      ('102', 2),
#      ('204', 2),
#      ('20.7', 2),
#      ('202', 2),
#      ('5.5', 2),
#      ('37', 2),
#      ('30.3', 2),
#      ('91.3', 2),
#      ('7.9', 2),
#      ('54', 2),
#      ('億萬', 2),
#      ('51億', 2),
#      ('1:0', 2),
#      ('112', 2),
#      ('0.276', 1),
#      ('05/03', 1),
#      ('5三', 1),
#      ('5/5', 1),
#      ('3億', 1),
#      ('20萬', 1),
#      ('559', 1),
#      ('549', 1),
#      ('232.0', 1),
#      ('236.3', 1),
#      ('近百萬', 1),
#      ('1500', 1),
#      ('160', 1),
#      ('27.8', 1),
#      ('幾百', 1),
#      ('81.8', 1),
#      ('1-4', 1),
#      ('5.1', 1),
#      ('94', 1),
#      ('91', 1),
#      ('31分12', 1),
#      ('五十', 1),
#      ('6/6', 1),
#      ('2.0', 1),
#      ('17.8', 1),
#      ('300', 1),
#      ('1129', 1),
#      ('1396', 1),
#      ('2011', 1),
#      ('2012', 1),
#      ('13萬', 1),
#      ('82973', 1),
#      ('7/8', 1),
#      ('02', 1),
#      ('01', 1),
#      ('09:56:00', 1),
#      ('09:30-10:00', 1),
#      ('190', 1),
#      ('5千', 1),
#      ('2.76', 1),
#      ('0.1', 1),
#      ('1.67', 1),
#      ('3成50', 1),
#      ('87', 1),
#      ('171', 1),
#      ('破百', 1),
#      ('2萬', 1),
#      ('2萬5', 1),
#      ('31分9', 1),
#      ('3三', 1),
#      ('2+1', 1),
#      ('10.5', 1),
#      ('3.3', 1),
#      ('5/7', 1),
#      ('6:1', 1),
#      ('+36', 1),
#      ('2004', 1),
#      ('81', 1),
#      ('458', 1),
#      ('1分9', 1),
#      ('1.3萬', 1),
#      ('3000', 1),
#      ('13.91', 1),
#      ('破萬', 1),
#      ('13.1萬', 1),
#      ('2400萬', 1)]),
#    ('全部',
#     [('10', 286),
#      ('之一', 174),
#      ('12', 155),
#      ('20', 148),
#      ('18', 123),
#      ('50', 122),
#      ('19', 120),
#      ('30', 119),
#      ('百萬', 113),
#      ('11', 110),
#      ('14', 110),
#      ('一半', 104),
#      ('15', 103),
#      ('21', 100),
#      ('13', 80),
#      ('16', 79),
#      ('17', 73),
#      ('100', 72),
#      ('23', 57),
#      ('60', 55),
#      ('40', 54),
#      ('48', 53),
#      ('24', 52),
#      ('100萬', 50),
#      ('25', 49),
#      ('70', 49),
#      ('20萬', 47),
#      ('1萬', 45),
#      ('119', 44),
#      ('10萬', 42),
#      ('2萬', 41),
#      ('76', 41),
#      ('200萬', 39),
#      ('40幾', 39),
#      ('29', 34),
#      ('200', 33),
#      ('400萬', 32),
#      ('22', 32),
#      ('300', 31),
#      ('500', 31),
#      ('38', 31),
#      ('千萬', 31),
#      ('33', 30),
#      ('80', 29),
#      ('近百', 29),
#      ('26', 28),
#      ('5萬', 28),
#      ('27', 27),
#      ('31', 27),
#      ('老二', 27),
#      ('28', 26),
#      ('上百', 26),
#      ('7萬', 24),
#      ('3萬', 23),
#      ('2000', 23),
#      ('2019', 23),
#      ('破萬', 23),
#      ('2022', 22),
#      ('8千', 22),
#      ('1000', 21),
#      ('46', 21),
#      ('二軍', 21),
#      ('1億', 20),
#      ('113', 20),
#      ('120', 20),
#      ('400', 20),
#      ('數百', 20),
#      ('40萬', 20),
#      ('35', 20),
#      ('數十萬', 20),
#      ('一千萬', 20),
#      ('41', 19),
#      ('55', 19),
#      ('34', 19),
#      ('82', 19),
#      ('萬六', 18),
#      ('108', 18),
#      ('5億', 18),
#      ('101', 18),
#      ('42', 17),
#      ('三千', 17),
#      ('70萬', 17),
#      ('30萬', 17),
#      ('6/10', 17),
#      ('71', 17),
#      ('6千', 17),
#      ('7+7', 16),
#      ('1980', 16),
#      ('1995', 16),
#      ('110', 16),
#      ('2.0', 16),
#      ('3000', 16),
#      ('47', 16),
#      ('124', 16),
#      ('99', 16),
#      ('1.9兆', 15),
#      ('96', 15),
#      ('1000萬', 15),
#      ('78', 15),
#      ('150萬', 15),
#      ('54', 14),
#      ('上千', 14),
#      ('3/4', 14),
#      ('58', 14),
#      ('36', 14),
#      ('數十', 14),
#      ('95', 14),
#      ('3萬多', 14),
#      ('3+4', 13),
#      ('50萬', 13),
#      ('192', 13),
#      ('800', 13),
#      ('90', 13),
#      ('6萬', 13),
#      ('2.5萬', 13),
#      ('三分之一', 13),
#      ('500萬', 13),
#      ('九成', 13),
#      ('1百', 13),
#      ('1700萬', 12),
#      ('73萬', 12),
#      ('600', 12),
#      ('64', 12),
#      ('數百萬', 12),
#      ('數千', 12),
#      ('4萬', 12),
#      ('57', 12),
#      ('10幾', 12),
#      ('123', 11),
#      ('700', 11),
#      ('12萬', 11),
#      ('77', 11),
#      ('300萬', 11),
#      ('130萬', 11),
#      ('86', 11),
#      ('59', 11),
#      ('6/30', 11),
#      ('8萬', 11),
#      ('一百萬', 11),
#      ('180', 11),
#      ('2:0', 11),
#      ('830', 11),
#      ('3.2', 11),
#      ('98', 10),
#      ('33萬', 10),
#      ('5.2萬', 10),
#      ('億萬', 10),
#      ('50多', 10),
#      ('102', 10),
#      ('2萬多', 10),
#      ('一百', 10),
#      ('43', 10),
#      ('60萬', 10),
#      ('36萬', 10),
#      ('二刀流', 10),
#      ('破百', 10),
#      ('83', 9),
#      ('十幾', 9),
#      ('140', 9),
#      ('8萬多', 9),
#      ('0800', 9),
#      ('5,000萬', 9),
#      ('68', 9),
#      ('73', 9),
#      ('5000萬', 9),
#      ('49', 9),
#      ('6/12', 9),
#      ('10億', 9),
#      ('85', 9),
#      ('2022.05.09', 9),
#      ('109', 9),
#      ('4、5', 9),
#      ('八千', 9),
#      ('6/1', 9),
#      ('3億', 9),
#      ('1200萬', 9),
#      ('八比二', 9),
#      ('五比五', 9),
#      ('六四分', 9),
#      ('七三分', 9),
#      ('1500', 8),
#      ('00', 8),
#      ('37', 8),
#      ('1925', 8),
#      ('22萬', 8),
#      ('32', 8),
#      ('322', 8),
#      ('87', 8),
#      ('240', 8),
#      ('66', 8),
#      ('10多', 8),
#      ('200多', 8),
#      ('201萬', 8),
#      ('520', 8),
#      ('5/8', 8),
#      ('5千', 8),
#      ('6/6', 8),
#      ('16萬', 8),
#      ('30多', 8),
#      ('13萬', 8)])]],
#  ['DATE',
#   [('焦點',
#     [('今天', 270),
#      ('今年', 72),
#      ('今日', 55),
#      ('昨天', 48),
#      ('去年', 42),
#      ('6月', 32),
#      ('3天', 26),
#      ('今（14）日', 24),
#      ('2020年', 23),
#      ('4月', 23),
#      ('5月', 23),
#      ('明天', 21),
#      ('13日', 19),
#      ('昨日', 18),
#      ('2019年', 16),
#      ('12日', 16),
#      ('2021年', 15),
#      ('近年', 15),
#      ('明日', 15),
#      ('20年', 14),
#      ('7天', 13),
#      ('當天', 13),
#      ('3月', 13),
#      ('2016年', 13),
#      ('2022年', 13),
#      ('6日', 12),
#      ('4個月', 12),
#      ('年底', 11),
#      ('近日', 11),
#      ('1日', 11),
#      ('4天', 10),
#      ('2歲', 10),
#      ('7月', 10),
#      ('3年', 10),
#      ('1年', 10),
#      ('2月24日', 9),
#      ('今（7）日', 9),
#      ('2年', 9),
#      ('18歲', 9),
#      ('6月底', 9),
#      ('一天', 9),
#      ('6月1日', 9),
#      ('30年', 9),
#      ('下半年', 9),
#      ('65歲', 9),
#      ('2014年', 9),
#      ('2018年', 9),
#      ('一年', 9),
#      ('6個月', 8),
#      ('前一天', 8),
#      ('10日', 8),
#      ('4日', 8),
#      ('今（8）日', 8),
#      ('2019', 8),
#      ('27年', 8),
#      ('21日', 8),
#      ('2日', 8),
#      ('5月底', 7),
#      ('9月', 7),
#      ('5天', 7),
#      ('明年', 7),
#      ('一週', 7),
#      ('這幾年', 7),
#      ('本週', 7),
#      ('兩天', 7),
#      ('2017年', 7),
#      ('8月', 7),
#      ('2月', 7),
#      ('這幾天', 6),
#      ('4月底', 6),
#      ('2天', 6),
#      ('5歲', 6),
#      ('8日', 6),
#      ('5月28日', 6),
#      ('3個月', 6),
#      ('10天', 6),
#      ('上週', 6),
#      ('上週四', 6),
#      ('22歲', 6),
#      ('1972年', 6),
#      ('14日', 6),
#      ('5月15日', 6),
#      ('30日', 6),
#      ('3日', 6),
#      ('110年', 5),
#      ('今年3月', 5),
#      ('6至11歲', 5),
#      ('日前', 5),
#      ('6年', 5),
#      ('2008年', 5),
#      ('半年', 5),
#      ('1天', 5),
#      ('10年', 5),
#      ('當年', 5),
#      ('一個月', 5),
#      ('多年', 5),
#      ('1986年', 5),
#      ('今（12）日', 5),
#      ('5月14日', 5),
#      ('16日', 5),
#      ('5月11日', 5),
#      ('週末', 5),
#      ('30天', 5),
#      ('20歲', 5),
#      ('20多歲', 5),
#      ('端午節', 5),
#      ('今（25）日', 5),
#      ('40歲', 5),
#      ('27日', 5),
#      ('21世紀', 5),
#      ('29日', 5),
#      ('5月27日', 5),
#      ('今（4）日', 5),
#      ('5日', 4),
#      ('1個月', 4),
#      ('2023年', 4),
#      ('11日', 4),
#      ('5月30日', 4),
#      ('6月16日', 4),
#      ('幾天', 4),
#      ('7日', 4),
#      ('9日', 4),
#      ('上週一', 4),
#      ('週一', 4),
#      ('2009年', 4),
#      ('8年', 4),
#      ('5年', 4),
#      ('5月12日', 4),
#      ('本周', 4),
#      ('1994年', 4),
#      ('1980年', 4),
#      ('5月2日', 4),
#      ('50週年', 4),
#      ('今年5月', 4),
#      ('本月', 4),
#      ('5月16日', 4),
#      ('7個月', 4),
#      ('上個月', 4),
#      ('23日', 4),
#      ('6月4日', 4),
#      ('當日', 4),
#      ('5月初', 4),
#      ('2003年', 4),
#      ('9個月', 4),
#      ('31日', 4),
#      ('6月10日', 4),
#      ('三個月', 4),
#      ('今（3）日', 4),
#      ('上月', 3),
#      ('這個月', 3),
#      ('下週', 3),
#      ('19年', 3),
#      ('4月30日', 3),
#      ('5月26日', 3),
#      ('62歲', 3),
#      ('過去幾年', 3),
#      ('5月25日', 3),
#      ('4歲', 3),
#      ('6月2日', 3),
#      ('6月6日', 3),
#      ('5月31日', 3),
#      ('2025年', 3),
#      ('幾十年', 3),
#      ('12歲', 3),
#      ('5月17日', 3),
#      ('45歲', 3),
#      ('1945年', 3),
#      ('2月底', 3),
#      ('上週同日', 3),
#      ('957天', 3),
#      ('1989年', 3),
#      ('2個月', 3),
#      ('12）日', 3),
#      ('2010年', 3),
#      ('5月10日', 3),
#      ('下週一', 3),
#      ('下週二', 3),
#      ('8天', 3),
#      ('3歲', 3),
#      ('14）日', 3),
#      ('2013年', 3),
#      ('32年', 3),
#      ('兩個月', 3),
#      ('去年11月', 3),
#      ('29歲', 3),
#      ('65歲以上', 3),
#      ('28歲', 3),
#      ('兩週', 3),
#      ('5個月', 3),
#      ('2027年', 3),
#      ('數月', 3),
#      ('5月21日', 3),
#      ('19日', 3),
#      ('今年2月', 3),
#      ('上週五', 3),
#      ('第二天', 3),
#      ('5月13日', 3),
#      ('2015年', 3),
#      ('5月23日', 3),
#      ('22日', 3)]),
#    ('要聞',
#     [('今天', 115),
#      ('今日', 95),
#      ('今年', 73),
#      ('去年', 55),
#      ('昨天', 27),
#      ('年底', 24),
#      ('今（9）日', 20),
#      ('3天', 19),
#      ('昨日', 19),
#      ('端午節', 18),
#      ('7月', 16),
#      ('2年', 14),
#      ('6月1日', 13),
#      ('2022年', 13),
#      ('5天', 13),
#      ('今（6）日', 12),
#      ('上週', 12),
#      ('6月', 12),
#      ('7天', 12),
#      ('明天', 12),
#      ('今（10）日', 12),
#      ('一天', 11),
#      ('5月', 11),
#      ('明日', 11),
#      ('近日', 11),
#      ('今（8）日', 11),
#      ('5月22日', 10),
#      ('8日', 10),
#      ('30年', 10),
#      ('4月', 10),
#      ('1年', 10),
#      ('今（30）日', 10),
#      ('21世紀', 10),
#      ('六四', 10),
#      ('三天', 9),
#      ('2週', 9),
#      ('一年', 9),
#      ('2027年', 9),
#      ('2歲', 9),
#      ('4天', 8),
#      ('今（7）日', 8),
#      ('9日', 8),
#      ('2天', 8),
#      ('下週', 8),
#      ('本週', 8),
#      ('今（5）日', 7),
#      ('6年', 7),
#      ('6月10日', 7),
#      ('6月底', 7),
#      ('當天', 7),
#      ('5月10日', 7),
#      ('去年6月', 7),
#      ('今（31）日', 7),
#      ('今（2）日', 7),
#      ('5月底', 6),
#      ('2018年', 6),
#      ('一週', 6),
#      ('5日', 6),
#      ('這幾天', 6),
#      ('8月', 6),
#      ('6月4日', 6),
#      ('2017年', 6),
#      ('1月', 6),
#      ('110年', 6),
#      ('下半年', 6),
#      ('2日', 6),
#      ('母親節', 5),
#      ('12日', 5),
#      ('5月9日', 5),
#      ('1週', 5),
#      ('2024年', 5),
#      ('今年2月', 5),
#      ('半年', 5),
#      ('近年', 5),
#      ('這兩天', 5),
#      ('7日', 5),
#      ('10天', 5),
#      ('2個月', 5),
#      ('4月28日', 5),
#      ('9月', 5),
#      ('第一季', 5),
#      ('今（14）日', 5),
#      ('今（23）日', 5),
#      ('5歲', 5),
#      ('本周', 5),
#      ('22日', 5),
#      ('5月27日', 5),
#      ('今（24）日', 5),
#      ('30）日', 5),
#      ('2015年', 5),
#      ('2014年', 4),
#      ('兩週', 4),
#      ('5月5日', 4),
#      ('5月12日', 4),
#      ('5月17日', 4),
#      ('113學年度', 4),
#      ('去年下半年', 4),
#      ('前一天', 4),
#      ('4個月', 4),
#      ('2月', 4),
#      ('5月28日', 4),
#      ('最後一天', 4),
#      ('111年', 4),
#      ('111學年度', 4),
#      ('7至18歲', 4),
#      ('2019年', 4),
#      ('這兩年', 4),
#      ('5月8日', 4),
#      ('23日', 4),
#      ('2013年', 4),
#      ('2023年', 4),
#      ('2016年', 4),
#      ('七月', 4),
#      ('26日', 4),
#      ('2026年', 4),
#      ('今（11）日', 4),
#      ('27日', 4),
#      ('6月30日', 4),
#      ('6月3日', 4),
#      ('今（1）日', 4),
#      ('一周', 3),
#      ('20日', 3),
#      ('2、3天', 3),
#      ('5月23日', 3),
#      ('5月20日', 3),
#      ('16日到23日', 3),
#      ('40年', 3),
#      ('109年', 3),
#      ('4月30日', 3),
#      ('8年', 3),
#      ('114學年度', 3),
#      ('5年', 3),
#      ('2021年', 3),
#      ('5月3日', 3),
#      ('6天', 3),
#      ('一年內', 3),
#      ('6日', 3),
#      ('12歲', 3),
#      ('5月29日', 3),
#      ('11天', 3),
#      ('6月6日', 3),
#      ('第一天', 3),
#      ('12年', 3),
#      ('2012年', 3),
#      ('週五', 3),
#      ('下週一', 3),
#      ('近幾日', 3),
#      ('7月17日', 3),
#      ('今（9日', 3),
#      ('週三', 3),
#      ('8年6月', 3),
#      ('3日', 3),
#      ('5月2日', 3),
#      ('5月6日', 3),
#      ('這天', 3),
#      ('5月7日', 3),
#      ('數十年', 3),
#      ('14天', 3),
#      ('五天', 3),
#      ('2020年', 3),
#      ('3年', 3),
#      ('23）日', 3),
#      ('全年', 3),
#      ('10年', 3),
#      ('五一勞動節', 3),
#      ('6月5日', 3),
#      ('一整天', 3),
#      ('6月18日', 3),
#      ('5至11歲', 3),
#      ('明年', 3),
#      ('四年', 3),
#      ('9月至12月底', 3),
#      ('7年前', 3),
#      ('5月31日', 3),
#      ('5月21日', 3),
#      ('0-4歲', 3),
#      ('今（3）日', 3),
#      ('百年', 3),
#      ('33周年', 3),
#      ('去年10月', 3),
#      ('1968年', 3),
#      ('今（4）日', 3),
#      ('上月', 2),
#      ('國慶日', 2),
#      ('民國九二年', 2),
#      ('今年3月', 2),
#      ('今年底', 2),
#      ('18日至20日', 2),
#      ('一個月', 2),
#      ('兩個月', 2),
#      ('2025年', 2),
#      ('端午', 2),
#      ('2021）年', 2),
#      ('92年', 2),
#      ('下周一', 2),
#      ('10年2月', 2),
#      ('4月11日', 2),
#      ('過去幾年', 2),
#      ('5月30日', 2),
#      ('114學年', 2)]),
#    ('即時',
#     [('今天', 322),
#      ('今年', 97),
#      ('去年', 68),
#      ('今日', 67),
#      ('母親節', 65),
#      ('今（9）日', 44),
#      ('昨天', 40),
#      ('8日', 30),
#      ('明天', 24),
#      ('2019年', 23),
#      ('3天', 23),
#      ('7日', 22),
#      ('4月', 21),
#      ('9日', 21),
#      ('5月', 21),
#      ('7天', 21),
#      ('一天', 20),
#      ('2016年', 18),
#      ('2021年', 17),
#      ('本週', 17),
#      ('昨日', 17),
#      ('4天', 15),
#      ('40歲', 15),
#      ('2022年', 15),
#      ('6年', 14),
#      ('2020年', 14),
#      ('近日', 14),
#      ('近年', 14),
#      ('6日', 14),
#      ('2個月', 14),
#      ('2018年', 14),
#      ('上週', 14),
#      ('5月8日', 13),
#      ('3年', 13),
#      ('今(9)日', 13),
#      ('20年', 13),
#      ('2月24日', 12),
#      ('6月', 12),
#      ('夏天', 12),
#      ('5年', 12),
#      ('一年', 11),
#      ('2年', 11),
#      ('2014年', 11),
#      ('5天', 11),
#      ('5月9日', 11),
#      ('兩年', 11),
#      ('這天', 11),
#      ('25歲', 11),
#      ('明日', 10),
#      ('7年', 10),
#      ('當天', 10),
#      ('7月', 10),
#      ('4年', 10),
#      ('10年', 10),
#      ('兩天', 10),
#      ('本周', 9),
#      ('3個月', 9),
#      ('一個月', 9),
#      ('2歲', 9),
#      ('這幾天', 9),
#      ('一週', 9),
#      ('18歲', 9),
#      ('三天', 9),
#      ('上個月', 8),
#      ('日前', 8),
#      ('2天', 8),
#      ('6月底', 8),
#      ('10日', 8),
#      ('今（8）日', 8),
#      ('4日', 8),
#      ('10天', 8),
#      ('今年4月', 8),
#      ('三個月', 8),
#      ('明年', 7),
#      ('5歲', 7),
#      ('2017年', 7),
#      ('今（7）日', 7),
#      ('1日', 7),
#      ('30年', 7),
#      ('3月', 7),
#      ('1年', 7),
#      ('上月', 7),
#      ('12日', 7),
#      ('14歲', 7),
#      ('元年', 7),
#      ('下個月', 6),
#      ('20歲', 6),
#      ('4月底', 6),
#      ('1個月', 6),
#      ('19歲', 6),
#      ('4個月', 6),
#      ('40年', 6),
#      ('2008年', 6),
#      ('8年6月', 6),
#      ('6月1日', 6),
#      ('這幾年', 6),
#      ('45歲', 6),
#      ('3歲', 6),
#      ('26歲', 6),
#      ('8月', 6),
#      ('8歲', 6),
#      ('4月28日', 6),
#      ('21世紀', 6),
#      ('年底', 5),
#      ('27歲', 5),
#      ('幾天', 5),
#      ('半年', 5),
#      ('1天', 5),
#      ('28歲', 5),
#      ('11日', 5),
#      ('2月', 5),
#      ('5月12日', 5),
#      ('8）日', 5),
#      ('5月11日', 5),
#      ('週四', 5),
#      ('週五', 5),
#      ('1986年', 5),
#      ('數十年', 5),
#      ('2013年', 5),
#      ('9個月', 5),
#      ('1996年', 5),
#      ('27日', 5),
#      ('31日', 5),
#      ('一整天', 4),
#      ('今年3月', 4),
#      ('2023年', 4),
#      ('4月30日', 4),
#      ('前一天', 4),
#      ('2025年', 4),
#      ('6月3日', 4),
#      ('21年', 4),
#      ('65歲', 4),
#      ('上週一', 4),
#      ('957天', 4),
#      ('勝利日', 4),
#      ('4月27日', 4),
#      ('2日', 4),
#      ('下週一', 4),
#      ('週末', 4),
#      ('7歲', 4),
#      ('年初', 4),
#      ('今（9日', 4),
#      ('週三', 4),
#      ('5月底', 4),
#      ('2到3周', 4),
#      ('五月', 4),
#      ('37歲', 4),
#      ('11年', 4),
#      ('36歲', 4),
#      ('開齋節', 4),
#      ('28日', 4),
#      ('9年', 4),
#      ('32歲', 4),
#      ('去年9月', 4),
#      ('15日', 4),
#      ('13日', 4),
#      ('近幾年', 4),
#      ('當日', 4),
#      ('聖誕節', 4),
#      ('1個多月', 4),
#      ('24日', 4),
#      ('5年2月', 4),
#      ('2003年', 4),
#      ('5月28日', 4),
#      ('30日', 4),
#      ('29日', 4),
#      ('13天', 3),
#      ('34歲', 3),
#      ('5日', 3),
#      ('6歲', 3),
#      ('十年', 3),
#      ('41歲', 3),
#      ('60多歲', 3),
#      ('62歲', 3),
#      ('25年', 3),
#      ('2012年', 3),
#      ('42歲', 3),
#      ('5月31日', 3),
#      ('7、8年', 3),
#      ('2009年', 3),
#      ('8年', 3),
#      ('4月29日', 3),
#      ('前幾天', 3),
#      ('昨（8）日', 3),
#      ('4歲', 3),
#      ('9月', 3),
#      ('數週', 3),
#      ('過去幾年', 3),
#      ('這兩年', 3),
#      ('3日', 3),
#      ('8個月', 3),
#      ('5月20日', 3),
#      ('全年', 3),
#      ('三年', 3),
#      ('16日', 3),
#      ('23日', 3),
#      ('5月7日', 3),
#      ('這些年', 3),
#      ('2011年', 3),
#      ('5月2日', 3)]),
#    ('娛樂',
#     [('今天', 39),
#      ('去年', 36),
#      ('今年', 30),
#      ('昨天', 22),
#      ('一天', 15),
#      ('26歲', 14),
#      ('6年', 13),
#      ('20年', 13),
#      ('30歲', 13),
#      ('近日', 13),
#      ('今日', 12),
#      ('20歲', 12),
#      ('27歲', 11),
#      ('25歲', 11),
#      ('2020年', 10),
#      ('24歲', 10),
#      ('40歲', 10),
#      ('8個月', 10),
#      ('2年', 9),
#      ('半年', 9),
#      ('3個月', 9),
#      ('2個月', 9),
#      ('7年', 9),
#      ('2017年', 9),
#      ('35歲', 9),
#      ('2015年', 9),
#      ('6歲', 9),
#      ('近年', 8),
#      ('2019年', 8),
#      ('一年', 8),
#      ('1年', 8),
#      ('2018年', 8),
#      ('去年底', 8),
#      ('昨日', 7),
#      ('10日', 7),
#      ('19歲', 7),
#      ('當天', 7),
#      ('41歲', 7),
#      ('17年', 7),
#      ('1年多', 7),
#      ('3日', 7),
#      ('5月', 6),
#      ('3年', 6),
#      ('5年', 6),
#      ('夏天', 6),
#      ('8日', 6),
#      ('5歲', 6),
#      ('16歲', 6),
#      ('1日', 6),
#      ('本週', 6),
#      ('57歲', 6),
#      ('下半年', 5),
#      ('42歲', 5),
#      ('2歲', 5),
#      ('2天', 5),
#      ('前年', 5),
#      ('4月', 5),
#      ('11年前', 5),
#      ('上月', 5),
#      ('9月', 5),
#      ('2月', 5),
#      ('1個月', 5),
#      ('36歲', 5),
#      ('32歲', 5),
#      ('今年1月', 5),
#      ('2016年', 5),
#      ('8年', 5),
#      ('11日', 5),
#      ('15年', 5),
#      ('6月', 5),
#      ('3歲', 5),
#      ('10年', 4),
#      ('3月', 4),
#      ('44歲', 4),
#      ('今（7）日', 4),
#      ('多年', 4),
#      ('6月24日', 4),
#      ('明年', 4),
#      ('隔年', 4),
#      ('9日', 4),
#      ('37歲', 4),
#      ('母親節', 4),
#      ('64歲', 4),
#      ('21歲', 4),
#      ('2021年', 4),
#      ('2010年', 4),
#      ('3天', 4),
#      ('六年', 4),
#      ('11年', 4),
#      ('23日', 4),
#      ('28歲', 4),
#      ('29日', 4),
#      ('28日', 4),
#      ('31日', 4),
#      ('2日', 4),
#      ('22歲', 4),
#      ('去年10月', 3),
#      ('4個月', 3),
#      ('40年', 3),
#      ('6日', 3),
#      ('那天', 3),
#      ('6）日', 3),
#      ('12歲', 3),
#      ('5月27日', 3),
#      ('4日', 3),
#      ('今年初', 3),
#      ('6天', 3),
#      ('5月13日', 3),
#      ('2013年', 3),
#      ('第一天', 3),
#      ('年初', 3),
#      ('去年7月', 3),
#      ('7月', 3),
#      ('三個月', 3),
#      ('47歲', 3),
#      ('昨（9）日', 3),
#      ('2005年', 3),
#      ('18歲', 3),
# ...
#      ('雪梨晨驅報', 1),
#      ('伊美黛', 1),
#      ('星島日報', 1),
#      ('News1', 1),
#      ('美麗島電子報', 1),
#      ('九歌', 1),
#      ('台北國際書展大獎', 1),
#      ('金蝶獎', 1),
#      ('金鼎獎', 1),
#      ('金漫獎', 1),
#      ('財星', 1),
#      ('上海封控成本考', 1),
#      ('HOME', 1),
#      ('小輓', 1),
#      ('情批', 1),
#      ('北京遊', 1),
#      ('川貝母', 1),
#      ('棄貓', 1),
#      ('欸？我說到哪裡了？', 1),
#      ('反差的我', 1),
#      ('Countdown', 1),
#      ('King', 1),
#      ('全世界暫停', 1),
#      ('Touchme', 1),
#      ('迷霧', 1),
#      ('▲原子少年售票演唱會', 1),
#      ('原子少年', 1),
#      ('原子少年ATOMBOYZ', 1),
#      ('今日廣場', 1),
#      ('日經亞洲', 1),
#      ('水行俠2', 1),
#      ('VanityFair', 1),
#      ('決戰水下伸展台', 1),
#      ('爆廢公社公開版', 1),
#      ('新聞周刊', 1)]),
#    ('要聞',
#     [('NOWnews今日新聞', 19),
#      ('今日新聞', 4),
#      ('今日廣場', 3),
#      ('東方紅', 2),
#      ('甘露水', 1),
#      ('火神的眼淚', 1),
#      ('火神的眼淚＿侯導篇', 1),
#      ('全球防衛雜誌', 1),
#      ('HOME', 1),
#      ('小輓', 1),
#      ('情批', 1),
#      ('北京遊', 1),
#      ('川貝母', 1),
#      ('棄貓', 1),
#      ('耶路撒冷郵報', 1),
#      ('土樓印象', 1),
#      ('緬懷', 1),
#      ('進擊的巨人', 1),
#      ('激流與倒影', 1),
#      ('穿越福爾摩沙1630-1930：法國人眼中的台灣印象', 1),
#      ('未來的光陰：給台灣新電影四十年的備忘錄', 1)]),
#    ('即時',
#     [('NOWnews今日新聞', 18),
#      ('今日新聞', 11),
#      ('原子少年', 9),
#      ('衣袖紅鑲邊', 7),
#      ('百想藝術大賞', 6),
#      ('二十五，二十一', 4),
#      ('D.P：逃兵追緝令', 4),
#      ('魷魚遊戲', 4),
#      ('金牌', 4),
#      ('死亡預報', 4),
#      ('親愛的亞當', 4),
#      ('愛你', 4),
#      ('以吾之名', 3),
#      ('那不是雪中紅', 3),
#      ('財閥家的小兒子', 3),
#      ('來吧！營業中', 3),
#      ('日經亞洲', 3),
#      ('乘風破浪', 3),
#      ('戀慕', 2),
#      ('地獄公使', 2),
#      ('神探具景伊', 2),
#      ('D.P', 2),
#      ('家族', 2),
#      ('開朗少女成功記', 2),
#      ('久違的再見', 2),
#      ('命中注定我愛你', 2),
#      ('OnePiece', 2),
#      ('海賊王', 2),
#      ('華燈初上', 2),
#      ('原子', 2),
#      ('二十一', 2),
#      ('少年法庭', 2),
#      ('羅希度', 2),
#      ('ThoseThatFollow', 2),
#      ('科幻小說', 2),
#      ('天若有情', 2),
#      ('NOWnews', 2),
#      ('每日電訊報', 2),
#      ('第六感之吻', 2),
#      ('文化獎', 2),
#      ('日本味', 2),
#      ('36題愛上你', 2),
#      ('臨終', 2),
#      ('食尚', 2),
#      ('一家團圓', 2),
#      ('中國日報', 2),
#      ('旺好運', 2),
#      ('與你襄愛', 2),
#      ('n@nownews.com名家論壇', 1),
#      ('萬安警報', 1),
#      ('台上，一路', 1),
#      ('Tracer', 1),
#      ('新聞不芹菜', 1),
#      ('童顏女神', 1),
#      ('我們的藍調時光', 1),
#      ('柔美2', 1),
#      ('少年吔', 1),
#      ('獵人', 1),
#      ('民雄鬼屋', 1),
#      ('隱娘', 1),
#      ('俗女養成記', 1),
#      ('如懿傳', 1),
#      ('自由時報', 1),
#      ('重出江湖', 1),
#      ('爆系故事館', 1),
#      ('郭婞淳：舉重若輕的婞念', 1),
#      ('新京報', 1),
#      ('盛典', 1),
#      ('百想', 1),
#      ('韓素希', 1),
#      ('金憓秀', 1),
#      ('金泰梨', 1),
#      ('她很漂亮', 1),
#      ('W－兩個世界', 1),
#      ('成均館緋聞', 1),
#      ('60天，指定倖存者', 1),
#      ('愛愛內含光', 1),
#      ('如果可以', 1),
#      ('R.I.P.', 1),
#      ('CheapLove', 1),
#      ('Yout', 1),
#      ('先不要', 1),
#      ('南韓電影', 1),
#      ('在你面前', 1),
#      ('明仔載', 1),
#      ('怪胎', 1),
#      ('同學來了', 1),
#      ('飛龍在天', 1),
#      ('意難忘', 1),
#      ('21歲', 1),
#      ('同學麥娜絲', 1),
#      ('同學麥娜', 1),
#      ('tars流星', 1),
#      ('無法抗拒的他', 1),
#      ('流星', 1),
#      ('ShootingStars流星', 1),
#      ('聲聲不息', 1),
#      ('迷電影', 1),
#      ('澳洲人報', 1),
#      ('深化藍色經濟合作備忘錄', 1),
#      ('中國好聲音', 1),
#      ('青春有你', 1),
#      ('夢想藍圖', 1),
#      ('啟程', 1),
#      ('超跑情人夢', 1),
#      ('83－37', 1),
#      ('羅志祥', 1),
#      ('九天玄女Remix', 1),
#      ('鐵達尼號', 1),
#      ('Myhea', 1),
#      ('席琳狄翁', 1),
#      ('今日廣場', 1),
#      ('女人我最大', 1),
#      ('倩女幽魂', 1),
#      ('美麗上海', 1),
#      ('覺醒家庭', 1),
#      ('衛報', 1),
#      ('基因', 1),
#      ('女性SEVEN', 1),
#      ('夫婦的世界', 1),
#      ('你好，我是誰', 1),
#      ('普立茲克獎', 1),
#      ('Joeman', 1),
#      ('諾貝爾物理學獎', 1),
#      ('肯尼NOW星球', 1),
#      ('愛的迫降', 1),
#      ('行政院文化獎', 1),
#      ('包浩斯', 1),
#      ('亞洲首展', 1),
#      ('Tomo桑', 1),
#      ('九歌', 1),
#      ('台北國際書展大獎', 1),
#      ('金蝶獎', 1),
#      ('金鼎獎', 1),
#      ('金漫獎', 1),
#      ('五妹娘', 1),
#      ('上海封控成本考', 1),
#      ('浪漫滿屋', 1),
#      ('他們的世界', 1),
#      ('宋慧喬I', 1),
#      ('北京日報', 1),
#      ('當你', 1),
#      ('睫毛彎彎', 1),
#      ('變成陌生人', 1),
#      ('ELLE', 1),
#      ('微笑PASTA', 1),
#      ('西街少年', 1),
#      ('天國的嫁衣', 1),
#      ('圖／翻攝', 1),
#      ('欸？我說到哪裡了？', 1),
#      ('小時代', 1),
#      ('苗可麗', 1),
#      ('人民日報', 1),
#      ('醜聞', 1),
#      ('弒婚遊戲', 1),
#      ('綜藝大哥大', 1),
#      ('營業', 1),
#      ('激流與倒影', 1),
#      ('穿越福爾摩沙1630-1930：法國人眼中的台灣印象', 1),
#      ('未來的光陰：給台灣新電影四十年的備忘錄', 1),
#      ('剛剛好的優雅', 1),
#      ('蜜桃成熟時', 1),
#      ('與你襄遇', 1),
#      ('一見峮心', 1),
#      ('今夏戀愛中', 1),
#      ('今日旅行', 1),
#      ('今日旅行中', 1),
#      ('原子少年ATOMBOYZ', 1),
#      ('ENDING妖精', 1),
#      ('喇舌', 1),
#      ('星球聯盟', 1),
#      ('天地聯盟', 1),
#      ('海王星', 1)]),
#    ('娛樂',
#     [('原子少年', 17),
#      ('NOWnews今日新聞', 13),
#      ('犯罪都市2', 9),
#      ('小姐不熙娣', 9),
#      ('D.P：逃兵追緝令', 9),
#      ('犯罪都市', 8),
#      ('百想藝術大賞', 8),
#      ('今日新聞', 8),
#      ('夏娃的醜聞', 8),
#      ('原子', 7),
#      ('二十五，二十一', 6),
#      ('魷魚遊戲', 6),
#      ('金馬獎', 6),
#      ('頭七', 6),
#      ('小明星大跟班', 6),
#      ('一家之主', 5),
#      ('金曲獎', 4),
#      ('來吧！營業中', 4),
#      ('死亡預報', 4),
#      ('乘風破浪', 4),
#      ('愛你', 4),
#      ('說太多', 4),
#      ('紙房子：韓國篇', 4),
#      ('我們的藍調時光', 3),
#      ('熙娣想聊', 3),
#      ('神探具景伊', 3),
#      ('殭屍校園', 3),
#      ('地獄公使', 3),
#      ('華燈初上', 3),
#      ('神鵰俠侶', 3),
#      ('準明星', 3),
#      ('財閥家的小兒子', 3),
#      ('同學來了', 3),
#      ('偷走你的心', 3),
#      ('白老鼠', 3),
#      ('摯友', 3),
#      ('精舞門', 3),
#      ('十天', 3),
#      ('女優可隨意擺爛', 3),
#      ('海王星', 3),
#      ('土星', 3),
#      ('怪獸死了怎麼辦', 3),
#      ('NFT', 3),
#      ('炎上', 3),
#      ('村裡來了個暴走女外科', 3),
#      ('醜聞', 3),
#      ('神鬼奇航', 3),
#      ('電影哆啦A夢', 3),
#      ('衣袖紅鑲邊', 2),
#      ('星光大道', 2),
#      ('Netflix', 2),
#      ('一家團圓', 2),
#      ('柔美的細胞小將2', 2),
#      ('黃昏', 2),
#      ('超級星光大道', 2),
#      ('安娜', 2),
#      ('戀愛是科學', 2),
#      ('女外科', 2),
#      ('愛愛內含光', 2),
#      ('科幻小說', 2),
#      ('天若有情', 2),
#      ('前男友的遺書', 2),
#      ('幸福三重奏', 2),
#      ('機智校園生活', 2),
#      ('神隱少女', 2),
#      ('波西傑克森', 2),
#      ('來自星星的你', 2),
#      ('雙重人生', 2),
#      ('全明星觀察中', 2),
#      ('愛的奇蹟', 2),
#      ('賭神3之少年賭神', 2),
#      ('乘風破浪的姐姐', 2),
#      ('特別貢獻獎', 2),
#      ('歹命阿狗兄', 2),
#      ('成功之路', 2),
#      ('微笑PASTA', 2),
#      ('惠比壽麝香葡萄', 2),
#      ('歐比王肯諾比', 2),
#      ('星球聯盟', 2),
#      ('木星', 2),
#      ('火星', 2),
#      ('天王星', 2),
#      ('天竺鼠', 2),
#      ('PUIPUI天竺鼠車車', 2),
#      ('AgainM', 2),
#      ('AgainMyLife', 2),
#      ('理想的男友', 2),
#      ('與你襄愛', 2),
#      ('CleaningUp', 2),
#      ('赤壁．愛', 2),
#      ('捍衛戰士：獨行俠', 2),
#      ('紙房子', 2),
#      ('鑑識英雄', 2),
#      ('暴走女外科', 2),
#      ('村裡', 2),
#      ('名家論壇', 2),
#      ('小時代', 2),
#      ('素顏7252', 2),
#      ('全明星運動會2', 2),
#      ('畢利卡星', 2),
#      ('吃掉我', 1),
#      ('康熙', 1),
#      ('電視部門', 1),
#      ('羽球少年團', 1),
#      ('D.P', 1),
#      ('逃兵追緝令', 1),
#      ('一年一度影視', 1),
#      ('少年法庭', 1),
#      ('紫色禮服秀火辣', 1),
#      ('一年一度', 1),
#      ('來追學姊', 1),
#      ('奇異博士2', 1),
#      ('奇異博士２', 1),
#      ('食尚玩家', 1),
#      ('莎甜苦辣', 1),
#      ('民雄鬼屋', 1),
#      ('隱娘', 1),
#      ('俗女養成記', 1),
#      ('芭拉蒂', 1),
#      ('黃金梅利號', 1),
#      ('OnePiece', 1),
#      ('寶可夢朱／紫', 1),
#      ('狗屎寫手', 1),
#      ('關掉/打開', 1),
#      ('我這麼可愛', 1),
#      ('細胞小將2', 1),
#      ('具雄', 1),
#      ('金音', 1),
#      ('國民姑丈', 1),
#      ('金曲', 1),
#      ('方言男演唱人獎', 1),
#      ('第32屆金鐘獎綜藝節目主持人獎', 1),
#      ('音樂鬼才', 1),
#      ('惡作劇二吻', 1),
#      ('國民女神', 1),
#      ('Start-Up：我的新創時代', 1),
#      ('親密的異邦人', 1),
#      ('單身騎士', 1),
#      ('TheKing：', 1),
#      ('柏青哥', 1),
#      ('高校十八禁Euphoria', 1),
#      ('陸貞傳奇', 1),
#      ('怦然心動', 1),
#      ('老徐賣歌', 1),
#      ('她很漂亮', 1),
#      ('W－兩個世界', 1),
#      ('成均館緋聞', 1),
#      ('60天，指定倖存者', 1),
#      ('海賊王', 1),
#      ('如果可以', 1),
#      ('R.I.P.', 1),
#      ('CheapLove', 1),
#      ('Yout', 1),
#      ('先不要', 1),
#      ('南韓電影', 1),
#      ('在你面前', 1),
#      ('飛龍在天', 1),
#      ('意難忘', 1),
#      ('21歲', 1),
#      ('同學麥娜絲', 1),
#      ('同學麥娜', 1),
#      ('tars流星', 1),
#      ('無法抗拒的他', 1),
#      ('流星', 1),
#      ('ShootingStars流星', 1),
#      ('聲聲不息', 1),
#      ('迷電影', 1),
#      ('羅志祥', 1),
#      ('格瑞特真相', 1),
#      ('瑞特真相', 1),
#      ('狂人', 1),
#      ('我還是愛著你', 1),
#      ('毒藥', 1),
#      ('都是我的錯', 1),
#      ('九澤C', 1),
#      ('PRODUCEX101', 1),
#      ('全明星運動會', 1),
#      ('不能說', 1),
#      ('E!Studio藝鏡到底', 1),
#      ('故事奪還者', 1),
#      ('機智', 1),
#      ('Shoot', 1),
#      ('馬錫道', 1),
#      ('全日萬', 1),
#      ('老鼠', 1),
#      ('Netflix科幻', 1),
#      ('超時空亞當計畫', 1),
#      ('香港電影金像獎新人獎', 1),
#      ('OneTheWoman', 1),
#      ('雞不可失', 1),
#      ('熱血祭司', 1),
#      ('模范棒棒堂', 1),
#      ('六燈獎', 1),
#      ('金鐘獎', 1),
#      ('姊妹淘', 1),
#      ('非分熟女', 1),
#      ('一把青', 1),
#      ('你說要我愛你', 1),
#      ('11點熱吵店', 1),
#      ('終極一班', 1)]),
#    ('新奇',
#     [('NOWnews今日新聞', 7),
#      ('NOWnews', 6),
#      ('旺好運', 4),
#      ('PTT', 3),
#      ('今日新聞', 3),
#      ('Dcard', 3),
#      ('神隱少女', 3),
#      ('小孟老師星座', 3),
#      ('傾聽畫語', 2),
#      ('長臂猿傳說', 2),
#      ('ThoseThatFollow', 2),
#      ('波西傑克森', 2),
#      ('神鬼奇航', 2),
#      ('捍衛戰士：獨行俠', 2),
#      ('搜狐網', 2),
#      ('奇異博士2', 1),
#      ('奇異博士２', 1),
#      ('買一送一', 1),
#      ('LoveDoll', 1),
#      ('長臂猿傳', 1),
#      ('MARVEL未來革命', 1),
#      ('我愛全聯', 1),
#      ('海賊王', 1),
#      ('明仔載', 1),
#      ('怪胎', 1),
#      ('塔羅牌之清水孟', 1),
#      ('Netflix科幻', 1),
#      ('超時空亞當計畫', 1),
#      ('Joeman', 1),
#      ('麥胖報告SuperSizeMe', 1),
#      ('閨蜜的話', 1),
#      ('蝴蝶姐姐', 1),
#      ('犯罪都市2', 1),
#      ('小孟老師星座塔羅牌之清水孟', 1),
#      ('炫耀文', 1),
#      ('爆廢公社', 1),
#      ('塔羅牌老師艾菲爾', 1),
#      ('九妹', 1),
#      ('紅蓮華', 1),
#      ('倩女幽魂', 1),
#      ('知りたいッ', 1),
#      ('日テレNEWS', 1),
#      ('高敏敏營養師', 1),
#      ('キャリコネニュース', 1),
#      ('7-11', 1),
#      ('小王子', 1),
#      ('T1LEAGUE', 1)]),
#    ('生活',
#     [('NOWnews今日新聞', 8),
#      ('愛你', 7),
#      ('NOWnews', 4),
#      ('原子少年', 3),
#      ('捍衛戰士：獨行俠', 3),
#      ('塔羅牌老師艾菲爾', 2),
#      ('小孟老師星座', 2),
#      ('傾聽畫語', 2),
#      ('長臂猿傳說', 2),
#      ('神隱少女', 2),
#      ('今日新聞', 2),
#      ('原子少年—STARformation', 1),
#      ('瀕臨絕種團', 1),
#      ('柴郎', 1),
#      ('長臂猿傳', 1),
#      ('MARVEL未來革命', 1),
#      ('我愛全聯', 1),
#      ('海賊王', 1),
#      ('無所不擊', 1),
#      ('媽祖，府中情', 1),
#      ('塔羅牌之清水孟', 1),
#      ('諾貝爾物理學獎', 1),
#      ('澎湃新聞', 1),
#      ('小孟老師星座塔羅牌之清水孟', 1),
#      ('四方報', 1),
#      ('天王星', 1),
#      ('木星', 1),
#      ('水星', 1),
#      ('金星', 1),
#      ('火星', 1),
#      ('土星', 1),
#      ('海王星', 1),
#      ('戰隊', 1),
#      ('倩女幽魂', 1),
#      ('讀者文摘', 1),
#      ('TCFA服務天使獎', 1),
#      ('知りたいッ', 1),
#      ('日テレNEWS', 1),
#      ('旺好運', 1),
#      ('決戰水下伸展台', 1),
#      ('小王子', 1),
#      ('爆廢公社公開版', 1)]),
#    ('財經',
#     [('NOWnews今日新聞', 7),
#      ('591實價登錄', 4),
#      ('三星樂', 3),
#      ('威力彩', 2),
#      ('5287', 2),
#      ('日經亞洲', 2),
#      ('大樂透', 1),
#      ('創世紀', 1),
#      ('金融奉獻獎', 1),
#      ('宏碁數創獎', 1),
#      ('富比士', 1)]),
#    ('專題',
#     [('華根初上', 195),
#      ('NOWnews今日新聞', 57),
#      ('NOWnews', 45),
#      ('鮑魚遊戲', 39),
#      ('華根', 33),
#      ('今日新聞', 9),
#      ('NOWNews今日新聞', 6),
#      ('91視頻', 6),
#      ('魷魚遊戲', 6),
#      ('塑封本之女', 3),
#      ('OL縫隙白皮書', 3),
#      ('玉蒲團', 3),
#      ('赤裸羔羊', 3),
#      ('空屋情人', 3),
#      ('霜花店：朕的男人', 3),
#      ('後宮', 3),
#      ('姦臣：色誘天下', 3),
#      ('台灣水電工', 3),
#      ('横綱凱咪', 3),
#      ('華燈初上', 3),
#      ('BBC中文網', 3)]),
#    ('全球',
#     [('南華早報', 4),
#      ('新京報', 3),
#      ('金棕櫚獎', 3),
#      ('人民日報', 3),
#      ('金馬獎', 2),
#      ('日經亞洲', 2),
#      ('環球時報', 2),
#      ('神隱少女', 2),
#      ('川語錄', 2),
#      ('惡魔姐姐', 2),
#      ('坎城金獎', 1),
#      ('華氏91', 1),
#      ('Thier', 1),
#      ('奧斯卡金像獎', 1),
#      ('明報', 1),
#      ('澳洲人報', 1),
#      ('深化藍色經濟合作備忘錄', 1),
#      ('NOWnews今日新聞', 1),
#      ('歐洲時報', 1),
#      ('中國青年報', 1),
#      ('鄭州日報', 1),
#      ('普立茲獎', 1),
#      ('NKNews', 1),
#      ('雪梨晨驅報', 1),
#      ('伊美黛', 1),
#      ('國家報', 1),
#      ('刺胳針', 1),
#      ('國家脈搏', 1),
#      ('中國病毒學', 1),
#      ('WANNABE', 1),
#      ('Nonkul', 1),
#      ('荷爾蒙3', 1),
#      ('愛情來了', 1),
#      ('模犯生', 1),
#      ('金天鵝獎', 1),
#      ('2022氣候變遷', 1),
#      ('流星花園', 1),
#      ('新民晚報', 1),
#      ('中國經濟週刊', 1),
#      ('星島日報', 1),
#      ('衛報', 1),
#      ('烏克蘭真理報', 1),
#      ('時代財經', 1),
#      ('緊急追捕令', 1),
#      ('舊金山紀事報', 1),
#      ('世界報', 1),
#      ('諾貝爾和平獎', 1),
#      ('水行俠2', 1),
#      ('VanityFair', 1)]),
#    ('運動',
#     [('新世紀福音戰士', 5),
#      ('超級王牌棒球隊', 5),
#      ('肯尼NOW星球', 4),
#      ('金牌', 4),
#      ('桃猿戰士', 4),
#      ('灌籃高手', 3),
#      ('ESPN', 2),
#      ('銅牌', 2),
#      ('2022', 2),
#      ('NBCSports', 1),
#      ('南華早報', 1),
#      ('樂天桃園', 1),
#      ('綜藝玩很大', 1),
#      ('國光幫幫忙', 1),
#      ('綜藝大熱門', 1),
#      ('綜藝大集合', 1),
#      ('飢餓遊戲', 1),
#      ('綜藝3國智', 1),
#      ('娛樂百分百', 1),
#      ('YAHOO奇摩', 1),
#      ('園遊會', 1),
#      ('台灣大哥大悍將中學', 1),
#      ('36題愛上你', 1),
#      ('音樂風雲榜', 1),
#      ('失重前幸福', 1),
#      ('TheRinger', 1),
#      ('StatMuse', 1),
#      ('TheAthletic', 1),
#      ('Green', 1),
#      ('麋先生MIXER', 1),
#      ('NOWnews今日新聞', 1),
#      ('KevinD', 1),
#      ('T1LEAGUE', 1)]),
#    ('全部',
#     [('華根初上', 195),
#      ('NOWnews今日新聞', 145),
#      ('NOWnews', 58),
#      ('今日新聞', 41),
#      ('鮑魚遊戲', 39),
#      ('華根', 33),
#      ('原子少年', 30),
#      ('魷魚遊戲', 16),
#      ('愛你', 15),
#      ('百想藝術大賞', 14),
#      ('D.P：逃兵追緝令', 13),
#      ('捍衛戰士：獨行俠', 10),
#      ('二十五，二十一', 10),
#      ('犯罪都市2', 10),
#      ('衣袖紅鑲邊', 9),
#      ('原子', 9),
#      ('小姐不熙娣', 9),
#      ('神隱少女', 9),
#      ('日經亞洲', 8),
#      ('華燈初上', 8),
#      ('金牌', 8),
#      ('死亡預報', 8),
#      ('犯罪都市', 8),
#      ('金馬獎', 8),
#      ('夏娃的醜聞', 8),
#      ('來吧！營業中', 7),
#      ('乘風破浪', 7),
#      ('旺好運', 7),
#      ('今日廣場', 6),
#      ('財閥家的小兒子', 6),
#      ('頭七', 6),
#      ('小明星大跟班', 6),
#      ('NOWNews今日新聞', 6),
#      ('91視頻', 6),
#      ('新京報', 5),
#      ('地獄公使', 5),
#      ('神探具景伊', 5),
#      ('海賊王', 5),
#      ('肯尼NOW星球', 5),
#      ('海王星', 5),
#      ('一家之主', 5),
#      ('神鬼奇航', 5),
#      ('小孟老師星座', 5),
#      ('南華早報', 5),
#      ('新世紀福音戰士', 5),
#      ('超級王牌棒球隊', 5),
#      ('文化獎', 4),
#      ('我們的藍調時光', 4),
#      ('ThoseThatFollow', 4),
#      ('同學來了', 4),
#      ('科幻小說', 4),
#      ('天若有情', 4),
#      ('倩女幽魂', 4),
#      ('親愛的亞當', 4),
#      ('一家團圓', 4),
#      ('人民日報', 4),
#      ('醜聞', 4),
#      ('與你襄愛', 4),
#      ('金曲獎', 4),
#      ('波西傑克森', 4),
#      ('土星', 4),
#      ('說太多', 4),
#      ('紙房子：韓國篇', 4),
#      ('傾聽畫語', 4),
#      ('長臂猿傳說', 4),
#      ('591實價登錄', 4),
#      ('桃猿戰士', 4),
#      ('北京日報', 3),
#      ('諾貝爾和平獎', 3),
#      ('原子少年ATOMBOYZ', 3),
#      ('水行俠2', 3),
#      ('VanityFair', 3),
#      ('以吾之名', 3),
#      ('D.P', 3),
#      ('OnePiece', 3),
#      ('那不是雪中紅', 3),
#      ('少年法庭', 3),
#      ('愛愛內含光', 3),
#      ('Joeman', 3),
#      ('36題愛上你', 3),
#      ('微笑PASTA', 3),
#      ('小時代', 3),
#      ('星球聯盟', 3),
#      ('熙娣想聊', 3),
#      ('殭屍校園', 3),
#      ('神鵰俠侶', 3),
#      ('準明星', 3),
#      ('偷走你的心', 3),
#      ('白老鼠', 3),
#      ('摯友', 3),
#      ('精舞門', 3),
#      ('十天', 3),
#      ('女優可隨意擺爛', 3),
#      ('木星', 3),
#      ('火星', 3),
#      ('天王星', 3),
#      ('怪獸死了怎麼辦', 3),
#      ('NFT', 3),
#      ('炎上', 3),
#      ('村裡來了個暴走女外科', 3),
#      ('T1LEAGUE', 3),
#      ('電影哆啦A夢', 3),
#      ('PTT', 3),
#      ('Dcard', 3),
#      ('塔羅牌老師艾菲爾', 3),
#      ('三星樂', 3),
#      ('塑封本之女', 3),
#      ('OL縫隙白皮書', 3),
#      ('玉蒲團', 3),
#      ('赤裸羔羊', 3),
#      ('空屋情人', 3),
#      ('霜花店：朕的男人', 3),
#      ('後宮', 3),
#      ('姦臣：色誘天下', 3),
#      ('台灣水電工', 3),
#      ('横綱凱咪', 3),
#      ('BBC中文網', 3),
#      ('金棕櫚獎', 3),
#      ('灌籃高手', 3),
#      ('n@nownews.com名家論壇', 2),
#      ('萬安警報', 2),
#      ('普立茲克獎', 2),
#      ('行政院文化獎', 2),
#      ('包浩斯', 2),
#      ('亞洲首展', 2),
#      ('雪梨晨驅報', 2),
#      ('伊美黛', 2),
#      ('星島日報', 2),
#      ('聖保羅頁報', 2),
#      ('九歌', 2),
#      ('台北國際書展大獎', 2),
#      ('金蝶獎', 2),
#      ('金鼎獎', 2),
#      ('金漫獎', 2),
#      ('上海封控成本考', 2),
#      ('HOME', 2),
#      ('小輓', 2),
#      ('情批', 2),
#      ('北京遊', 2),
#      ('川貝母', 2),
#      ('棄貓', 2),
#      ('欸？我說到哪裡了？', 2),
#      ('捍衛戰士', 2),
#      ('決戰水下伸展台', 2),
#      ('爆廢公社公開版', 2),
#      ('東方紅', 2),
#      ('進擊的巨人', 2),
#      ('激流與倒影', 2),
#      ('穿越福爾摩沙1630-1930：法國人眼中的台灣印象', 2),
#      ('未來的光陰：給台灣新電影四十年的備忘錄', 2),
#      ('戀慕', 2),
#      ('家族', 2),
#      ('開朗少女成功記', 2),
#      ('久違的再見', 2),
#      ('命中注定我愛你', 2),
#      ('民雄鬼屋', 2),
#      ('隱娘', 2),
#      ('俗女養成記', 2),
#      ('二十一', 2),
#      ('羅希度', 2),
#      ('她很漂亮', 2),
#      ('W－兩個世界', 2),
#      ('成均館緋聞', 2),
#      ('60天，指定倖存者', 2),
#      ('如果可以', 2),
#      ('R.I.P.', 2),
#      ('CheapLove', 2),
#      ('Yout', 2),
#      ('先不要', 2),
#      ('南韓電影', 2),
#      ('在你面前', 2),
#      ('明仔載', 2),
#      ('怪胎', 2),
#      ('飛龍在天', 2),
#      ('意難忘', 2),
#      ('21歲', 2),
#      ('同學麥娜絲', 2),
#      ('同學麥娜', 2),
#      ('tars流星', 2),
#      ('無法抗拒的他', 2),
#      ('流星', 2),
#      ('ShootingStars流星', 2),
#      ('聲聲不息', 2),
#      ('迷電影', 2),
#      ('澳洲人報', 2),
#      ('深化藍色經濟合作備忘錄', 2),
#      ('羅志祥', 2),
#      ('衛報', 2),
#      ('每日電訊報', 2),
#      ('諾貝爾物理學獎', 2),
#      ('第六感之吻', 2),
#      ('日本味', 2),
#      ('臨終', 2),
#      ('食尚', 2),
#      ('中國日報', 2),
#      ('剛剛好的優雅', 2),
#      ('喇舌', 2),
#      ('星光大道', 2),
#      ('奇異博士2', 2),
#      ('奇異博士２', 2)])]]]

# %%
df_top_word_NE = pd.DataFrame(top_word_NE, columns = ['ne_name','top_keys'])

# %%
df_top_word_NE.to_csv('now_news_topkey_by_ner_and_category.csv', sep=',', index=False)
