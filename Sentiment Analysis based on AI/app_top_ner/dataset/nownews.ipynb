# %% [markdown]
# ## There are 10 categories in Managertoday

# %% [markdown]
# 焦點 https://www.nownews.com/cat/column/
#
# 要聞 https://www.nownews.com/cat/news-summary/
#
# 即時 https://www.nownews.com/cat/breaking/
#
# 娛樂 https://www.nownews.com/cat/entertainment/
#
# 新奇 https://www.nownews.com/cat/novelty/
#
# 生活 https://www.nownews.com/cat/life/
#
# 財經 https://www.nownews.com/cat/finance/
#
# 專題 https://www.nownews.com/cat/st/
#
# 全球 https://www.nownews.com/cat/news-global/
#
# 運動 https://www.nownews.com/cat/sport/

# %% [markdown]
# # Crawl news for 10 categories

# %%
news_links = ['column/', 'news-summary/', 'breaking/', 'entertainment/', 'novelty/', 'life/', 'finance/', 'st/', 'news-global/', 'sport/']
news_categories = ['焦點', '要聞', '即時', '娛樂', '新奇', '生活', '財經', '專題', '全球', '運動']
base_url = 'https://www.nownews.com/cat/'

# %%
import requests
import re
from bs4 import BeautifulSoup
import time
import pandas as pd
from datetime import datetime, timedelta

# %%
links = []
titeles = []
dates = []
contents = []
categories = []
item_id = []
photo_links = []

for i, url_short_name in enumerate(news_links):  

    category = news_categories[i] 

    category_url = base_url + url_short_name
    print("Getting categorical news:", category)

    req = requests.get(category_url)
    page = BeautifulSoup(req.text, 'lxml')

    items = page.find('div', {'class': re.compile("listBlk horizontal\w*")}).findAll('li')

    serial_no = 1
    for j, item in enumerate (items):
        title = item.find('div', {'class': "txt"}).text
        print(serial_no, '--', title )

        link = item.find('a').get('href')

        dt = item.find('p', {'class':"time"}).text

        try:
            if item.find('img').has_attr('data-src'):
                photo_link = item.find('img').get('data-src')
            else:
                photo_link = item.find('img').get('src')
     
        except:
            photo_link = ''

        categories.append(category)
        dates.append(dt)
        titeles.append(title)
        links.append(link)
        photo_links.append(photo_link)
        
        # item id
        t = datetime.strptime(dt, '%Y-%m-%d %H:%M')
        tstr = t.strftime("%Y%m%d")

        item_id.append(url_short_name + "_" + tstr + "_" + str(serial_no))
        serial_no += 1

        
        # There are some words we don't like to analyze, They should be removed.
        page = BeautifulSoup(requests.get( link ).text,'lxml')

        # Find content
        content = page.find('article',{'itemprop':"articleBody"})

        # 額外插入的圖片與文字說明區塊-->移除之
        try:
            for media in content.findAll('div', {'id':"viewdeo_dable"}):
                media.decompose()
        except:
            pass

        try:
            for promote in content.findAll('div', {'class':"ad-blk1"}):
                promote.decompose()
        except:
            pass

        try:
            for tag in content.findAll('span', {'class':"hash-tag"}):
                tag.decompose()
        except:
            pass

        # Remove unnecessary content
        cont = content.text
        cont = re.sub('（中央社記者.+?）','', cont)
        cont = re.sub('（編輯：.*','', cont) 
        cont = re.sub('（譯者：.*','', cont) 
        cont = re.sub('（中央社\w*）','', cont) 
        cont = re.sub('\n','', cont) 
        cont = re.sub('\r','', cont) 
        cont = re.sub('\t','', cont) 
        cont = re.sub(' ','', cont) 

        contents.append(cont)
        time.sleep(2)  # 遵守爬蟲禮節，請小睡一下

        if (j==1): # Here we crawl only 2 pieces of news for each category, in order to save time.
                break
# Out:
# Getting categorical news: 焦點
# 1 --
# 北市再曝8張足跡圖！遍佈春水堂、台大、饗饗、大湖公園
# 指揮中心公布，今（14）日新增874例本土個案，臺北市政府衛生局今晚也公布案28123、28557、28558、28734、28849、28868、29421、30692的足跡，共有8張確診足跡圖，包...
# 2022-04-14 21:20
#
# 2 --
# 美參議院外委會主席搭空軍專機抵台　將拜會邱國正
# 美國聯邦參議院外交委員會主席梅南德茲今（14）日率領美國國會議員團共6人訪問台灣，訪團搭乘C-40C行政專機於今晚7時40分抵達台北松山機場，訪團明天將晉見總統蔡英文，針對台美合作、中國威脅、區域安全...
# 2022-04-14 21:00
#
# Getting categorical news: 要聞
# 1 --
# 三中案唯一判有罪　蔡正元拼二審無罪
# 前總統馬英九涉賤賣「三中」黨產案，高院今（14）日審理一審中唯一被判有罪的被告、前立委蔡正元出庭。蔡正元做無罪答辯，並批檢方上訴「竹蒿湊菜刀」，一審混淆事實才會判有罪。檢方指控，蔡正元自2007年7月...
# 2022-04-14 20:01
#
# 2 --
# 美國參議院外委主席梅南德茲率團訪台！預計7：40抵達
# 台美互動頻繁，外交部今（14）日晚間發布活動通知，美國參議院的外委會主席梅南德茲（Bob Menendez）率團訪台，預計今晚19點40分抵台。根據澳洲報導，擔任外委會主席的參議員梅南德茲，率領5名參...
# 2022-04-14 19:45
#
# Getting categorical news: 即時
# 1 --
# 台北車站清晨驚傳妙齡女意外落軌　消防急救援送醫
# 台北車站今（14）日清晨5點多，驚傳一位年約20多歲的年輕女子在台鐵月台發生落軌意外，一旁民眾連忙通報鐵路警察，台鐵緊急通知進站的列車停駛，由消防隊員到場將女子救出。所幸女子並無大礙，就醫時意識清醒，...
# 2022-04-14 20:43
#
# 2 --
# 桃園驚傳連環車禍！男疑似心臟病發「癱倒駕駛座」身亡
# 桃園市一名呂姓男子（61歲），今天（14日）下午開車行經民權路時，疑似身體不適突然休克，導致車輛先撞上路旁機車後，又追撞多台汽機車，最後撞上路燈才停下，警方獲報到場時，呂男已攤倒在駕駛座上，緊急送醫後...
# 2022-04-14 20:42
#
# Getting categorical news: 娛樂
# 1 --
# JPM為《原子少年》合體　形容和棒棒堂11年關係
# 從棒棒堂出道的廖允杰、邱勝翊與邱宇辰在2011年組成JPM，優秀舞蹈實力與唱功曾風靡萬千少男少女。睽違六年未合體演出，這次三人從偶像男團進階為導師，與《原子少年ATOM BOYZ》的地球團共同演出經典...
# 2022-04-14 20:00
#
# 2 --
# 鳳梨女友出門被嫌太保守　扯開遮蔽物「比基尼剩一半」
# 網紅鳳梨（吳泓毅）因獨特的「鼠薯」口音闖出名聲，霸氣的外貌和幽默的本土風格吸引各年齡層關注，也時常與貼身「祕書」、女友的歐菈放閃。近日鳳梨帶著歐菈前往墾丁度假，不過女友不同以往的保守穿搭讓他疑惑，這時...
# 2022-04-14 20:00
#
# Getting categorical news: 新奇
# 1 --
# 「順暢便姿」曝光！他喊該納入課綱　網驚：原來全上錯
# 現在人因為工作繁忙，長時間久坐加上缺乏運動或是補充足夠膳食纖維，容易形成便秘問題，常常會坐在馬桶上折騰許久。一名網友就分享藥廠的「順暢便姿」，只要加上一小物就能讓便便快速排出，貼文一出立刻引起討論。日...
# 2022-04-14 18:04
#
# 2 --
# 瓦城為啥一堆人愛？他愣：很貴啊　老饕抖「神優勢」夯爆
# 美食對人們來說，是充實生活、紓解壓力的重要元素，因此除了台灣本土的食物外，極具特色的「異國料理」也受到許多人的愛戴，而主打泰式料理的知名品牌「瓦城」就是其中之一，不過有網友卻提到，他認為瓦城的價位偏高...
# 2022-04-14 17:49
#
# Getting categorical news: 生活
# 1 --
# 刑事局也淪陷！警政監侯東輝下午快篩呈「陽性反應」
# 疫情持續升溫，今天（14日）更是突破歷史紀錄新增874例個案，而刑事局也傳出疑似確診案例，據了解，警政監侯東輝下午快篩時呈現陽性反應，目前仍在等待PCR結果出爐，全局知悉此消息後，已在第一時間清查相關...
# 2022-04-14 20:12
#
# 2 --
# 老婆不想生！人夫掏「180萬激勵獎金」　過來人狠戳1關鍵
# 隨著物價、房價飆漲，現代年輕人生存壓力大增，想生小孩也必須詳細規劃。就有位女網友表示，婚前就有表明不想生，但幾年之後老公掏出「180萬激勵獎金」希望能有孩子，遭遇曝光後就有過來人點破「1重點」。原PO...
# 2022-04-14 20:10
#
# Getting categorical news: 財經
# 1 --
# 中國封控供應鏈受影響　台積電積極行動派團隊支援
# 台積電今（14）日下午法說會登場，市場關注中國大陸封控將對供應鏈造成影響，為此，台積電總裁魏哲家表示，這是其他產業也面臨到的狀況，但台積電將積極採取行動，與供應商緊密合作，也派出多個團隊進行現場支援，...
# 2022-04-14 17:55
#
# 2 --
# 大立光Q1每股盈餘41.3元　林恩平：4、5月不會比3月好
# 高階手機鏡頭大廠大立光今（14）日下午舉行法說會，第1季合併營收達101.33億元，季減22%、年減14%，首季稅後盈餘則達55.13億元，季增7%、年增4%，每股盈餘為41.3元。大立光執行長林恩平...
# 2022-04-14 17:23
#
# Getting categorical news: 專題
# 1 --
# 解碼AV圈12／作品百部！最強男優Jacky：我們比誰都高尚
# 女優雖是AV產業的靈魂，不過日本AV產業發展40多年，仍有不少男優因頻繁出現在螢幕上而廣為人知，其中最具知名度的男優，當屬有「性愛帝王」之稱的加藤鷹。那台灣男優的頂點在哪？《NOWnews今日新聞》訪...
# 2022-04-14 12:14
#
# 2 --
# 解碼AV圈11／想當男優看過來！別想免費打砲　要多練下盤
# 爭議網紅鄧佳華去年獲邀擔任A片《華根初上》男優，順利圓夢破處，激發不少宅男心中湧現「有為者亦若是」的雄心壯志。不過想要擔任男優，有什麼條件或門檻嗎？資深男優Jacky說，除了要認清男優是低薪、超級消耗...
# 2022-04-14 12:12
#
# Getting categorical news: 全球
# 1 --
# 日本取消俄羅斯最惠國待遇　即將完成修法
# （中央社記者楊明珠東京14日專電）鑑於俄羅斯軍事侵略烏克蘭，日本對俄國採取制裁措施，包括取消保障俄羅斯貿易優惠措施「最惠國待遇」等法津修正案，眾議院院會今天表決通過，將送交參議院審議通過後生效。日本放...
# 2022-04-14 18:16
#
# 2 --
# 虧大了！俄寡頭名下超級遊艇駛抵斐濟　遭警方扣押調查
# （中央社雪梨14日綜合外電報導）俄羅斯入侵烏克蘭後，西方國家紛紛對俄國寡頭、官員等祭出制裁。外媒披露，俄國受制裁億萬富豪名下的一艘超級遊艇12日悄悄駛抵南太平洋島國斐濟，隨後遭警方扣押。斐濟報紙報導，...
# 2022-04-14 18:13
#
# Getting categorical news: 運動
# 1 --
# NBA／詹皇想和自己一起打球　Curry高EQ回應：在2K很無解
# 日前「詹皇」LeBron James表示除了兒子Bronny之外，自己會想和Stephen Curry一起打球，也引起外界的熱議。不過當時後者的回答比較冷處理，除了一些客套話之外，也直接表示「自己現在...
# 2022-04-14 17:27
#
# 2 --
# T1／女神峮峮領軍！中信特攻啦啦隊最吸睛
# 台灣運彩xT1聯盟元年2021-22球季例行賽進入最後階段，隨著日前聯盟註冊大限到期，六都球團補強底定，準備最後衝刺，爭取季後賽機會，趕在例行賽結束前1個月，聯盟特別舉辦季中媒體大調查活動，吸引42位...
# 2022-04-14 15:53

# %% [markdown]
# ## Save data

# %%
data = zip(item_id, dates, categories, title, contents, links, photo_links)
df = pd.DataFrame(list(data), columns=['item_id','date','category','title','content','link','photo_link'])

# %%
df.head(2)
# Out:
#               item_id              date category title  \
# 0  column/_20220414_1  2022-04-14 21:20       焦點    \n
# 1  column/_20220414_2  2022-04-14 21:00       焦點     T
#
#                                              content  \
# 0  指揮中心公布，今（14）日新增874例本土個案，臺北市政府衛生局今晚也公布案28123、28...
# 1  美國聯邦參議院外交委員會主席梅南德茲今（14）日率領美國國會議員團共6人訪問台灣，訪團搭乘C...
#
#                                    link  \
# 0  https://www.nownews.com/news/5775726
# 1  https://www.nownews.com/news/5775707
#
#                                           photo_link
# 0  https://media.nownews.com/nn_media/thumbnail/2...
# 1  https://media.nownews.com/nn_media/thumbnail/2...

# %%
df.shape
# Out:
# (20, 7)

# %%
df.content[0]
# Out:
# '指揮中心公布，今（14）日新增874例本土個案，臺北市政府衛生局今晚也公布案28123、28557、28558、28734、28849、28868、29421、30692的足跡，共有8張確診足跡圖，包含春水堂光南店、饗饗、台大籃球場、TABOOClub、金坊酒店等地。北市衛生局提醒，曾造訪與確診者足跡相同場域之民眾，加強自我健康監測，每日定時量測體溫及監測有無疑似症狀，如有發燒、喉嚨痛、咳嗽、流鼻水等呼吸道症狀或腹瀉、嗅味覺異常等症狀，先使用家用快篩採檢，也可至本市7家社區採檢站或醫療機構就醫。'

# %%
df.to_csv("now_category_news.csv", sep="|", index=False)

# %% [markdown]
# # News Preprocessing Using Ckiplab NLP Package

# %%
import pandas as pd
import numpy
from collections import Counter
from snownlp import SnowNLP
from ckip_transformers.nlp import CkipWordSegmenter, CkipPosTagger, CkipNerChunker

df = pd.read_csv('now_category_news.csv', sep='|')

ws = CkipWordSegmenter(level=2)
pos = CkipPosTagger(level=2)
ner = CkipNerChunker(level=2)

tokens = ws(df.content)

tokens_pos = pos(tokens)

word_pos_pair = [list(zip(w, p)) for w, p in zip(tokens, tokens_pos)]

entity_list = ner(df.content)

allowPOS = ['Na', 'Nb', 'Nc', 'VA', 'VAC', 'VB', 'VC']

tokens_v2 = []
for wp in word_pos_pair:
    tokens_v2.append([w for w, p in wp if (len(w) >= 2) and p in allowPOS])

df['tokens'] = tokens
df['tokens_v2'] = tokens_v2
df['entities'] = entity_list
df['token_pos'] = word_pos_pair

allowPOS = ['Na', 'Nb', 'Nc', 'VC']

def word_frequency(wp_pair):
    filtered_words = []
    for word, pos in wp_pair:
        if (pos in allowPOS) & (len(word) >= 2):
            filtered_words.append(word)

    counter = Counter(filtered_words)
    return counter.most_common(200)


keyfreqs = []
for wp in word_pos_pair:
    topwords = word_frequency(wp)
    keyfreqs.append(topwords)

df['top_key_freq'] = keyfreqs

summary = []
sentiment = []
for text in df.content:
    sn = SnowNLP(text)
    summary.append(sn.summary())
    sentiment.append(round(sn.sentiments, 2))

df['summary'] = summary
df['sentiment'] = sentiment

df = df[[
    'item_id', 'date','category', 'title', 'content', 'sentiment', 'summary',
    'top_key_freq', 'tokens', 'tokens_v2', 'entities', 'token_pos', 'link',
    'photo_link'
]]

df.to_csv('now_news_preprocessed.csv', sep='|', index=False)

print("process OK!")
# Out:
# Tokenization: 100%|██████████| 20/20 [00:00<00:00, 1179.88it/s]
# Inference: 100%|██████████| 1/1 [00:28<00:00, 28.74s/it]
# Tokenization: 100%|██████████| 20/20 [00:00<00:00, 835.58it/s]
# Inference: 100%|██████████| 5/5 [01:57<00:00, 23.59s/it]
# Tokenization: 100%|██████████| 20/20 [00:00<00:00, 72.46it/s]
# Inference: 100%|██████████| 1/1 [00:39<00:00, 39.58s/it]
# process OK!

# %%
df = pd.read_csv('now_news_preprocessed.csv', sep='|')
df.head(1)
# Out:
#               item_id              date category title  \
# 0  column/_20220414_1  2022-04-14 21:20       焦點    \n
#
#                                              content  sentiment  \
# 0  指揮中心公布，今（14）日新增874例本土個案，臺北市政府衛生局今晚也公布案28123、28...        0.0
#
#                                              summary  \
# 0  ['臺北市政府衛生局今晚也公布案28123、28557、28558、28734、28849、...
#
#                                         top_key_freq  \
# 0  [('症狀', 3), ('衛生局', 2), ('足跡', 2), ('監測', 2), ...
#
#                                               tokens  \
# 0  ['指揮', '中心', '公布', '，', '今', '（', '14）', '日', ...
#
#                                            tokens_v2  \
# 0  ['指揮', '中心', '本土', '個案', '臺北', '市政府', '衛生局', '...
#
#                                             entities  \
# 0  [NerToken(word='今（14）日', ner='DATE', idx=(7, 1...
#
#                                            token_pos  \
# 0  [('指揮', 'Na'), ('中心', 'Nc'), ('公布', 'VE'), ('，...
#
#                                    link  \
# 0  https://www.nownews.com/news/5775726
#
#                                           photo_link
# 0  https://media.nownews.com/nn_media/thumbnail/2...

# %% [markdown]
# ## Count top 200 word frequency for each category

# %%
import pandas as pd

# %%
df = pd.read_csv('now_news_preprocessed.csv',sep='|')

# %%
from collections import Counter

# %%
news_links = ['column/', 'news-summary/', 'breaking/', 'entertainment/', 'novelty/', 'life/', 'finance/', 'st/', 'news-global/', 'sport/']
news_categories = ['焦點', '要聞', '即時', '娛樂', '新奇', '生活', '財經', '專題', '全球', '運動']

# %%
allowedPOS=['Na', 'Nb', 'Nc']

# %%
def get_top_words():
    top_cate_words={}
    counter_all = Counter()
    for category in news_categories:
        df_group = df[df.category == category]
        words_group = []
        for row in df_group.token_pos:
            filtered_words = []
            for (word, pos) in eval(row):
                if (len(word) >= 2) & (pos in allowedPOS):
                    filtered_words.append(word)                
            words_group += filtered_words
        counter = Counter( words_group )
        counter_all += counter
        topwords = counter.most_common(200)
        top_cate_words[category] = topwords
    top_cate_words['全部'] = counter_all.most_common(200)
    return list(top_cate_words.items())

# %%
result = get_top_words()

# %%
top_group_words = get_top_words()

# %%
df_top_group_words = pd.DataFrame(top_group_words, columns = ['category','top_keys'])

# %%
df_top_group_words
# Out:
#    category                                           top_keys
# 0        焦點  [(美國, 14), (國會, 12), (委員會, 7), (台灣, 7), (訪團, 6...
# 1        要聞  [(中影, 12), (蔡正元, 6), (檢方, 6), (莊女, 6), (阿波羅, 5...
# 2        即時  [(女子, 6), (意識, 3), (原因, 3), (警方, 3), (呂男, 3), ...
# 3        娛樂  [(歐菈, 12), (少年, 7), (原子, 6), (選手, 5), (鳳梨, 5),...
# 4        新奇  [(瓦城, 9), (網友, 8), (馬桶, 6), (傳單, 5), (推特, 4), ...
# 5        生活  [(疫情, 3), (小孩, 3), (老公, 3), (過來人, 3), (歷史, 2),...
# 6        財經  [(台積電, 19), (供應商, 9), (供應鏈, 7), (需求, 6), (盈餘, ...
# 7        專題  [(男優, 45), (女優, 16), (片場, 10), (經紀人, 9), (台灣, ...
# 8        全球  [(斐濟, 12), (俄羅斯, 9), (阿瑪迪亞號, 7), (修法案, 6), (遊艇...
# 9        運動  [(台灣, 17), (聯盟, 15), (新北, 15), (中信, 15), (英熊, ...
# 10       全部  [(男優, 45), (台灣, 34), (台積電, 19), (美國, 18), (聯盟,...

# %%
df_top_group_words.to_csv('now_news_topkeys_with_category_via_token_pos.csv', index=False)

# %% [markdown]
# ## Count top 200 persons via NER

# %%
df = pd.read_csv('now_news_preprocessed.csv',sep='|')

# %%
df.head(1)
# Out:
#               item_id              date category title  \
# 0  column/_20220422_1  2022-04-22 00:17       焦點    \n
#
#                                              content  sentiment  \
# 0  每年4月22日是世界地球日（EarthDay），各大企業、通路都會在今（22）日發起環保相關...        0.0
#
#                                              summary  \
# 0  ['平均1包百抽衛生紙8元', '平均1包百抽衛生紙8元', '用環保杯購買再折抵3元', ...
#
#                                         top_key_freq  \
# 0  [('使用', 8), ('環保', 7), ('咖啡', 7), ('回收', 6), (...
#
#                                               tokens  \
# 0  ['每', '年', '4月', '22日', '是', '世界', '地球', '日', ...
#
#                                            tokens_v2  \
# 0  ['世界', '地球', '企業', '通路', '發起', '環保', '活動', '統計...
#
#                                             entities  \
# 0  [NerToken(word='世界地球日', ner='DATE', idx=(8, 13...
#
#                                            token_pos  \
# 0  [('每', 'Nes'), ('年', 'Nf'), ('4月', 'Nd'), ('22...
#
#                                    link  \
# 0  https://www.nownews.com/news/5782576
#
#                                           photo_link
# 0  https://media.nownews.com/nn_media/thumbnail/2...

# %%
df.entities[0]
# Out:
# "[NerToken(word='世界地球日', ner='DATE', idx=(8, 13)), NerToken(word='28億', ner='CARDINAL', idx=(64, 67)), NerToken(word='7元', ner='MONEY', idx=(209, 211)), NerToken(word='4月28日', ner='DATE', idx=(212, 217)), NerToken(word='70元', ner='MONEY', idx=(245, 248)), NerToken(word='75元', ner='MONEY', idx=(266, 269)), NerToken(word='75元', ner='MONEY', idx=(289, 292)), NerToken(word='2', ner='CARDINAL', idx=(296, 297)), NerToken(word='99元', ner='MONEY', idx=(300, 303)), NerToken(word='4月22日至4月24日', ner='DATE', idx=(313, 324)), NerToken(word='6月30日', ner='DATE', idx=(343, 348)), NerToken(word='3元', ner='MONEY', idx=(364, 366)), NerToken(word='22日至24日', ner='DATE', idx=(443, 450)), NerToken(word='4', ner='CARDINAL', idx=(477, 478)), NerToken(word='5萬', ner='CARDINAL', idx=(508, 510)), NerToken(word='8', ner='CARDINAL', idx=(532, 533)), NerToken(word='3萬', ner='CARDINAL', idx=(537, 539)), NerToken(word='英式', ner='NORP', idx=(551, 553)), NerToken(word='8', ner='CARDINAL', idx=(562, 563)), NerToken(word='3萬', ner='CARDINAL', idx=(567, 569)), NerToken(word='一次性', ner='CARDINAL', idx=(596, 599)), NerToken(word='5萬', ner='CARDINAL', idx=(605, 607)), NerToken(word='1年', ner='DATE', idx=(661, 663)), NerToken(word='109元', ner='MONEY', idx=(677, 681)), NerToken(word='17日', ner='DATE', idx=(684, 687)), NerToken(word='一', ner='CARDINAL', idx=(706, 707)), NerToken(word='5萬', ner='CARDINAL', idx=(714, 716)), NerToken(word='1年', ner='DATE', idx=(736, 738)), NerToken(word='109元', ner='MONEY', idx=(750, 754)), NerToken(word='一', ner='CARDINAL', idx=(767, 768)), NerToken(word='2', ner='CARDINAL', idx=(779, 780)), NerToken(word='4/30前', ner='DATE', idx=(786, 791)), NerToken(word='3元', ner='MONEY', idx=(818, 820)), NerToken(word='2', ner='CARDINAL', idx=(836, 837)), NerToken(word='2', ner='CARDINAL', idx=(854, 855)), NerToken(word='夏季', ner='DATE', idx=(858, 860)), NerToken(word='50元', ner='MONEY', idx=(877, 880)), NerToken(word='39元', ner='MONEY', idx=(883, 886)), NerToken(word='3元', ner='MONEY', idx=(896, 898)), NerToken(word='3月', ner='DATE', idx=(926, 928)), NerToken(word='6小時', ner='TIME', idx=(948, 951)), NerToken(word='7', ner='CARDINAL', idx=(954, 955)), NerToken(word='6.7', ner='CARDINAL', idx=(1002, 1005)), NerToken(word='100', ner='CARDINAL', idx=(1022, 1025)), NerToken(word='7', ner='CARDINAL', idx=(1027, 1028)), NerToken(word='2', ner='CARDINAL', idx=(1028, 1029)), NerToken(word='899元', ner='MONEY', idx=(1036, 1040)), NerToken(word='599元', ner='MONEY', idx=(1043, 1047)), NerToken(word='8元', ner='MONEY', idx=(1057, 1059)), NerToken(word='6.7', ner='CARDINAL', idx=(1069, 1072)), NerToken(word='100', ner='CARDINAL', idx=(1087, 1090)), NerToken(word='72', ner='CARDINAL', idx=(1092, 1094)), NerToken(word='899元', ner='MONEY', idx=(1101, 1105)), NerToken(word='599元', ner='MONEY', idx=(1108, 1112)), NerToken(word='百', ner='CARDINAL', idx=(1117, 1118)), NerToken(word='8元', ner='MONEY', idx=(1122, 1124)), NerToken(word='去年', ner='DATE', idx=(1174, 1176)), NerToken(word='10', ner='CARDINAL', idx=(1191, 1193)), NerToken(word='1', ner='CARDINAL', idx=(1197, 1198)), NerToken(word='4月22日至4月24日', ner='DATE', idx=(1223, 1234)), NerToken(word='三天', ner='DATE', idx=(1235, 1237)), NerToken(word='3元', ner='MONEY', idx=(1261, 1263)), NerToken(word='5元', ner='MONEY', idx=(1267, 1269)), NerToken(word='40', ner='CARDINAL', idx=(1303, 1305)), NerToken(word='680元', ner='MONEY', idx=(1308, 1312)), NerToken(word='17元', ner='MONEY', idx=(1317, 1320)), NerToken(word='當天', ner='DATE', idx=(1323, 1325)), NerToken(word='50', ner='CARDINAL', idx=(1327, 1329)), NerToken(word='4月21日至5月8日', ner='DATE', idx=(1360, 1370)), NerToken(word='台門市', ner='GPE', idx=(1386, 1389)), NerToken(word='台灣', ner='GPE', idx=(1393, 1395)), NerToken(word='一', ner='CARDINAL', idx=(1398, 1399)), NerToken(word='5月8日', ner='DATE', idx=(1429, 1433)), NerToken(word='1', ner='CARDINAL', idx=(1457, 1458)), NerToken(word='台灣', ner='NORP', idx=(1468, 1470)), NerToken(word='1', ner='CARDINAL', idx=(1473, 1474)), NerTo ...

# %%
def NerToken(word, ner, idx):
    return ner,word

# %%
for ner,key in eval(df.entities[0]):
    print(ner,key)
# Out:
# DATE 世界地球日
# CARDINAL 28億
# MONEY 7元
# DATE 4月28日
# MONEY 70元
# MONEY 75元
# MONEY 75元
# CARDINAL 2
# MONEY 99元
# DATE 4月22日至4月24日
# DATE 6月30日
# MONEY 3元
# DATE 22日至24日
# CARDINAL 4
# CARDINAL 5萬
# CARDINAL 8
# CARDINAL 3萬
# NORP 英式
# CARDINAL 8
# CARDINAL 3萬
# CARDINAL 一次性
# CARDINAL 5萬
# DATE 1年
# MONEY 109元
# DATE 17日
# CARDINAL 一
# CARDINAL 5萬
# DATE 1年
# MONEY 109元
# CARDINAL 一
# CARDINAL 2
# DATE 4/30前
# MONEY 3元
# CARDINAL 2
# CARDINAL 2
# DATE 夏季
# MONEY 50元
# MONEY 39元
# MONEY 3元
# DATE 3月
# TIME 6小時
# CARDINAL 7
# CARDINAL 6.7
# CARDINAL 100
# CARDINAL 7
# CARDINAL 2
# MONEY 899元
# MONEY 599元
# MONEY 8元
# CARDINAL 6.7
# CARDINAL 100
# CARDINAL 72
# MONEY 899元
# MONEY 599元
# CARDINAL 百
# MONEY 8元
# DATE 去年
# CARDINAL 10
# CARDINAL 1
# DATE 4月22日至4月24日
# DATE 三天
# MONEY 3元
# MONEY 5元
# CARDINAL 40
# MONEY 680元
# MONEY 17元
# DATE 當天
# CARDINAL 50
# DATE 4月21日至5月8日
# GPE 台門市
# GPE 台灣
# CARDINAL 一
# DATE 5月8日
# CARDINAL 1
# NORP 台灣
# CARDINAL 1
# CARDINAL 1
# MONEY 50元硬幣
# ORG 網教
# CARDINAL 3

# %%
from collections import Counter

# %%
allowedNE = ['PERSON']

news_categories = ['焦點', '要聞', '即時', '娛樂', '新奇', '生活', '財經', '專題', '全球', '運動']

# %%
def ne_word_frequency( a_news_ne ):
    filtered_words =[]
    for ner,word in a_news_ne:
        if (len(word) >= 2) & (ner in allowedNE):
            filtered_words.append(word)
    counter = Counter( filtered_words )
    return counter.most_common( 200 )

# %%
def get_top_ner_words():
    top_cate_ner_words={}
    words_all=[]
    for category in news_categories:
        df_group = df[df.category == category]
        words_group = []

        # concatenate terms in a category
        for row in df_group.entities:
            words_group += eval(row)

        # concatenate all terms
        words_all += words_group

        # Get top words by calling ne_word_frequency() function
        topwords = ne_word_frequency( words_group )
        top_cate_ner_words[category] = topwords

    topwords_all = ne_word_frequency(words_all)
    top_cate_ner_words['全部'] = topwords_all
    
    return list(top_cate_ner_words.items())
    # return top_cate_ne_words

# %%
allowedNE=['PERSON']
hotPersons = get_top_ner_words()

# %%
hotPersons
# Out:
# [('焦點',
#   [('阿布杜梅亭', 13),
#    ('林傳凱', 8),
#    ('周淑萍', 3),
#    ('陳雅琳', 1),
#    ('李妍瑾', 1),
#    ('吳姍儒', 1),
#    ('小玉', 1),
#    ('連千毅', 1)]),
#  ('要聞',
#   [('麥建方', 10),
#    ('蔡易餘', 9),
#    ('周玉蔻', 7),
#    ('邱垂正', 3),
#    ('陳時中', 2),
#    ('曾銘宗', 2),
#    ('徐正文', 2),
#    ('李明哲', 2),
#    ('張國煒', 2),
#    ('陳吉仲', 1),
#    ('莫德納', 1),
#    ('陳明文喬', 1),
#    ('黃越宏', 1),
#    ('李秉穎', 1)]),
#  ('即時',
#   [('布雷克', 2),
#    ('蘇俊羽', 2),
#    ('陳雅琳', 1),
#    ('李妍瑾', 1),
#    ('曾豪駒', 1),
#    ('王鏡銘', 1),
#    ('朱育賢', 1),
#    ('梁家榮', 1),
#    ('林立', 1)]),
#  ('娛樂',
#   [('劉品言', 13),
#    ('黃捷', 13),
#    ('傅孟柏', 12),
#    ('林襄', 10),
#    ('小玉', 7),
#    ('蔡淑臻', 6),
#    ('曾之喬', 5),
#    ('鄧仲謀', 2),
#    ('朱玉宸', 2),
#    ('鄭家純', 2),
#    ('高國慶', 2),
#    ('吳政紘', 2),
#    ('羅凌筠', 1),
#    ('楊銘威', 1),
#    ('劉品', 1),
#    ('張閔勛', 1),
#    ('王建民', 1),
#    ('納瓦洛', 1)]),
#  ('新奇',
#   [('林傳凱', 8),
#    ('周淑萍', 3),
#    ('貝莉梅', 3),
#    ('Putri', 1),
#    ('Cherng', 1),
#    ('阿樂', 1)]),
#  ('生活',
#   [('林傳凱', 8),
#    ('小玉', 7),
#    ('盧秀燕', 4),
#    ('周淑萍', 3),
#    ('朱玉宸', 2),
#    ('鄭家純', 2),
#    ('曾梓展', 1),
#    ('傅雲慶', 1),
#    ('周玉蔻', 1)]),
#  ('財經',
#   [('孟若羽', 12),
#    ('鄧佳華', 6),
#    ('Morgan', 6),
#    ('吳夢夢', 5),
#    ('楊丞琳', 4),
#    ('張烽益', 4),
#    ('一劍浣春秋', 3),
#    ('圤智雨', 3),
#    ('金寶娜', 2),
#    ('Jacky', 2),
#    ('鄭家純', 1),
#    ('阿嘉', 1),
#    ('女優苡若', 1)]),
#  ('專題',
#   [('鄧佳華', 12),
#    ('Morgan', 10),
#    ('孟若羽', 3),
#    ('阿嘉', 3),
#    ('YoungJohnny', 3),
#    ('一劍浣春秋', 2),
#    ('圤智雨', 2),
#    ('楊丞琳', 1),
#    ('女優苡若', 1),
#    ('金寶娜', 1),
#    ('阿喜', 1),
#    ('林育品', 1),
#    ('雪碧', 1),
#    ('方祺媛', 1),
#    ('阿澎', 1),
#    ('劉心語', 1),
#    ('Mogran', 1),
#    ('吳夢夢', 1)]),
#  ('全球',
#   [('職燁', 8),
#    ('張愛玲', 8),
#    ('澤倫斯基', 5),
#    ('桑傑士', 4),
#    ('佛瑞德里克森', 3),
#    ('長平', 3),
#    ('培斯科夫', 2),
#    ('VolodymyrZelensky）', 1),
#    ('PedroS', 1),
#    ('羅布雷斯', 1),
#    ('MargaritaRobles）', 1),
#    ('平田晃正利', 1),
#    ('平田晃正', 1),
#    ('平田', 1),
#    ('蘇青', 1),
#    ('關露', 1),
#    ('周瘦鵑', 1)]),
#  ('運動',
#   [('陳冠宇', 9),
#    ('志彥哥', 7),
#    ('林襄', 5),
#    ('黃捷', 5),
#    ('林志彥', 3),
#    ('肯尼哥', 3),
#    ('林立', 2),
#    ('蔣智賢', 2),
#    ('曾豪駒', 2),
#    ('吳岱豪', 2),
#    ('羅賓森', 2),
#    ('朱雲豪', 2),
#    ('樂天桃猿', 1),
#    ('布雷克', 1),
#    ('梁家榮', 1),
#    ('陳晨威', 1),
#    ('蘇俊羽', 1),
#    ('高飛', 1),
#    ('陳家駒', 1),
#    ('李振昌', 1),
#    ('于森旭', 1),
#    ('林哲瑄', 1),
#    ('AndreIguodala', 1),
#    ('Kerr', 1),
#    ('Curry', 1),
#    ('Poole', 1),
#    ('Thompson', 1),
#    ('布魯斯', 1)]),
#  ('全部',
#   [('林傳凱', 24),
#    ('黃捷', 18),
#    ('鄧佳華', 18),
#    ('Morgan', 16),
#    ('小玉', 15),
#    ('林襄', 15),
#    ('孟若羽', 15),
#    ('阿布杜梅亭', 13),
#    ('劉品言', 13),
#    ('傅孟柏', 12),
#    ('麥建方', 10),
#    ('周淑萍', 9),
#    ('蔡易餘', 9),
#    ('陳冠宇', 9),
#    ('周玉蔻', 8),
#    ('職燁', 8),
#    ('張愛玲', 8),
#    ('志彥哥', 7),
#    ('蔡淑臻', 6),
#    ('吳夢夢', 6),
#    ('曾之喬', 5),
#    ('鄭家純', 5),
#    ('楊丞琳', 5),
#    ('一劍浣春秋', 5),
#    ('圤智雨', 5),
#    ('澤倫斯基', 5),
#    ('朱玉宸', 4),
#    ('盧秀燕', 4),
#    ('張烽益', 4),
#    ('阿嘉', 4),
#    ('桑傑士', 4),
#    ('邱垂正', 3),
#    ('曾豪駒', 3),
#    ('布雷克', 3),
#    ('蘇俊羽', 3),
#    ('林立', 3),
#    ('貝莉梅', 3),
#    ('金寶娜', 3),
#    ('YoungJohnny', 3),
#    ('佛瑞德里克森', 3),
#    ('長平', 3),
#    ('林志彥', 3),
#    ('肯尼哥', 3),
#    ('陳雅琳', 2),
#    ('李妍瑾', 2),
#    ('陳時中', 2),
#    ('曾銘宗', 2),
#    ('徐正文', 2),
#    ('李明哲', 2),
#    ('張國煒', 2),
#    ('梁家榮', 2),
#    ('鄧仲謀', 2),
#    ('高國慶', 2),
#    ('吳政紘', 2),
#    ('Jacky', 2),
#    ('女優苡若', 2),
#    ('培斯科夫', 2),
#    ('蔣智賢', 2),
#    ('吳岱豪', 2),
#    ('羅賓森', 2),
#    ('朱雲豪', 2),
#    ('吳姍儒', 1),
#    ('連千毅', 1),
#    ('陳吉仲', 1),
#    ('莫德納', 1),
#    ('陳明文喬', 1),
#    ('黃越宏', 1),
#    ('李秉穎', 1),
#    ('王鏡銘', 1),
#    ('朱育賢', 1),
#    ('羅凌筠', 1),
#    ('楊銘威', 1),
#    ('劉品', 1),
#    ('張閔勛', 1),
#    ('王建民', 1),
#    ('納瓦洛', 1),
#    ('Putri', 1),
#    ('Cherng', 1),
#    ('阿樂', 1),
#    ('曾梓展', 1),
#    ('傅雲慶', 1),
#    ('阿喜', 1),
#    ('林育品', 1),
#    ('雪碧', 1),
#    ('方祺媛', 1),
#    ('阿澎', 1),
#    ('劉心語', 1),
#    ('Mogran', 1),
#    ('VolodymyrZelensky）', 1),
#    ('PedroS', 1),
#    ('羅布雷斯', 1),
#    ('MargaritaRobles）', 1),
#    ('平田晃正利', 1),
#    ('平田晃正', 1),
#    ('平田', 1),
#    ('蘇青', 1),
#    ('關露', 1),
#    ('周瘦鵑', 1),
#    ('樂天桃猿', 1),
#    ('陳晨威', 1),
#    ('高飛', 1),
#    ('陳家駒', 1),
#    ('李振昌', 1),
#    ('于森旭', 1),
#    ('林哲瑄', 1),
#    ('AndreIguodala', 1),
#    ('Kerr', 1),
#    ('Curry', 1),
#    ('Poole', 1),
#    ('Thompson', 1),
#    ('布魯斯', 1)])]

# %%
df_hotPersons = pd.DataFrame(hotPersons, columns = ['category','top_keys'])

# %%
df_hotPersons
# Out:
#    category                                           top_keys
# 0        焦點  [(阿布杜梅亭, 13), (林傳凱, 8), (周淑萍, 3), (陳雅琳, 1), (李...
# 1        要聞  [(麥建方, 10), (蔡易餘, 9), (周玉蔻, 7), (邱垂正, 3), (陳時中...
# 2        即時  [(布雷克, 2), (蘇俊羽, 2), (陳雅琳, 1), (李妍瑾, 1), (曾豪駒,...
# 3        娛樂  [(劉品言, 13), (黃捷, 13), (傅孟柏, 12), (林襄, 10), (小玉...
# 4        新奇  [(林傳凱, 8), (周淑萍, 3), (貝莉梅, 3), (Putri, 1), (Ch...
# 5        生活  [(林傳凱, 8), (小玉, 7), (盧秀燕, 4), (周淑萍, 3), (朱玉宸, ...
# 6        財經  [(孟若羽, 12), (鄧佳華, 6), (Morgan, 6), (吳夢夢, 5), (...
# 7        專題  [(鄧佳華, 12), (Morgan, 10), (孟若羽, 3), (阿嘉, 3), (...
# 8        全球  [(職燁, 8), (張愛玲, 8), (澤倫斯基, 5), (桑傑士, 4), (佛瑞德里...
# 9        運動  [(陳冠宇, 9), (志彥哥, 7), (林襄, 5), (黃捷, 5), (林志彥, 3...
# 10       全部  [(林傳凱, 24), (黃捷, 18), (鄧佳華, 18), (Morgan, 16),...

# %%
df_hotPersons.to_csv('now_news_top_person_by_category_via_ner.csv', sep=',', index=False)

# %% [markdown]
# # Count top-200 hot keywords for each NE name
#
# count keywords for each NE name

# %%
NE_Name=['CARDINAL','DATE','EVENT','FAC','GPE','LANGUAGE','LAW','LOC','MONEY','NORP','ORDINAL','ORG','PERCENT','PERSON','PRODUCT','QUANTITY','TIME','WORK_OF_ART']

# %%
# %%time
# It takes time, at least 2 minitues.
top_word_NE=[]
for ne_name in NE_Name:
    allowedNE= [ne_name]
    topwords = get_top_ner_words()
    top_word_NE.append([ne_name, topwords])
# Out:
# CPU times: total: 406 ms
# Wall time: 393 ms

# %%
top_word_NE
# Out:
# [['CARDINAL',
#   [('焦點',
#     [('5萬', 3),
#      ('3萬', 2),
#      ('6.7', 2),
#      ('100', 2),
#      ('28億', 1),
#      ('一次性', 1),
#      ('72', 1),
#      ('10', 1),
#      ('40', 1),
#      ('50', 1),
#      ('20餘', 1),
#      ('3000', 1),
#      ('119', 1),
#      ('18', 1),
#      ('98', 1),
#      ('600', 1),
#      ('11', 1),
#      ('1300', 1),
#      ('一半', 1),
#      ('之一', 1)]),
#    ('要聞',
#     [('1922', 1),
#      ('119', 1),
#      ('180萬', 1),
#      ('1120', 1),
#      ('73億', 1),
#      ('9.34億', 1),
#      ('40億', 1)]),
#    ('即時', [('10', 4)]),
#    ('娛樂', [('162萬', 2), ('之一', 2), ('20', 1), ('百萬', 1)]),
#    ('新奇',
#     [('12', 1),
#      ('600', 1),
#      ('11', 1),
#      ('1300', 1),
#      ('一半', 1),
#      ('之一', 1),
#      ('破萬', 1)]),
#    ('生活',
#     [('之一', 3),
#      ('15', 3),
#      ('442', 2),
#      ('17萬', 2),
#      ('600', 1),
#      ('11', 1),
#      ('1300', 1),
#      ('一半', 1),
#      ('300萬', 1),
#      ('百萬', 1),
#      ('21', 1),
#      ('149', 1),
#      ('14', 1),
#      ('50', 1),
#      ('70', 1),
#      ('0800', 1),
#      ('1925', 1),
#      ('1980', 1),
#      ('1995', 1),
#      ('15萬', 1)]),
#    ('財經',
#     [('24', 1),
#      ('50多', 1),
#      ('400萬', 1),
#      ('4百萬', 1),
#      ('70', 1),
#      ('一半', 1),
#      ('200', 1),
#      ('30萬', 1),
#      ('20幾萬', 1),
#      ('破百', 1),
#      ('百萬', 1),
#      ('18', 1),
#      ('19', 1),
#      ('20', 1),
#      ('10', 1)]),
#    ('專題',
#     [('一半', 2),
#      ('10', 1),
#      ('3萬多', 1),
#      ('八比二', 1),
#      ('五比五', 1),
#      ('15', 1),
#      ('之一', 1),
#      ('40幾', 1),
#      ('20', 1)]),
#    ('全球',
#     [('10萬', 2),
#      ('13萬4000', 1),
#      ('6萬4000', 1),
#      ('12', 1),
#      ('2019', 1),
#      ('1800', 1),
#      ('4萬7131', 1),
#      ('51', 1),
#      ('754萬3609', 1),
#      ('2萬9222', 1),
#      ('6713', 1),
#      ('180', 1),
#      ('5905.1', 1),
#      ('1573', 1),
#      ('147', 1),
#      ('14萬8921', 1),
#      ('445', 1),
#      ('633.82', 1),
#      ('419.45', 1),
#      ('6000', 1),
#      ('逾萬', 1)]),
#    ('運動',
#     [('10', 4),
#      ('12', 1),
#      ('70', 1),
#      ('13', 1),
#      ('65', 1),
#      ('138', 1),
#      ('180', 1),
#      ('11', 1),
#      ('23', 1),
#      ('47', 1),
#      ('29', 1),
#      ('126.09', 1),
#      ('1.7', 1),
#      ('50', 1),
#      ('1.0', 1),
#      ('60', 1),
#      ('306', 1)]),
#    ('全部',
#     [('10', 11),
#      ('之一', 8),
#      ('一半', 6),
#      ('11', 4),
#      ('15', 4),
#      ('5萬', 3),
#      ('50', 3),
#      ('600', 3),
#      ('1300', 3),
#      ('20', 3),
#      ('百萬', 3),
#      ('12', 3),
#      ('70', 3),
#      ('3萬', 2),
#      ('6.7', 2),
#      ('100', 2),
#      ('119', 2),
#      ('18', 2),
#      ('162萬', 2),
#      ('442', 2),
#      ('17萬', 2),
#      ('10萬', 2),
#      ('180', 2),
#      ('28億', 1),
#      ('一次性', 1),
#      ('72', 1),
#      ('40', 1),
#      ('20餘', 1),
#      ('3000', 1),
#      ('98', 1),
#      ('1922', 1),
#      ('180萬', 1),
#      ('1120', 1),
#      ('73億', 1),
#      ('9.34億', 1),
#      ('40億', 1),
#      ('破萬', 1),
#      ('300萬', 1),
#      ('21', 1),
#      ('149', 1),
#      ('14', 1),
#      ('0800', 1),
#      ('1925', 1),
#      ('1980', 1),
#      ('1995', 1),
#      ('15萬', 1),
#      ('24', 1),
#      ('50多', 1),
#      ('400萬', 1),
#      ('4百萬', 1),
#      ('200', 1),
#      ('30萬', 1),
#      ('20幾萬', 1),
#      ('破百', 1),
#      ('19', 1),
#      ('3萬多', 1),
#      ('八比二', 1),
#      ('五比五', 1),
#      ('40幾', 1),
#      ('13萬4000', 1),
#      ('6萬4000', 1),
#      ('2019', 1),
#      ('1800', 1),
#      ('4萬7131', 1),
#      ('51', 1),
#      ('754萬3609', 1),
#      ('2萬9222', 1),
#      ('6713', 1),
#      ('5905.1', 1),
#      ('1573', 1),
#      ('147', 1),
#      ('14萬8921', 1),
#      ('445', 1),
#      ('633.82', 1),
#      ('419.45', 1),
#      ('6000', 1),
#      ('逾萬', 1),
#      ('13', 1),
#      ('65', 1),
#      ('138', 1),
#      ('23', 1),
#      ('47', 1),
#      ('29', 1),
#      ('126.09', 1),
#      ('1.7', 1),
#      ('1.0', 1),
#      ('60', 1),
#      ('306', 1)])]],
#  ['DATE',
#   [('焦點',
#     [('今天', 5),
#      ('4月22日至4月24日', 2),
#      ('1年', 2),
#      ('21日', 2),
#      ('昨天', 2),
#      ('世界地球日', 1),
#      ('4月28日', 1),
#      ('6月30日', 1),
#      ('22日至24日', 1),
#      ('17日', 1),
#      ('4/30前', 1),
#      ('夏季', 1),
#      ('3月', 1),
#      ('去年', 1),
#      ('三天', 1),
#      ('當天', 1),
#      ('4月21日至5月8日', 1),
#      ('5月8日', 1),
#      ('去年6月', 1),
#      ('歿年21歲', 1),
#      ('2021年5月中下旬', 1),
#      ('2021年6月14日', 1),
#      ('2021年8月20日', 1),
#      ('2021年11月25日', 1),
#      ('20日', 1),
#      ('上周', 1),
#      ('第4天', 1),
#      ('2022年', 1),
#      ('4月23日', 1),
#      ('3年', 1),
#      ('今年', 1),
#      ('這三天', 1),
#      ('母親節', 1),
#      ('422世界地球日', 1)]),
#    ('要聞',
#     [('21）日', 3),
#      ('今（21）日', 2),
#      ('1年', 2),
#      ('2歲', 1),
#      ('14日', 1),
#      ('19日', 1),
#      ('6歲', 1),
#      ('5月', 1),
#      ('10日', 1),
#      ('30天', 1),
#      ('18日', 1),
#      ('3天', 1),
#      ('10天', 1),
#      ('28日', 1),
#      ('2020年', 1),
#      ('本（4）月', 1),
#      ('今（2022）年度', 1),
#      ('2021年', 1),
#      ('今年度', 1),
#      ('4月', 1)]),
#    ('即時', [('今天', 3), ('昨天', 2), ('20日', 1), ('1309天', 1)]),
#    ('娛樂',
#     [('今天', 4),
#      ('21日', 3),
#      ('30年', 3),
#      ('1個月', 2),
#      ('26歲', 1),
#      ('4個月', 1),
#      ('母親節', 1),
#      ('20年', 1),
#      ('今年', 1)]),
#    ('新奇',
#     [('這天', 4),
#      ('7歲', 1),
#      ('去年10月', 1),
#      ('103年6月30日', 1),
#      ('去年', 1),
#      ('30天', 1),
#      ('3月中旬', 1),
#      ('5月', 1),
#      ('3月', 1),
#      ('夏天', 1),
#      ('2022年', 1),
#      ('4月23日', 1),
#      ('3年', 1),
#      ('今年', 1),
#      ('這三天', 1),
#      ('母親節', 1),
#      ('422世界地球日', 1),
#      ('2歲半', 1),
#      ('1歲半', 1)]),
#    ('生活',
#     [('今天', 4),
#      ('21日', 2),
#      ('明天', 2),
#      ('5月', 2),
#      ('2022年', 1),
#      ('4月23日', 1),
#      ('3年', 1),
#      ('今年', 1),
#      ('這三天', 1),
#      ('母親節', 1),
#      ('422世界地球日', 1),
#      ('28歲', 1),
#      ('今天（21日', 1),
#      ('25歲', 1),
#      ('26歲', 1),
#      ('52歲', 1)]),
#    ('財經',
#     [('去年底', 3),
#      ('下個月', 2),
#      ('3月初', 1),
#      ('今年', 1),
#      ('2019年3月', 1),
#      ('020年11月', 1),
#      ('3月21日', 1),
#      ('6個月', 1),
#      ('最近幾年', 1),
#      ('近年', 1),
#      ('5、6年', 1),
#      ('2到3年', 1),
#      ('前幾天', 1),
#      ('18歲', 1),
#      ('50歲', 1),
#      ('2019年', 1),
#      ('三天', 1),
#      ('22歲', 1),
#      ('18歲前', 1),
#      ('18', 1),
#      ('今年年初', 1),
#      ('去年12月', 1),
#      ('今年一月', 1),
#      ('二月', 1),
#      ('一個月', 1),
#      ('三年多', 1)]),
#    ('專題',
#     [('去年底', 2),
#      ('下個月', 2),
#      ('去年', 2),
#      ('今年年初', 1),
#      ('去年12月', 1),
#      ('今年一月', 1),
#      ('二月', 1),
#      ('一個月', 1),
#      ('三年多', 1),
#      ('近年', 1),
#      ('7年前', 1),
#      ('今年', 1),
#      ('30歲', 1),
#      ('去年年末', 1),
#      ('幾十歲', 1),
#      ('一兩年', 1),
#      ('今年2月', 1),
#      ('2015年', 1),
#      ('一年', 1)]),
#    ('全球',
#     [('今天', 8),
#      ('94歲', 5),
#      ('上週四', 3),
#      ('20日', 2),
#      ('18日', 2),
#      ('同日', 2),
#      ('21日', 1),
#      ('數天後', 1),
#      ('2月24日', 1),
#      ('10天', 1),
#      ('上週', 1),
#      ('7天', 1),
#      ('最近一週', 1),
#      ('去年底', 1),
#      ('今年初', 1),
#      ('5月12日', 1),
#      ('6月底', 1),
#      ('2個月', 1),
#      ('數日', 1),
#      ('3月', 1),
#      ('上月', 1),
#      ('74歲', 1),
#      ('隔天', 1),
#      ('16日', 1),
#      ('3天', 1),
#      ('15日', 1),
#      ('近一個月', 1),
#      ('1920年', 1),
#      ('1949年', 1),
#      ('1952年', 1),
#      ('1950至1976年', 1),
#      ('當年', 1)]),
#    ('運動',
#     [('今天', 4),
#      ('上周', 3),
#      ('本周', 2),
#      ('2003年', 1),
#      ('2016年', 1),
#      ('1309日', 1),
#      ('昨天', 1),
#      ('24日', 1),
#      ('30年', 1),
#      ('今年', 1),
#      ('去年', 1),
#      ('一個月', 1),
#      ('今年二月', 1)]),
#    ('全部',
#     [('今天', 28),
#      ('21日', 8),
#      ('今年', 7),
#      ('去年底', 6),
#      ('去年', 5),
#      ('昨天', 5),
#      ('94歲', 5),
#      ('1年', 4),
#      ('20日', 4),
#      ('上周', 4),
#      ('母親節', 4),
#      ('5月', 4),
#      ('30年', 4),
#      ('這天', 4),
#      ('下個月', 4),
#      ('3月', 3),
#      ('2022年', 3),
#      ('4月23日', 3),
#      ('3年', 3),
#      ('這三天', 3),
#      ('422世界地球日', 3),
#      ('21）日', 3),
#      ('18日', 3),
#      ('一個月', 3),
#      ('上週四', 3),
#      ('4月22日至4月24日', 2),
#      ('三天', 2),
#      ('今（21）日', 2),
#      ('30天', 2),
#      ('3天', 2),
#      ('10天', 2),
#      ('1個月', 2),
#      ('26歲', 2),
#      ('明天', 2),
#      ('近年', 2),
#      ('今年年初', 2),
#      ('去年12月', 2),
#      ('今年一月', 2),
#      ('二月', 2),
#      ('三年多', 2),
#      ('同日', 2),
#      ('本周', 2),
#      ('世界地球日', 1),
#      ('4月28日', 1),
#      ('6月30日', 1),
#      ('22日至24日', 1),
#      ('17日', 1),
#      ('4/30前', 1),
#      ('夏季', 1),
#      ('當天', 1),
#      ('4月21日至5月8日', 1),
#      ('5月8日', 1),
#      ('去年6月', 1),
#      ('歿年21歲', 1),
#      ('2021年5月中下旬', 1),
#      ('2021年6月14日', 1),
#      ('2021年8月20日', 1),
#      ('2021年11月25日', 1),
#      ('第4天', 1),
#      ('2歲', 1),
#      ('14日', 1),
#      ('19日', 1),
#      ('6歲', 1),
#      ('10日', 1),
#      ('28日', 1),
#      ('2020年', 1),
#      ('本（4）月', 1),
#      ('今（2022）年度', 1),
#      ('2021年', 1),
#      ('今年度', 1),
#      ('4月', 1),
#      ('1309天', 1),
#      ('4個月', 1),
#      ('20年', 1),
#      ('7歲', 1),
#      ('去年10月', 1),
#      ('103年6月30日', 1),
#      ('3月中旬', 1),
#      ('夏天', 1),
#      ('2歲半', 1),
#      ('1歲半', 1),
#      ('28歲', 1),
#      ('今天（21日', 1),
#      ('25歲', 1),
#      ('52歲', 1),
#      ('3月初', 1),
#      ('2019年3月', 1),
#      ('020年11月', 1),
#      ('3月21日', 1),
#      ('6個月', 1),
#      ('最近幾年', 1),
#      ('5、6年', 1),
#      ('2到3年', 1),
#      ('前幾天', 1),
#      ('18歲', 1),
#      ('50歲', 1),
#      ('2019年', 1),
#      ('22歲', 1),
#      ('18歲前', 1),
#      ('18', 1),
#      ('7年前', 1),
#      ('30歲', 1),
#      ('去年年末', 1),
#      ('幾十歲', 1),
#      ('一兩年', 1),
#      ('今年2月', 1),
#      ('2015年', 1),
#      ('一年', 1),
#      ('數天後', 1),
#      ('2月24日', 1),
#      ('上週', 1),
#      ('7天', 1),
#      ('最近一週', 1),
#      ('今年初', 1),
#      ('5月12日', 1),
#      ('6月底', 1),
#      ('2個月', 1),
#      ('數日', 1),
#      ('上月', 1),
#      ('74歲', 1),
#      ('隔天', 1),
#      ('16日', 1),
#      ('15日', 1),
#      ('近一個月', 1),
#      ('1920年', 1),
#      ('1949年', 1),
#      ('1952年', 1),
#      ('1950至1976年', 1),
#      ('當年', 1),
#      ('2003年', 1),
#      ('2016年', 1),
#      ('1309日', 1),
#      ('24日', 1),
#      ('今年二月', 1)])]],
#  ['EVENT',
#   [('焦點', []),
#    ('要聞', [('新冠肺炎', 1)]),
#    ('即時', []),
#    ('娛樂', []),
#    ('新奇', []),
#    ('生活', []),
#    ('財經', [('鄧佳華事件', 1)]),
#    ('專題', [('鄧佳華事件', 1)]),
#    ('全球', [('俄烏戰爭', 2)]),
#    ('運動', []),
#    ('全部', [('鄧佳華事件', 2), ('俄烏戰爭', 2), ('新冠肺炎', 1)])]],
#  ['FAC',
#   [('焦點', []),
#    ('要聞', []),
#    ('即時', []),
#    ('娛樂', [('樂天主場', 2)]),
#    ('新奇', []),
#    ('生活',
#     [('耕莘醫院', 1),
#      ('新北福和橋', 1),
#      ('陸軍航空特戰部', 1),
#      ('29處', 1),
#      ('119', 1),
#      ('一中街', 1)]),
#    ('財經', []),
#    ('專題', []),
#    ('全球', [('紐約醫院', 1)]),
#    ('運動', [('球場', 1), ('台中洲際球場', 1)]),
#    ('全部',
#     [('樂天主場', 2),
#      ('耕莘醫院', 1),
#      ('新北福和橋', 1),
#      ('陸軍航空特戰部', 1),
#      ('29處', 1),
#      ('119', 1),
#      ('一中街', 1),
#      ('紐約醫院', 1),
#      ('球場', 1),
#      ('台中洲際球場', 1)])]],
#  ['GPE',
#   [('焦點',
#     [('台灣', 6),
#      ('美國', 6),
#      ('台北', 4),
#      ('寧波市', 2),
#      ('台門市', 1),
#      ('寧波', 1),
#      ('中國', 1),
#      ('浙江省', 1),
#      ('新北', 1),
#      ('南港', 1)]),
#    ('要聞', [('中國', 2), ('北京市', 1), ('台北市', 1), ('兩岸', 1), ('台中', 1)]),
#    ('即時', [('台北', 2), ('新北', 1)]),
#    ('娛樂', [('高雄市', 3), ('緬甸', 1), ('泰國', 1)]),
#    ('新奇',
#     [('台灣', 5),
#      ('美國', 5),
#      ('新加坡', 3),
#      ('台北市', 2),
#      ('台北', 2),
#      ('南港', 1),
#      ('日本', 1)]),
#    ('生活',
#     [('台中市', 6),
#      ('美國', 5),
#      ('台灣', 4),
#      ('台北', 3),
#      ('錢莊', 2),
#      ('台中', 2),
#      ('南港', 1),
#      ('新北市', 1),
#      ('新店', 1),
#      ('嘉義', 1),
#      ('中市', 1),
#      ('高雄市', 1),
#      ('北市', 1)]),
#    ('財經',
#     [('台灣', 42),
#      ('日本', 13),
#      ('中國', 9),
#      ('台北市', 2),
#      ('新北市', 1),
#      ('中資', 1),
#      ('上海', 1)]),
#    ('專題', [('台灣', 28), ('日本', 11), ('中國', 3), ('美國', 1)]),
#    ('全球',
#     [('上海', 12),
#      ('烏克蘭', 9),
#      ('日本', 6),
#      ('丹麥', 5),
#      ('基輔', 5),
#      ('西班牙', 4),
#      ('烏國', 4),
#      ('俄方', 4),
#      ('東京都', 3),
#      ('沖繩縣', 3),
#      ('俄羅斯', 3),
#      ('中國', 3),
#      ('馬德里', 2),
#      ('哥本哈根', 1),
#      ('西國', 1),
#      ('沖繩', 1),
#      ('佐賀縣', 1),
#      ('東京', 1),
#      ('烏方', 1),
#      ('上海市', 1),
#      ('美國', 1),
#      ('德國', 1),
#      ('大陸', 1)]),
#    ('運動', [('金州', 1), ('台灣', 1), ('肯尼哥', 1)]),
#    ('全部',
#     [('台灣', 86),
#      ('日本', 31),
#      ('中國', 18),
#      ('美國', 18),
#      ('上海', 13),
#      ('台北', 11),
#      ('烏克蘭', 9),
#      ('台中市', 6),
#      ('台北市', 5),
#      ('丹麥', 5),
#      ('基輔', 5),
#      ('高雄市', 4),
#      ('西班牙', 4),
#      ('烏國', 4),
#      ('俄方', 4),
#      ('南港', 3),
#      ('台中', 3),
#      ('新加坡', 3),
#      ('東京都', 3),
#      ('沖繩縣', 3),
#      ('俄羅斯', 3),
#      ('寧波市', 2),
#      ('新北', 2),
#      ('新北市', 2),
#      ('錢莊', 2),
#      ('馬德里', 2),
#      ('台門市', 1),
#      ('寧波', 1),
#      ('浙江省', 1),
#      ('北京市', 1),
#      ('兩岸', 1),
#      ('緬甸', 1),
#      ('泰國', 1),
#      ('新店', 1),
#      ('嘉義', 1),
#      ('中市', 1),
#      ('北市', 1),
#      ('中資', 1),
#      ('哥本哈根', 1),
#      ('西國', 1),
#      ('沖繩', 1),
#      ('佐賀縣', 1),
#      ('東京', 1),
#      ('烏方', 1),
#      ('上海市', 1),
#      ('德國', 1),
#      ('大陸', 1),
#      ('金州', 1),
#      ('肯尼哥', 1)])]],
#  ['LANGUAGE',
#   [('焦點', []),
#    ('要聞', []),
#    ('即時', [('台語', 6)]),
#    ('娛樂', []),
#    ('新奇', [('中文', 1)]),
#    ('生活', []),
#    ('財經', [('華語', 1)]),
#    ('專題', [('華語', 3)]),
#    ('全球', []),
#    ('運動', []),
#    ('全部', [('台語', 6), ('華語', 4), ('中文', 1)])]],
#  ['LAW',
#   [('焦點', []),
#    ('要聞', [('會計法', 2), ('兩岸條例第33條', 1), ('公職人員選舉罷免法', 1)]),
#    ('即時', []),
#    ('娛樂', []),
#    ('新奇', []),
#    ('生活', []),
#    ('財經', [('勞動基準法', 1)]),
#    ('專題', []),
#    ('全球', []),
#    ('運動', []),
#    ('全部', [('會計法', 2), ('兩岸條例第33條', 1), ('公職人員選舉罷免法', 1), ('勞動基準法', 1)])]],
#  ['LOC',
#   [('焦點', [('歐洲', 4), ('大屯火山', 1)]),
#    ('要聞', [('亞洲', 1)]),
#    ('即時', [('大屯火山', 1), ('金牛座', 1)]),
#    ('娛樂', []),
#    ('新奇', [('歐洲', 5)]),
#    ('生活', [('歐洲', 4), ('新店山區', 1), ('新店溪', 1)]),
#    ('財經', [('兩岸', 1)]),
#    ('專題', [('東南亞', 1), ('亞洲', 1)]),
#    ('全球', []),
#    ('運動', []),
#    ('全部',
#     [('歐洲', 13),
#      ('大屯火山', 2),
#      ('亞洲', 2),
#      ('金牛座', 1),
#      ('新店山區', 1),
#      ('新店溪', 1),
#      ('兩岸', 1),
#      ('東南亞', 1)])]],
#  ['MONEY',
#   [('焦點',
#     [('3元', 4),
#      ('75元', 2),
#      ('109元', 2),
#      ('899元', 2),
#      ('599元', 2),
#      ('8元', 2),
#      ('7元', 1),
#      ('70元', 1),
#      ('99元', 1),
#      ('50元', 1),
#      ('39元', 1),
#      ('5元', 1),
#      ('680元', 1),
#      ('17元', 1),
#      ('50元硬幣', 1)]),
#    ('要聞',
#     [('4元', 1),
#      ('16.6億餘元', 1),
#      ('7.96億元', 1),
#      ('3.91億元', 1),
#      ('0.19億元', 1),
#      ('40億元', 1)]),
#    ('即時', []),
#    ('娛樂', [('800元', 1), ('1900元', 1), ('上千萬元', 1), ('1千萬元', 1)]),
#    ('新奇', []),
#    ('生活', [('20萬元', 1), ('800元', 1), ('1900元', 1), ('上千萬元', 1)]),
#    ('財經',
#     [('5億元', 1),
#      ('200萬台幣', 1),
#      ('數億元', 1),
#      ('30幾萬元', 1),
#      ('十幾萬元', 1),
#      ('萬元', 1)]),
#    ('專題',
#     [('30萬元', 2),
#      ('120元', 1),
#      ('三百多萬元', 1),
#      ('40萬元', 1),
#      ('一百多萬元', 1),
#      ('兩千元', 1)]),
#    ('全球', []),
#    ('運動', []),
#    ('全部',
#     [('3元', 4),
#      ('75元', 2),
#      ('109元', 2),
#      ('899元', 2),
#      ('599元', 2),
#      ('8元', 2),
#      ('800元', 2),
#      ('1900元', 2),
#      ('上千萬元', 2),
#      ('30萬元', 2),
#      ('7元', 1),
#      ('70元', 1),
#      ('99元', 1),
#      ('50元', 1),
#      ('39元', 1),
#      ('5元', 1),
#      ('680元', 1),
#      ('17元', 1),
#      ('50元硬幣', 1),
#      ('4元', 1),
#      ('16.6億餘元', 1),
#      ('7.96億元', 1),
#      ('3.91億元', 1),
#      ('0.19億元', 1),
#      ('40億元', 1),
#      ('1千萬元', 1),
#      ('20萬元', 1),
#      ('5億元', 1),
#      ('200萬台幣', 1),
#      ('數億元', 1),
#      ('30幾萬元', 1),
#      ('十幾萬元', 1),
#      ('萬元', 1),
#      ('120元', 1),
#      ('三百多萬元', 1),
#      ('40萬元', 1),
#      ('一百多萬元', 1),
#      ('兩千元', 1)])]],
#  ['NORP',
#   [('焦點', [('美國籍', 2), ('英式', 1), ('台灣', 1)]),
#    ('要聞', []),
#    ('即時', []),
#    ('娛樂', [('日本', 1), ('日系', 1), ('台灣', 1)]),
#    ('新奇', [('南美', 1), ('日本', 1)]),
#    ('生活', [('日本', 1), ('日系', 1)]),
#    ('財經', [('台灣', 2), ('中資', 1), ('日本', 1)]),
#    ('專題', [('台灣', 3), ('日本', 2), ('日本人', 1)]),
#    ('全球', [('上海人', 3), ('烏國', 1), ('烏克蘭人', 1)]),
#    ('運動', []),
#    ('全部',
#     [('台灣', 7),
#      ('日本', 6),
#      ('上海人', 3),
#      ('美國籍', 2),
#      ('日系', 2),
#      ('英式', 1),
#      ('南美', 1),
#      ('中資', 1),
#      ('日本人', 1),
#      ('烏國', 1),
#      ('烏克蘭人', 1)])]],
#  ['ORDINAL',
#   [('焦點', [('第一', 1)]),
#    ('要聞', [('第6', 3), ('第20', 2), ('第2', 1), ('第1', 1), ('第3', 1)]),
#    ('即時', [('第一', 2), ('第二', 1), ('第三', 1)]),
#    ('娛樂', [('第二', 1), ('第一', 1)]),
#    ('新奇', [('第一', 2)]),
#    ('生活', [('第一', 1)]),
#    ('財經', [('第一', 3)]),
#    ('專題', [('第一', 2), ('第二', 1), ('第五', 1)]),
#    ('全球', [('第一', 2), ('第2', 1), ('第7', 1)]),
#    ('運動', [('第二', 3), ('第三', 2), ('第2', 1), ('第一', 1)]),
#    ('全部',
#     [('第一', 15),
#      ('第二', 6),
#      ('第6', 3),
#      ('第2', 3),
#      ('第三', 3),
#      ('第20', 2),
#      ('第1', 1),
#      ('第3', 1),
#      ('第五', 1),
#      ('第7', 1)])]],
#  ['ORG',
#   [('焦點',
#     [('凱銳光電', 9),
#      ('寧波中院', 4),
#      ('華視', 4),
#      ('寧波市中級法院', 2),
#      ('Amazon', 2),
#      ('網教', 1),
#      ('人大', 1),
#      ('中共', 1),
#      ('衛生局', 1),
#      ('疾管署', 1),
#      ('福斯集團Tier1', 1),
#      ('凱銳', 1),
#      ('藍寶堅尼', 1),
#      ('賓利', 1),
#      ('保時捷', 1),
#      ('奧迪', 1)]),
#    ('要聞',
#     [('陸委會', 6),
#      ('法務部', 5),
#      ('星宇航空', 4),
#      ('星宇', 4),
#      ('衛生局', 2),
#      ('疾管署', 2),
#      ('國民黨', 2),
#      ('中央', 1),
#      ('中心', 1),
#      ('台灣兒科醫學會', 1),
#      ('中央流行疫情指揮中心', 1),
#      ('行政院', 1),
#      ('立法院', 1),
#      ('中共', 1),
#      ('立法院財政委員會', 1),
#      ('民進黨', 1),
#      ('交通委員會', 1),
#      ('新北衛生局', 1),
#      ('嘉義衛生局長', 1),
#      ('國民黨團', 1),
#      ('星宇航', 1),
#      ('立榮', 1),
#      ('長榮航太', 1)]),
#    ('即時', [('華視', 4), ('中共', 1)]),
#    ('娛樂', [('威視', 1), ('新北地檢署', 1)]),
#    ('新奇',
#     [('凱銳光電', 9),
#      ('台北市立動物園', 3),
#      ('Amazon', 2),
#      ('北市立動物園', 1),
#      ('福斯集團Tier1', 1),
#      ('凱銳', 1),
#      ('藍寶堅尼', 1),
#      ('賓利', 1),
#      ('保時捷', 1),
#      ('奧迪', 1)]),
#    ('生活',
#     [('凱銳光電', 9),
#      ('Amazon', 2),
#      ('福斯集團Tier1', 1),
#      ('凱銳', 1),
#      ('藍寶堅尼', 1),
#      ('賓利', 1),
#      ('保時捷', 1),
#      ('奧迪', 1),
#      ('新北地檢署', 1),
#      ('衛生局', 1),
#      ('消防局', 1),
#      ('台中榮', 1),
#      ('國民黨團', 1)]),
#    ('財經',
#     [('文化部', 7),
#      ('勞動部', 3),
#      ('陸委會', 3),
#      ('TWAV', 3),
#      ('iWant', 2),
#      ('經濟部', 2),
#      ('愛旺', 1),
#      ('台灣勞動與社會政策研究協會', 1),
#      ('中華演藝總工會', 1),
#      ('台北市電影電視演藝業職業工會', 1),
#      ('Youtuber', 1),
#      ('政府', 1),
#      ('中國新聞出版署', 1),
#      ('上海市公安局奉賢分局', 1),
#      ('麻豆', 1),
#      ('NOWnews', 1),
#      ('金管會', 1),
#      ('財政部', 1),
#      ('Jacky', 1)]),
#    ('專題', [('iWant', 1), ('Jacky', 1)]),
#    ('全球',
#     [('中共', 3),
#      ('中央社', 1),
#      ('西國政府', 1),
#      ('歐洲聯盟', 1),
#      ('西國國防部', 1),
#      ('俄軍', 1),
#      ('日本放送協會', 1),
#      ('朝日電視台', 1),
#      ('古屋工業大學', 1),
#      ('克里姆林宮', 1),
#      ('美聯社', 1),
#      ('疾管署', 1),
#      ('輝瑞', 1)]),
#    ('運動',
#     [('富邦', 2),
#      ('中信', 1),
#      ('KevinLooney', 1),
#      ('Gar', 1),
#      ('Green', 1),
#      ('Kerr', 1),
#      ('JoeLacob', 1),
#      ('Bob', 1)]),
#    ('全部',
#     [('凱銳光電', 27),
#      ('陸委會', 9),
#      ('華視', 8),
#      ('文化部', 7),
#      ('中共', 6),
#      ('Amazon', 6),
#      ('法務部', 5),
#      ('寧波中院', 4),
#      ('衛生局', 4),
#      ('疾管署', 4),
#      ('星宇航空', 4),
#      ('星宇', 4),
#      ('福斯集團Tier1', 3),
#      ('凱銳', 3),
#      ('藍寶堅尼', 3),
#      ('賓利', 3),
#      ('保時捷', 3),
#      ('奧迪', 3),
#      ('台北市立動物園', 3),
#      ('iWant', 3),
#      ('勞動部', 3),
#      ('TWAV', 3),
#      ('寧波市中級法院', 2),
#      ('國民黨', 2),
#      ('國民黨團', 2),
#      ('新北地檢署', 2),
#      ('經濟部', 2),
#      ('Jacky', 2),
#      ('富邦', 2),
#      ('網教', 1),
#      ('人大', 1),
#      ('中央', 1),
#      ('中心', 1),
#      ('台灣兒科醫學會', 1),
#      ('中央流行疫情指揮中心', 1),
#      ('行政院', 1),
#      ('立法院', 1),
#      ('立法院財政委員會', 1),
#      ('民進黨', 1),
#      ('交通委員會', 1),
#      ('新北衛生局', 1),
#      ('嘉義衛生局長', 1),
#      ('星宇航', 1),
#      ('立榮', 1),
#      ('長榮航太', 1),
#      ('威視', 1),
#      ('北市立動物園', 1),
#      ('消防局', 1),
#      ('台中榮', 1),
#      ('愛旺', 1),
#      ('台灣勞動與社會政策研究協會', 1),
#      ('中華演藝總工會', 1),
#      ('台北市電影電視演藝業職業工會', 1),
#      ('Youtuber', 1),
#      ('政府', 1),
#      ('中國新聞出版署', 1),
#      ('上海市公安局奉賢分局', 1),
#      ('麻豆', 1),
#      ('NOWnews', 1),
#      ('金管會', 1),
#      ('財政部', 1),
#      ('中央社', 1),
#      ('西國政府', 1),
#      ('歐洲聯盟', 1),
#      ('西國國防部', 1),
#      ('俄軍', 1),
#      ('日本放送協會', 1),
#      ('朝日電視台', 1),
#      ('古屋工業大學', 1),
#      ('克里姆林宮', 1),
#      ('美聯社', 1),
#      ('輝瑞', 1),
#      ('中信', 1),
#      ('KevinLooney', 1),
#      ('Gar', 1),
#      ('Green', 1),
#      ('Kerr', 1),
#      ('JoeLacob', 1),
#      ('Bob', 1)])]],
#  ['PERCENT',
#   [('焦點', [('54%', 1), ('4%', 1)]),
#    ('要聞',
#     [('94%', 1),
#      ('千分之4', 1),
#      ('萬分之4', 1),
#      ('萬分之1', 1),
#      ('20%', 1),
#      ('103.28%', 1)]),
#    ('即時', []),
#    ('娛樂', []),
#    ('新奇', [('54%', 1), ('4%', 1)]),
#    ('生活', [('54%', 1), ('4%', 1)]),
#    ('財經', [('百分之百', 1)]),
#    ('專題', []),
#    ('全球', [('99%', 1), ('3.2%', 1)]),
#    ('運動', []),
#    ('全部',
#     [('54%', 3),
#      ('4%', 3),
#      ('94%', 1),
#      ('千分之4', 1),
#      ('萬分之4', 1),
#      ('萬分之1', 1),
#      ('20%', 1),
#      ('103.28%', 1),
#      ('百分之百', 1),
#      ('99%', 1),
#      ('3.2%', 1)])]],
#  ['PERSON',
#   [('焦點',
#     [('阿布杜梅亭', 13),
#      ('林傳凱', 8),
#      ('周淑萍', 3),
#      ('陳雅琳', 1),
#      ('李妍瑾', 1),
#      ('吳姍儒', 1),
#      ('小玉', 1),
#      ('連千毅', 1)]),
#    ('要聞',
#     [('麥建方', 10),
#      ('蔡易餘', 9),
#      ('周玉蔻', 7),
#      ('邱垂正', 3),
#      ('陳時中', 2),
#      ('曾銘宗', 2),
#      ('徐正文', 2),
#      ('李明哲', 2),
#      ('張國煒', 2),
#      ('陳吉仲', 1),
#      ('莫德納', 1),
#      ('陳明文喬', 1),
#      ('黃越宏', 1),
#      ('李秉穎', 1)]),
#    ('即時',
#     [('布雷克', 2),
#      ('蘇俊羽', 2),
#      ('陳雅琳', 1),
#      ('李妍瑾', 1),
#      ('曾豪駒', 1),
#      ('王鏡銘', 1),
#      ('朱育賢', 1),
#      ('梁家榮', 1),
#      ('林立', 1)]),
#    ('娛樂',
#     [('劉品言', 13),
#      ('黃捷', 13),
#      ('傅孟柏', 12),
#      ('林襄', 10),
#      ('小玉', 7),
#      ('蔡淑臻', 6),
#      ('曾之喬', 5),
#      ('鄧仲謀', 2),
#      ('朱玉宸', 2),
#      ('鄭家純', 2),
#      ('高國慶', 2),
#      ('吳政紘', 2),
#      ('羅凌筠', 1),
#      ('楊銘威', 1),
#      ('劉品', 1),
#      ('張閔勛', 1),
#      ('王建民', 1),
#      ('納瓦洛', 1)]),
#    ('新奇',
#     [('林傳凱', 8),
#      ('周淑萍', 3),
#      ('貝莉梅', 3),
#      ('Putri', 1),
#      ('Cherng', 1),
#      ('阿樂', 1)]),
#    ('生活',
#     [('林傳凱', 8),
#      ('小玉', 7),
#      ('盧秀燕', 4),
#      ('周淑萍', 3),
#      ('朱玉宸', 2),
#      ('鄭家純', 2),
#      ('曾梓展', 1),
#      ('傅雲慶', 1),
#      ('周玉蔻', 1)]),
#    ('財經',
#     [('孟若羽', 12),
#      ('鄧佳華', 6),
#      ('Morgan', 6),
#      ('吳夢夢', 5),
#      ('楊丞琳', 4),
#      ('張烽益', 4),
#      ('一劍浣春秋', 3),
#      ('圤智雨', 3),
#      ('金寶娜', 2),
#      ('Jacky', 2),
#      ('鄭家純', 1),
#      ('阿嘉', 1),
#      ('女優苡若', 1)]),
#    ('專題',
#     [('鄧佳華', 12),
#      ('Morgan', 10),
#      ('孟若羽', 3),
#      ('阿嘉', 3),
#      ('YoungJohnny', 3),
#      ('一劍浣春秋', 2),
#      ('圤智雨', 2),
#      ('楊丞琳', 1),
#      ('女優苡若', 1),
#      ('金寶娜', 1),
#      ('阿喜', 1),
#      ('林育品', 1),
#      ('雪碧', 1),
#      ('方祺媛', 1),
#      ('阿澎', 1),
#      ('劉心語', 1),
#      ('Mogran', 1),
#      ('吳夢夢', 1)]),
#    ('全球',
#     [('職燁', 8),
#      ('張愛玲', 8),
#      ('澤倫斯基', 5),
#      ('桑傑士', 4),
#      ('佛瑞德里克森', 3),
#      ('長平', 3),
#      ('培斯科夫', 2),
#      ('VolodymyrZelensky）', 1),
#      ('PedroS', 1),
#      ('羅布雷斯', 1),
#      ('MargaritaRobles）', 1),
#      ('平田晃正利', 1),
#      ('平田晃正', 1),
#      ('平田', 1),
#      ('蘇青', 1),
#      ('關露', 1),
#      ('周瘦鵑', 1)]),
#    ('運動',
#     [('陳冠宇', 9),
#      ('志彥哥', 7),
#      ('林襄', 5),
#      ('黃捷', 5),
#      ('林志彥', 3),
#      ('肯尼哥', 3),
#      ('林立', 2),
#      ('蔣智賢', 2),
#      ('曾豪駒', 2),
#      ('吳岱豪', 2),
#      ('羅賓森', 2),
#      ('朱雲豪', 2),
#      ('樂天桃猿', 1),
#      ('布雷克', 1),
#      ('梁家榮', 1),
#      ('陳晨威', 1),
#      ('蘇俊羽', 1),
#      ('高飛', 1),
#      ('陳家駒', 1),
#      ('李振昌', 1),
#      ('于森旭', 1),
#      ('林哲瑄', 1),
#      ('AndreIguodala', 1),
#      ('Kerr', 1),
#      ('Curry', 1),
#      ('Poole', 1),
#      ('Thompson', 1),
#      ('布魯斯', 1)]),
#    ('全部',
#     [('林傳凱', 24),
#      ('黃捷', 18),
#      ('鄧佳華', 18),
#      ('Morgan', 16),
#      ('小玉', 15),
#      ('林襄', 15),
#      ('孟若羽', 15),
#      ('阿布杜梅亭', 13),
#      ('劉品言', 13),
#      ('傅孟柏', 12),
#      ('麥建方', 10),
#      ('周淑萍', 9),
#      ('蔡易餘', 9),
#      ('陳冠宇', 9),
#      ('周玉蔻', 8),
#      ('職燁', 8),
#      ('張愛玲', 8),
#      ('志彥哥', 7),
#      ('蔡淑臻', 6),
#      ('吳夢夢', 6),
#      ('曾之喬', 5),
#      ('鄭家純', 5),
#      ('楊丞琳', 5),
#      ('一劍浣春秋', 5),
#      ('圤智雨', 5),
#      ('澤倫斯基', 5),
#      ('朱玉宸', 4),
#      ('盧秀燕', 4),
#      ('張烽益', 4),
#      ('阿嘉', 4),
#      ('桑傑士', 4),
#      ('邱垂正', 3),
#      ('曾豪駒', 3),
#      ('布雷克', 3),
#      ('蘇俊羽', 3),
#      ('林立', 3),
#      ('貝莉梅', 3),
#      ('金寶娜', 3),
#      ('YoungJohnny', 3),
#      ('佛瑞德里克森', 3),
#      ('長平', 3),
#      ('林志彥', 3),
#      ('肯尼哥', 3),
#      ('陳雅琳', 2),
#      ('李妍瑾', 2),
#      ('陳時中', 2),
#      ('曾銘宗', 2),
#      ('徐正文', 2),
#      ('李明哲', 2),
#      ('張國煒', 2),
#      ('梁家榮', 2),
#      ('鄧仲謀', 2),
#      ('高國慶', 2),
#      ('吳政紘', 2),
#      ('Jacky', 2),
#      ('女優苡若', 2),
#      ('培斯科夫', 2),
#      ('蔣智賢', 2),
#      ('吳岱豪', 2),
#      ('羅賓森', 2),
#      ('朱雲豪', 2),
#      ('吳姍儒', 1),
#      ('連千毅', 1),
#      ('陳吉仲', 1),
#      ('莫德納', 1),
#      ('陳明文喬', 1),
#      ('黃越宏', 1),
#      ('李秉穎', 1),
#      ('王鏡銘', 1),
#      ('朱育賢', 1),
#      ('羅凌筠', 1),
#      ('楊銘威', 1),
#      ('劉品', 1),
#      ('張閔勛', 1),
#      ('王建民', 1),
#      ('納瓦洛', 1),
#      ('Putri', 1),
#      ('Cherng', 1),
#      ('阿樂', 1),
#      ('曾梓展', 1),
#      ('傅雲慶', 1),
#      ('阿喜', 1),
#      ('林育品', 1),
#      ('雪碧', 1),
#      ('方祺媛', 1),
#      ('阿澎', 1),
#      ('劉心語', 1),
#      ('Mogran', 1),
#      ('VolodymyrZelensky）', 1),
#      ('PedroS', 1),
#      ('羅布雷斯', 1),
#      ('MargaritaRobles）', 1),
#      ('平田晃正利', 1),
#      ('平田晃正', 1),
#      ('平田', 1),
#      ('蘇青', 1),
#      ('關露', 1),
#      ('周瘦鵑', 1),
#      ('樂天桃猿', 1),
#      ('陳晨威', 1),
#      ('高飛', 1),
#      ('陳家駒', 1),
#      ('李振昌', 1),
#      ('于森旭', 1),
#      ('林哲瑄', 1),
#      ('AndreIguodala', 1),
#      ('Kerr', 1),
#      ('Curry', 1),
#      ('Poole', 1),
#      ('Thompson', 1),
#      ('布魯斯', 1)])]],
#  ['PRODUCT',
#   [('焦點', [('遠傳4G', 1), ('499', 1)]),
#    ('要聞', []),
#    ('即時', []),
#    ('娛樂', []),
#    ('新奇', [('遠傳4G', 1), ('499', 1)]),
#    ('生活', [('遠傳4G', 1), ('499', 1)]),
#    ('財經', []),
#    ('專題', []),
#    ('全球', []),
#    ('運動', []),
#    ('全部', [('遠傳4G', 3), ('499', 3)])]],
#  ['QUANTITY',
#   [('焦點', []),
#    ('要聞', [('39度', 1)]),
#    ('即時', []),
#    ('娛樂', []),
#    ('新奇', []),
#    ('生活', []),
#    ('財經', []),
#    ('專題', []),
#    ('全球', [('數百噸', 1), ('一位', 1)]),
#    ('運動', []),
#    ('全部', [('39度', 1), ('數百噸', 1), ('一位', 1)])]],
#  ['TIME',
#   [('焦點',
#     [('6小時', 1),
#      ('晚間', 1),
#      ('8時許', 1),
#      ('晚上', 1),
#      ('9時48分許', 1),
#      ('2021年6月14日晚間', 1),
#      ('次日淩晨', 1),
#      ('凌晨', 1),
#      ('上午9時許', 1),
#      ('9點34分', 1),
#      ('9點36分', 1)]),
#    ('要聞', [('48小時', 1), ('12小時', 1), ('24小時', 1), ('一個早上', 1), ('10點多', 1)]),
#    ('即時', [('凌晨', 1), ('上午9時許', 1), ('9點34分', 1), ('9點36分', 1)]),
#    ('娛樂', []),
#    ('新奇', []),
#    ('生活', [('下午', 2), ('凌晨', 1), ('1時許', 1), ('3時許', 1)]),
#    ('財經', []),
#    ('專題', [('5分鐘', 1), ('10分鐘', 1), ('一個小時', 1), ('一個多小時', 1)]),
#    ('全球',
#     [('晚間6時30分止', 1),
#      ('下午', 1),
#      ('19日晚間', 1),
#      ('19日凌晨2時', 1),
#      ('凌晨2點', 1),
#      ('半夜', 1),
#      ('兩點', 1)]),
#    ('運動', [('19分鐘', 1), ('半夜', 1), ('晚上十點', 1)]),
#    ('全部',
#     [('凌晨', 3),
#      ('下午', 3),
#      ('上午9時許', 2),
#      ('9點34分', 2),
#      ('9點36分', 2),
#      ('半夜', 2),
#      ('6小時', 1),
#      ('晚間', 1),
#      ('8時許', 1),
#      ('晚上', 1),
#      ('9時48分許', 1),
#      ('2021年6月14日晚間', 1),
#      ('次日淩晨', 1),
#      ('48小時', 1),
#      ('12小時', 1),
#      ('24小時', 1),
#      ('一個早上', 1),
#      ('10點多', 1),
#      ('1時許', 1),
#      ('3時許', 1),
#      ('5分鐘', 1),
#      ('10分鐘', 1),
#      ('一個小時', 1),
#      ('一個多小時', 1),
#      ('晚間6時30分止', 1),
#      ('19日晚間', 1),
#      ('19日凌晨2時', 1),
#      ('凌晨2點', 1),
#      ('兩點', 1),
#      ('19分鐘', 1),
#      ('晚上十點', 1)])]],
#  ['WORK_OF_ART',
#   [('焦點', [('小明星大跟班', 1), ('今日新聞', 1), ('0800-001922', 1)]),
#    ('要聞', [('NOWnews今日新聞', 1)]),
#    ('即時', [('爆廢公社', 1), ('旺好運', 1)]),
#    ('娛樂', [('華燈初上', 4), ('售命', 2), ('婆婆', 1), ('華燈', 1)]),
#    ('新奇', []),
#    ('生活', []),
#    ('財經',
#     [('華根初上', 6),
#      ('NOWnews今日新聞', 2),
#      ('NOWnews', 2),
#      ('鮑魚遊戲', 2),
#      ('華根', 2),
#      ('NOWNews今日新聞', 1),
#      ('91視頻', 1)]),
#    ('專題', [('華根初上', 5), ('華根', 1), ('NOWnews今日新聞', 1)]),
#    ('全球', []),
#    ('運動', []),
#    ('全部',
#     [('華根初上', 11),
#      ('NOWnews今日新聞', 4),
#      ('華燈初上', 4),
#      ('華根', 3),
#      ('售命', 2),
#      ('NOWnews', 2),
#      ('鮑魚遊戲', 2),
#      ('小明星大跟班', 1),
#      ('今日新聞', 1),
#      ('0800-001922', 1),
#      ('爆廢公社', 1),
#      ('旺好運', 1),
#      ('婆婆', 1),
#      ('華燈', 1),
#      ('NOWNews今日新聞', 1),
#      ('91視頻', 1)])]]]

# %%
df_top_word_NE = pd.DataFrame(top_word_NE, columns = ['ne_name','top_keys'])

# %%
df_top_word_NE
# Out:
#         ne_name                                           top_keys
# 0      CARDINAL  [(焦點, [('5萬', 3), ('3萬', 2), ('6.7', 2), ('100...
# 1          DATE  [(焦點, [('今天', 5), ('4月22日至4月24日', 2), ('1年', 2...
# 2         EVENT  [(焦點, []), (要聞, [('新冠肺炎', 1)]), (即時, []), (娛樂,...
# 3           FAC  [(焦點, []), (要聞, []), (即時, []), (娛樂, [('樂天主場', ...
# 4           GPE  [(焦點, [('台灣', 6), ('美國', 6), ('台北', 4), ('寧波市'...
# 5      LANGUAGE  [(焦點, []), (要聞, []), (即時, [('台語', 6)]), (娛樂, [...
# 6           LAW  [(焦點, []), (要聞, [('會計法', 2), ('兩岸條例第33條', 1), ...
# 7           LOC  [(焦點, [('歐洲', 4), ('大屯火山', 1)]), (要聞, [('亞洲', ...
# 8         MONEY  [(焦點, [('3元', 4), ('75元', 2), ('109元', 2), ('8...
# 9          NORP  [(焦點, [('美國籍', 2), ('英式', 1), ('台灣', 1)]), (要聞...
# 10      ORDINAL  [(焦點, [('第一', 1)]), (要聞, [('第6', 3), ('第20', 2...
# 11          ORG  [(焦點, [('凱銳光電', 9), ('寧波中院', 4), ('華視', 4), ('...
# 12      PERCENT  [(焦點, [('54%', 1), ('4%', 1)]), (要聞, [('94%', ...
# 13       PERSON  [(焦點, [('阿布杜梅亭', 13), ('林傳凱', 8), ('周淑萍', 3), ...
# 14      PRODUCT  [(焦點, [('遠傳4G', 1), ('499', 1)]), (要聞, []), (即...
# 15     QUANTITY  [(焦點, []), (要聞, [('39度', 1)]), (即時, []), (娛樂, ...
# 16         TIME  [(焦點, [('6小時', 1), ('晚間', 1), ('8時許', 1), ('晚上...
# 17  WORK_OF_ART  [(焦點, [('小明星大跟班', 1), ('今日新聞', 1), ('0800-0019...

# %%
df_top_word_NE.to_csv('now_news_topkey_by_ner_and_category.csv', sep=',', index=False) # 本次的NER任務
